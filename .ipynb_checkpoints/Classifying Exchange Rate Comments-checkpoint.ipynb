# %%
import re
from TextCleaner import TextCleaner
import pandas as pd
import numpy as np
import time
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sn
import keras_metrics as km
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold
from numpy import sqrt 
# %matplotlib inline
import nltk
from langdetect import detect
import contractions
from nltk.corpus import stopwords
from textblob import Word
from sklearn.preprocessing import LabelEncoder
from collections import Counter
from wordcloud import WordCloud
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem.snowball import PorterStemmer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split 

from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, GRU, SimpleRNN, SpatialDropout1D
from tensorflow.keras.layers import SpatialDropout1D
from tensorflow.keras.layers import Embedding
from tensorflow.python.keras.metrics import Metric
import tensorflow as tf    
import tensorflow_addons as tfa
from tensorflow import keras 
from keras.metrics import Precision, Recall

# Classifiers
from sklearn.naive_bayes import BernoulliNB
from sklearn import metrics
from sklearn.naive_bayes import (
    BernoulliNB,
    ComplementNB,
    MultinomialNB,
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
pd.options.mode.chained_assignment = None  # default='warn'

# %%
df = pd.read_csv('sentiment.csv')
df = df.drop(df.columns[0], axis=1)
df
# Out:
#                Author                                               Text  \
# 0            yusobays  @elonmusk @elonmusk  please Come to TRY₺ #turk...
# 1       BtcTurkDestek  @DrBatal  Hello, if you have registered using ...
# 2      RisingValhalla  “I trade weekly bars. You?”\n\n200 day moving ...
# 3        Erda55203615  @elonmusk Try turkish lira its at the bottom m...
# 4        Erda55203615            @ImTooRealForU TRY FUCKING TURKISH LIRA
# ...               ...                                                ...
# 1944  flyingstocksman  For those of you who missed it last night with...
# 1945         alpeshbp  GBP/USD Weekly Price Forecast – The British Po...
# 1946     campsbay_com  20.0142 ZAR for 1 GBP @ December 31, 2020 at 0...
# 1947       MajorFXNow  GBP/EUR: Pound Lifted by UK Approval of AstraZ...
# 1948     trader_blitz  GBP/JPY | $GBPJPY | $GBP $JPY\n\nBRITISH POUND...
#
#                            Time  Like Count Currency ISO Code  \
# 0     2021-01-31 22:21:58+00:00           1               TRY
# 1     2021-01-30 18:07:15+00:00           0               TRY
# 2     2021-01-30 03:29:59+00:00           0               TRY
# 3     2021-01-29 20:20:49+00:00           0               TRY
# 4     2021-01-29 20:19:36+00:00           0               TRY
# ...                         ...         ...               ...
# 1944  2021-01-01 09:24:17+00:00           0               GBP
# 1945  2021-01-01 07:13:32+00:00           0               GBP
# 1946  2021-01-01 04:20:02+00:00           0               GBP
# 1947  2021-01-01 02:32:32+00:00           0               GBP
# 1948  2021-01-01 00:42:01+00:00           0               GBP
#
#                                                     Url  target
# 0     https://twitter.com/yusobays/status/1356004827...     0.0
# 1     https://twitter.com/BtcTurkDestek/status/13555...     0.0
# 2     https://twitter.com/RisingValhalla/status/1355...     0.0
# 3     https://twitter.com/Erda55203615/status/135524...    -1.0
# 4     https://twitter.com/Erda55203615/status/135524...    -1.0
# ...                                                 ...     ...
# 1944  https://twitter.com/flyingstocksman/status/134...     0.0
# 1945  https://twitter.com/alpeshbp/status/1344904575...     0.0
# 1946  https://twitter.com/campsbay_com/status/134486...     0.0
# 1947  https://twitter.com/MajorFXNow/status/13448338...     0.0
# 1948  https://twitter.com/trader_blitz/status/134480...     0.0
#
# [1949 rows x 7 columns]

# %%
def sentiments(df):
    if df['target'] >= 0:
        return 'Positive'
    elif df['target'] < 0:
        return 'Negative'

# %%
df['Sentiment'] = df.apply(sentiments, axis=1)

# %%
df
# Out:
#                Author                                               Text  \
# 0            yusobays  @elonmusk @elonmusk  please Come to TRY₺ #turk...
# 1       BtcTurkDestek  @DrBatal  Hello, if you have registered using ...
# 2      RisingValhalla  “I trade weekly bars. You?”\n\n200 day moving ...
# 3        Erda55203615  @elonmusk Try turkish lira its at the bottom m...
# 4        Erda55203615            @ImTooRealForU TRY FUCKING TURKISH LIRA
# ...               ...                                                ...
# 1944  flyingstocksman  For those of you who missed it last night with...
# 1945         alpeshbp  GBP/USD Weekly Price Forecast – The British Po...
# 1946     campsbay_com  20.0142 ZAR for 1 GBP @ December 31, 2020 at 0...
# 1947       MajorFXNow  GBP/EUR: Pound Lifted by UK Approval of AstraZ...
# 1948     trader_blitz  GBP/JPY | $GBPJPY | $GBP $JPY\n\nBRITISH POUND...
#
#                            Time  Like Count Currency ISO Code  \
# 0     2021-01-31 22:21:58+00:00           1               TRY
# 1     2021-01-30 18:07:15+00:00           0               TRY
# 2     2021-01-30 03:29:59+00:00           0               TRY
# 3     2021-01-29 20:20:49+00:00           0               TRY
# 4     2021-01-29 20:19:36+00:00           0               TRY
# ...                         ...         ...               ...
# 1944  2021-01-01 09:24:17+00:00           0               GBP
# 1945  2021-01-01 07:13:32+00:00           0               GBP
# 1946  2021-01-01 04:20:02+00:00           0               GBP
# 1947  2021-01-01 02:32:32+00:00           0               GBP
# 1948  2021-01-01 00:42:01+00:00           0               GBP
#
#                                                     Url  target Sentiment
# 0     https://twitter.com/yusobays/status/1356004827...     0.0  Positive
# 1     https://twitter.com/BtcTurkDestek/status/13555...     0.0  Positive
# 2     https://twitter.com/RisingValhalla/status/1355...     0.0  Positive
# 3     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# 4     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# ...                                                 ...     ...       ...
# 1944  https://twitter.com/flyingstocksman/status/134...     0.0  Positive
# 1945  https://twitter.com/alpeshbp/status/1344904575...     0.0  Positive
# 1946  https://twitter.com/campsbay_com/status/134486...     0.0  Positive
# 1947  https://twitter.com/MajorFXNow/status/13448338...     0.0  Positive
# 1948  https://twitter.com/trader_blitz/status/134480...     0.0  Positive
#
# [1949 rows x 8 columns]

# %%
data_v1 = df[['Text','Sentiment']]
data_v1.isnull().sum()
# Out:
# Text         0
# Sentiment    0
# dtype: int64

# %%
plt.figure(figsize=(7,8))
plt.title("Number of records of positive and negative sentiments")
plot = sn.countplot(x = 'Sentiment', data = data_v1)
for p in plot.patches:
    plot.annotate(p.get_height(),(p.get_x() + 0.2 ,p.get_height()+80))

# %%
clean = TextCleaner()
text = clean.convert_emoji_to_text("Hilarious 😂. The feeling of making a sale 😎, The feeling of actually fulfilling orders 😒")
print(text)

text4 = "Hello :-) :-)"
resp = clean.convert_emoticons(text4)
print(resp)
# Out:
# Hilarious face with tears of joy. The feeling of making a sale smiling face with sunglasses, The feeling of actually fulfilling orders unamused face
# Hello Happy face smiley Happy face smiley

# %%
df
# Out:
#                Author                                               Text  \
# 0            yusobays  @elonmusk @elonmusk  please Come to TRY₺ #turk...
# 1       BtcTurkDestek  @DrBatal  Hello, if you have registered using ...
# 2      RisingValhalla  “I trade weekly bars. You?”\n\n200 day moving ...
# 3        Erda55203615  @elonmusk Try turkish lira its at the bottom m...
# 4        Erda55203615            @ImTooRealForU TRY FUCKING TURKISH LIRA
# ...               ...                                                ...
# 1944  flyingstocksman  For those of you who missed it last night with...
# 1945         alpeshbp  GBP/USD Weekly Price Forecast – The British Po...
# 1946     campsbay_com  20.0142 ZAR for 1 GBP @ December 31, 2020 at 0...
# 1947       MajorFXNow  GBP/EUR: Pound Lifted by UK Approval of AstraZ...
# 1948     trader_blitz  GBP/JPY | $GBPJPY | $GBP $JPY\n\nBRITISH POUND...
#
#                            Time  Like Count Currency ISO Code  \
# 0     2021-01-31 22:21:58+00:00           1               TRY
# 1     2021-01-30 18:07:15+00:00           0               TRY
# 2     2021-01-30 03:29:59+00:00           0               TRY
# 3     2021-01-29 20:20:49+00:00           0               TRY
# 4     2021-01-29 20:19:36+00:00           0               TRY
# ...                         ...         ...               ...
# 1944  2021-01-01 09:24:17+00:00           0               GBP
# 1945  2021-01-01 07:13:32+00:00           0               GBP
# 1946  2021-01-01 04:20:02+00:00           0               GBP
# 1947  2021-01-01 02:32:32+00:00           0               GBP
# 1948  2021-01-01 00:42:01+00:00           0               GBP
#
#                                                     Url  target Sentiment
# 0     https://twitter.com/yusobays/status/1356004827...     0.0  Positive
# 1     https://twitter.com/BtcTurkDestek/status/13555...     0.0  Positive
# 2     https://twitter.com/RisingValhalla/status/1355...     0.0  Positive
# 3     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# 4     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# ...                                                 ...     ...       ...
# 1944  https://twitter.com/flyingstocksman/status/134...     0.0  Positive
# 1945  https://twitter.com/alpeshbp/status/1344904575...     0.0  Positive
# 1946  https://twitter.com/campsbay_com/status/134486...     0.0  Positive
# 1947  https://twitter.com/MajorFXNow/status/13448338...     0.0  Positive
# 1948  https://twitter.com/trader_blitz/status/134480...     0.0  Positive
#
# [1949 rows x 8 columns]

# %%
def remove_url(text):
    result = re.sub(r'https?:\/\/\S*', '', text, flags=re.MULTILINE)
    return result

def replace_contractions(text):
    return contractions.fix(text)

abbs =  {"eur": "euro", "usd": "dollar", "gbp" : "pound", "u":"you", "tryeur":"turkish lira euro", "try":" turkish lira", "gt":"greater than","lt": "less than","btc":"bitcoin",
        "gbpusd": "pound dollar", "usdtry":"dollar turkish lira", "fx":"forex", "u":"you", "eurusd":"euro usd", "eurgbp":"euro pound", "jpy":"japanese yen","cny":"chinese yuan","uk":"united kingdom"}

def replace_currency(text):
    val = ''
    for i in text.split():
        if abbs.get(i.lower().strip()) is not None:
            #print(abbs.get(i.lower().strip()))
            val = val + str(abbs.get(i.lower().strip())) + ' '
        else:
            val = val + i + ' '
    return val

# %%
print(remove_url(df['Text'].iloc[1942]))
# Out:
# Visit  to check the latest #bitcoin price in #gbp #uk #pound. You can also use our free $GBP to $BTC price converter.

# %%
print(replace_currency("@elonmusk Try turkish lira its at the bottom"))
# Out:
# @elonmusk  turkish lira turkish lira its at the bottom

# %%
clean = TextCleaner()

def cleaning(df_cl, stop_words):
    
    # Removing URLs
    df_cl["Text"] = df_cl["Text"].apply(lambda x: remove_url(x))
    
     # Removing mentioned author names
    df_cl["Text"] = df_cl["Text"].apply(lambda x: re.sub("@[A-Za-z0-9]+","", x))
    
    # Lowercase
    df_cl['Text'] = df_cl['Text'].apply(lambda x: ' '.join(x.lower() for x in x.split()))
    
    df_cl["Text"] = df_cl["Text"].apply(lambda x: replace_contractions(x))
    
    df_cl["Text"] = df_cl["Text"].apply(lambda x: replace_currency(x))
    
     # Remove Non -letters
    df_cl['Text'] = df_cl['Text'].apply(lambda x: re.sub(r"[^a-zA-Z0-9]", ' ', x))
    
    # Removing Punctuation
    df_cl["Text"] = df_cl["Text"].apply(lambda x: re.sub(r'[^\w\s]','', x))
    
    # Removing stop words
    df_cl['Text'] = df_cl['Text'].apply(lambda x:' '.join(x for x in x.split() if x not in stop_words))
    
    # Lemmatization
    df_cl['Text'] = df_cl['Text'].apply(lambda x:' '.join([Word(x).lemmatize() for x in x.split()]))
    
    # Emoticons
    df_cl['Text'] = df_cl['Text'].apply(lambda x: clean.convert_emoji_to_text(x))
    
    # Emojis
    df_cl['Text'] = df_cl['Text'].apply(lambda x: clean.convert_emoji_to_text(x))    
    
    # Stemming
    #df_cl['Text'] = df_cl['Text'].apply(lambda x: port_stemmer(x))
    return df_cl

stop_words = stopwords.words('english')

# %%
data_v1 = cleaning(data_v1, stop_words)

# %%
data_v1
# Out:
#                                                    Text Sentiment
# 0                           please come try turkishlira  Positive
# 1     hello registered using turkish citizenship id ...  Positive
# 2     trade weekly bar 200 day moving average breach...  Positive
# 3       turkish lira turkish lira bottom maybe would go  Negative
# 4                     turkish lira fucking turkish lira  Negative
# ...                                                 ...       ...
# 1944  missed last night nye potentially important tw...  Positive
# 1945  gbp usd weekly price forecast british pound lo...  Positive
# 1946  20 0142 zar 1 pound december 31 2020 06 20am s...  Positive
# 1947  gbp eur pound lifted united kingdom approval a...  Positive
# 1948  gbp jpy gbpjpy gbp jpy british pound brexit br...  Positive
#
# [1949 rows x 2 columns]

# %%
common_words = ''
for i in data_v1.Text:
    i = str(i)
    tokens = i.split()
    common_words += " ".join(tokens)+" "
wordcloud = WordCloud(width=1600, height=800).generate(common_words)
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
lb = LabelEncoder()
data_v1['Sentiment'] = lb.fit_transform(data_v1['Sentiment'])

# %%
tokenizer = Tokenizer(num_words=1000, split=' ', lower=True) 
tokenizer.fit_on_texts(data_v1['Text'].values)
X = tokenizer.texts_to_sequences(df['Text'].values)
X = pad_sequences(X)

# %%
y = pd.get_dummies(data_v1['Sentiment'])

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# <h3>Time Series Methodologies</h3>
# <h4>Defining Models</h4>

# %%
models = [ 'SimpleRNN', 'LSTM', 'GRU']

# %%
METRICS = [ 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      km.binary_precision(), 
      km.binary_recall(),
      'mse', 
      'mae', 
      keras.metrics.AUC(name='auc'),
      tfa.metrics.F1Score(num_classes=2, threshold=0.5, average='macro'),
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn')
]
# Out:
# 2022-03-14 21:53:44.176041: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def build_model(nb_words, _model="SimpleRNN", embedding_matrix=None):
    model = Sequential()
    model.add(Embedding(input_dim=1000, output_dim=64, input_length = nb_words))
    if _model == "SimpleRNN":
        model.add(SimpleRNN(128, dropout=0.1, recurrent_dropout=0.1, activation='relu'))
    elif _model == "LSTM":
        model.add(LSTM(100, return_sequences=True))
        model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.1, activation='relu'))
    elif _model == "GRU":
        model.add(GRU(128))
    model.add(Dense(2, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=[METRICS])
    return model

# %%
print(X.shape)
print(y.shape)
# Out:
# (1949, 38)
# (1949, 2)

# %%
tsa_classifiers = []

# %%
output_df = pd.DataFrame(columns=['model', 'accuracy', 'precision', 'recall', 'mse', 'mae', 'auc', 'f1_score', 'prediction time'])

seed = 5
kfold = KFold(seed, True, 7)
cvscores = []

batch_size = 64

x1=np.array(X)
y1=np.array(y)

for idx, mdl in enumerate(models):
    accuracy = precision = recall = mse = mae = auc = f1_score_val = prediction_time = 0
    
    print("Model : " + str(mdl))
    model_ = build_model(X.shape[1], mdl, None)
    
    keras_model = KerasClassifier(build_fn=model_)
    keras_model._estimator_type = "classifier"    
    tsa_classifiers.append(( str(mdl), keras_model  ))
    
    print("Model Summary")
    print(model_.summary())
    
    for train_index, test_index in kfold.split(x1,y1):
        X_train, X_test, y_train, y_test = x1[train_index], x1[test_index], y1[train_index], y1[test_index]   
        model_.fit(X_train, y_train, epochs=5, validation_split=0.2, batch_size=batch_size, verbose = 'auto', shuffle=False, validation_data=(X_test,y_test))
        
        
        start_time = time.time()
        y_pred = model_.predict(X_test)
        end_time = time.time() - start_time
        print("")

        scores = model_.evaluate(X_test, y_test)
        print("%s: %.2f%%" % (model_.metrics_names[1], scores[1]*100))    
        print("")
        accuracy += scores[1]
        precision += scores[2]
        recall += scores[3]
        mse += scores[4]
        mae += scores[5]
        auc += scores[6]
        f1_score_val += scores[7]
        prediction_time += end_time
        
        #print("")
        #print("Time taken to predict the model " + str(end_time))

    output_df = output_df.append([{'model': str(mdl), 'accuracy':accuracy/seed,'precision':precision/seed
                                       ,'recall':recall/seed,'mse':mse/seed,'mae':mae/seed
                                       ,'auc':auc/seed,'f1_score':f1_score_val/seed, 'prediction time': prediction_time/seed}], ignore_index=True)

    yhat = model_.predict_on_batch(X_test)
    #print("yhat[:,1]",yhat[:,1])
    #print("y_test",y_test)
    fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test[:,1], yhat[:,1])
    plt.rcParams["figure.figsize"] = (10,7)
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr_rf, tpr_rf, label=str(mdl) + ' (area = {:.3f})'.format(auc/seed))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.savefig('tsa_roc_curve.png')

    #print(classification_report(y_test.values.argmax(axis=1), y_pred.argmax(axis=1)))
    print("___________________________________________________________________________________")

    print("")
    print("")
    print("")
    
plt.show()
# Out:
# Model : SimpleRNN
# Model Summary
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 38, 64)            64000
#
#  simple_rnn (SimpleRNN)      (None, 128)               24704
#
#  dense (Dense)               (None, 2)                 258
#
# =================================================================
# Total params: 88,962
# Trainable params: 88,962
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass shuffle=True, random_state=7 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /var/folders/33/v0__8kvs301dg744qmtfs33w0000gn/T/ipykernel_5045/2981902032.py:18: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_model = KerasClassifier(build_fn=model_)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /opt/anaconda3/lib/python3.9/site-packages/keras_metrics/metrics.py:26: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return object.__getattribute__(self, name)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 20/20 [==============================] - ETA: 0s - loss: 0.6961 - accuracy: 0.6568 - precision: 0.0909 - recall: 0.0144 - mse: 0.2489 - mae: 0.4709 - auc: 0.6029 - f1_score: 0.3986 - tp: 819.0000 - fp: 428.0000 - tn: 819.0000 - fn: 428.0000WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 20/20 [==============================] - 3s 45ms/step - loss: 0.6961 - accuracy: 0.6568 - precision: 0.0909 - recall: 0.0144 - mse: 0.2489 - mae: 0.4709 - auc: 0.6029 - f1_score: 0.3986 - tp: 819.0000 - fp: 428.0000 - tn: 819.0000 - fn: 428.0000 - val_loss: 0.6166 - val_accuracy: 0.7212 - val_precision: 0.0909 - val_recall: 0.0021 - val_mse: 0.2123 - val_mae: 0.4494 - val_auc: 0.7333 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 2/5
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6487 - accuracy: 0.6640 - precision: 0.0909 - recall: 0.0015 - mse: 0.2280 - mae: 0.4674 - auc: 0.6465 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.6222 - val_accuracy: 0.7212 - val_precision: 0.0909 - val_recall: 0.0010 - val_mse: 0.2150 - val_mae: 0.4545 - val_auc: 0.7333 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 3/5
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6538 - accuracy: 0.6640 - precision: 0.0909 - recall: 8.5147e-04 - mse: 0.2302 - mae: 0.4630 - auc: 0.6082 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.6056 - val_accuracy: 0.7212 - val_precision: 0.0909 - val_recall: 6.7091e-04 - val_mse: 0.2072 - val_mae: 0.4375 - val_auc: 0.7359 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 4/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6479 - accuracy: 0.6640 - precision: 0.0909 - recall: 5.9373e-04 - mse: 0.2273 - mae: 0.4514 - auc: 0.6232 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.6005 - val_accuracy: 0.7212 - val_precision: 0.0909 - val_recall: 5.0083e-04 - val_mse: 0.2049 - val_mae: 0.4305 - val_auc: 0.7403 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 5/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6449 - accuracy: 0.6640 - precision: 0.0909 - recall: 4.5613e-04 - mse: 0.2260 - mae: 0.4489 - auc: 0.6326 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.6018 - val_accuracy: 0.7212 - val_precision: 0.0909 - val_recall: 3.9955e-04 - val_mse: 0.2055 - val_mae: 0.4322 - val_auc: 0.7325 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
#
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6486 - accuracy: 0.6462 - precision: 0.0909 - recall: 3.8458e-04 - mse: 0.2281 - mae: 0.4551 - auc: 0.6568 - f1_score: 0.3925 - tp: 252.0000 - fp: 138.0000 - tn: 252.0000 - fn: 138.0000
# accuracy: 64.62%
#
# Epoch 1/5
# 20/20 [==============================] - 0s 15ms/step - loss: 0.6524 - accuracy: 0.6447 - precision: 0.0909 - recall: 3.5034e-04 - mse: 0.2298 - mae: 0.4565 - auc: 0.6309 - f1_score: 0.3920 - tp: 804.0000 - fp: 443.0000 - tn: 804.0000 - fn: 443.0000 - val_loss: 0.6269 - val_accuracy: 0.6827 - val_precision: 0.0909 - val_recall: 3.1472e-04 - val_mse: 0.2176 - val_mae: 0.4474 - val_auc: 0.7028 - val_f1_score: 0.4057 - val_tp: 213.0000 - val_fp: 99.0000 - val_tn: 213.0000 - val_fn: 99.0000
# Epoch 2/5
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6536 - accuracy: 0.6447 - precision: 0.0909 - recall: 2.9435e-04 - mse: 0.2303 - mae: 0.4588 - auc: 0.6232 - f1_score: 0.3920 - tp: 804.0000 - fp: 443.0000 - tn: 804.0000 - fn: 443.0000 - val_loss: 0.6271 - val_accuracy: 0.6827 - val_precision: 0.0909 - val_recall: 2.6886e-04 - val_mse: 0.2177 - val_mae: 0.4480 - val_auc: 0.7053 - val_f1_score: 0.4057 - val_tp: 213.0000 - val_fp: 99.0000 - val_tn: 213.0000 - val_fn: 99.0000
# Epoch 3/5
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6529 - accuracy: 0.6447 - precision: 0.0909 - recall: 2.5380e-04 - mse: 0.2300 - mae: 0.4582 - auc: 0.6254 - f1_score: 0.3920 - tp: 804.0000 - fp: 443.0000 - tn: 804.0000 - fn: 443.0000 - val_loss: 0.6270 - val_accuracy: 0.6827 - val_precision: 0.0909 - val_recall: 2.3466e-04 - val_mse: 0.2176 - val_mae: 0.4474 - val_auc: 0.7056 - val_f1_score: 0.4057 - val_tp: 213.0000 - val_fp: 99.0000 - val_tn: 213.0000 - val_fn: 99.0000
# Epoch 4/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6530 - accuracy: 0.6447 - precision: 0.0909 - recall: 2.2309e-04 - mse: 0.2300 - mae: 0.4577 - auc: 0.6231 - f1_score: 0.3920 - tp: 804.0000 - fp: 443.0000 - tn: 804.0000 - fn: 443.0000 - val_loss: 0.6272 - val_accuracy: 0.6763 - val_precision: 0.1120 - val_recall: 2.9089e-04 - val_mse: 0.2177 - val_mae: 0.4474 - val_auc: 0.7029 - val_f1_score: 0.4128 - val_tp: 211.0000 - val_fp: 101.0000 - val_tn: 211.0000 - val_fn: 101.0000
# Epoch 5/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6510 - accuracy: 0.6464 - precision: 0.1787 - recall: 5.6464e-04 - mse: 0.2291 - mae: 0.4570 - auc: 0.6312 - f1_score: 0.3969 - tp: 806.0000 - fp: 441.0000 - tn: 806.0000 - fn: 441.0000 - val_loss: 0.6275 - val_accuracy: 0.6763 - val_precision: 0.2414 - val_recall: 8.2266e-04 - val_mse: 0.2179 - val_mae: 0.4474 - val_auc: 0.7033 - val_f1_score: 0.4128 - val_tp: 211.0000 - val_fp: 101.0000 - val_tn: 211.0000 - val_fn: 101.0000
#
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6027 - accuracy: 0.7308 - precision: 0.2251 - recall: 9.2111e-04 - mse: 0.2058 - mae: 0.4354 - auc: 0.7402 - f1_score: 0.4222 - tp: 285.0000 - fp: 105.0000 - tn: 285.0000 - fn: 105.0000
# accuracy: 73.08%
#
# Epoch 1/5
# 20/20 [==============================] - 0s 15ms/step - loss: 0.6490 - accuracy: 0.6640 - precision: 0.2568 - recall: 0.0012 - mse: 0.2278 - mae: 0.4527 - auc: 0.6205 - f1_score: 0.4058 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5971 - val_accuracy: 0.7244 - val_precision: 0.2708 - val_recall: 0.0014 - val_mse: 0.2033 - val_mae: 0.4290 - val_auc: 0.7503 - val_f1_score: 0.4311 - val_tp: 226.0000 - val_fp: 86.0000 - val_tn: 226.0000 - val_fn: 86.0000
# Epoch 2/5
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6418 - accuracy: 0.6648 - precision: 0.2951 - recall: 0.0017 - mse: 0.2246 - mae: 0.4496 - auc: 0.6414 - f1_score: 0.4039 - tp: 829.0000 - fp: 418.0000 - tn: 829.0000 - fn: 418.0000 - val_loss: 0.5984 - val_accuracy: 0.7276 - val_precision: 0.3056 - val_recall: 0.0017 - val_mse: 0.2038 - val_mae: 0.4304 - val_auc: 0.7496 - val_f1_score: 0.4212 - val_tp: 227.0000 - val_fp: 85.0000 - val_tn: 227.0000 - val_fn: 85.0000
# Epoch 3/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6422 - accuracy: 0.6640 - precision: 0.3056 - recall: 0.0017 - mse: 0.2248 - mae: 0.4500 - auc: 0.6418 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5983 - val_accuracy: 0.7276 - val_precision: 0.3056 - val_recall: 0.0016 - val_mse: 0.2038 - val_mae: 0.4302 - val_auc: 0.7467 - val_f1_score: 0.4212 - val_tp: 227.0000 - val_fp: 85.0000 - val_tn: 227.0000 - val_fn: 85.0000
# Epoch 4/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6418 - accuracy: 0.6648 - precision: 0.3187 - recall: 0.0016 - mse: 0.2246 - mae: 0.4495 - auc: 0.6378 - f1_score: 0.4016 - tp: 829.0000 - fp: 418.0000 - tn: 829.0000 - fn: 418.0000 - val_loss: 0.5979 - val_accuracy: 0.7276 - val_precision: 0.3243 - val_recall: 0.0016 - val_mse: 0.2036 - val_mae: 0.4295 - val_auc: 0.7422 - val_f1_score: 0.4212 - val_tp: 227.0000 - val_fp: 85.0000 - val_tn: 227.0000 - val_fn: 85.0000
# Epoch 5/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6418 - accuracy: 0.6656 - precision: 0.3539 - recall: 0.0018 - mse: 0.2245 - mae: 0.4490 - auc: 0.6359 - f1_score: 0.4042 - tp: 830.0000 - fp: 417.0000 - tn: 830.0000 - fn: 417.0000 - val_loss: 0.5982 - val_accuracy: 0.7276 - val_precision: 0.3590 - val_recall: 0.0018 - val_mse: 0.2037 - val_mae: 0.4298 - val_auc: 0.7372 - val_f1_score: 0.4212 - val_tp: 227.0000 - val_fp: 85.0000 - val_tn: 227.0000 - val_fn: 85.0000
#
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6452 - accuracy: 0.6462 - precision: 0.3902 - recall: 0.0020 - mse: 0.2266 - mae: 0.4526 - auc: 0.6783 - f1_score: 0.4059 - tp: 252.0000 - fp: 138.0000 - tn: 252.0000 - fn: 138.0000
# accuracy: 64.62%
#
# Epoch 1/5
# 20/20 [==============================] - 0s 15ms/step - loss: 0.6430 - accuracy: 0.6576 - precision: 0.4289 - recall: 0.0023 - mse: 0.2253 - mae: 0.4514 - auc: 0.6519 - f1_score: 0.4033 - tp: 820.0000 - fp: 427.0000 - tn: 820.0000 - fn: 427.0000 - val_loss: 0.6061 - val_accuracy: 0.7212 - val_precision: 0.4222 - val_recall: 0.0022 - val_mse: 0.2074 - val_mae: 0.4359 - val_auc: 0.7172 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 2/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6444 - accuracy: 0.6624 - precision: 0.5056 - recall: 0.0030 - mse: 0.2258 - mae: 0.4519 - auc: 0.6454 - f1_score: 0.4160 - tp: 826.0000 - fp: 421.0000 - tn: 826.0000 - fn: 421.0000 - val_loss: 0.6047 - val_accuracy: 0.7212 - val_precision: 0.5094 - val_recall: 0.0030 - val_mse: 0.2068 - val_mae: 0.4336 - val_auc: 0.7183 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 3/5
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6434 - accuracy: 0.6584 - precision: 0.5365 - recall: 0.0033 - mse: 0.2254 - mae: 0.4494 - auc: 0.6525 - f1_score: 0.4080 - tp: 821.0000 - fp: 426.0000 - tn: 821.0000 - fn: 426.0000 - val_loss: 0.6038 - val_accuracy: 0.7212 - val_precision: 0.5333 - val_recall: 0.0033 - val_mse: 0.2064 - val_mae: 0.4324 - val_auc: 0.7222 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 4/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6412 - accuracy: 0.6600 - precision: 0.5725 - recall: 0.0041 - mse: 0.2243 - mae: 0.4475 - auc: 0.6668 - f1_score: 0.4211 - tp: 823.0000 - fp: 424.0000 - tn: 823.0000 - fn: 424.0000 - val_loss: 0.6025 - val_accuracy: 0.7212 - val_precision: 0.5584 - val_recall: 0.0042 - val_mse: 0.2058 - val_mae: 0.4301 - val_auc: 0.7243 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 5/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6391 - accuracy: 0.6616 - precision: 0.5960 - recall: 0.0049 - mse: 0.2234 - mae: 0.4454 - auc: 0.6686 - f1_score: 0.4156 - tp: 825.0000 - fp: 422.0000 - tn: 825.0000 - fn: 422.0000 - val_loss: 0.6047 - val_accuracy: 0.7179 - val_precision: 0.5862 - val_recall: 0.0048 - val_mse: 0.2068 - val_mae: 0.4314 - val_auc: 0.7209 - val_f1_score: 0.4179 - val_tp: 224.0000 - val_fp: 88.0000 - val_tn: 224.0000 - val_fn: 88.0000
#
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6272 - accuracy: 0.6744 - precision: 0.5909 - recall: 0.0048 - mse: 0.2179 - mae: 0.4423 - auc: 0.6978 - f1_score: 0.4102 - tp: 263.0000 - fp: 127.0000 - tn: 263.0000 - fn: 127.0000
# accuracy: 67.44%
#
# Epoch 1/5
# 20/20 [==============================] - 0s 15ms/step - loss: 0.6340 - accuracy: 0.6715 - precision: 0.6060 - recall: 0.0054 - mse: 0.2209 - mae: 0.4418 - auc: 0.6764 - f1_score: 0.4197 - tp: 838.0000 - fp: 410.0000 - tn: 838.0000 - fn: 410.0000 - val_loss: 0.6203 - val_accuracy: 0.6955 - val_precision: 0.5941 - val_recall: 0.0053 - val_mse: 0.2143 - val_mae: 0.4368 - val_auc: 0.7008 - val_f1_score: 0.4102 - val_tp: 217.0000 - val_fp: 95.0000 - val_tn: 217.0000 - val_fn: 95.0000
# Epoch 2/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6316 - accuracy: 0.6723 - precision: 0.6043 - recall: 0.0059 - mse: 0.2198 - mae: 0.4388 - auc: 0.6770 - f1_score: 0.4244 - tp: 839.0000 - fp: 409.0000 - tn: 839.0000 - fn: 409.0000 - val_loss: 0.6212 - val_accuracy: 0.6955 - val_precision: 0.5983 - val_recall: 0.0059 - val_mse: 0.2146 - val_mae: 0.4355 - val_auc: 0.6989 - val_f1_score: 0.4102 - val_tp: 217.0000 - val_fp: 95.0000 - val_tn: 217.0000 - val_fn: 95.0000
# Epoch 3/5
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6312 - accuracy: 0.6731 - precision: 0.6136 - recall: 0.0065 - mse: 0.2196 - mae: 0.4376 - auc: 0.6808 - f1_score: 0.4247 - tp: 840.0000 - fp: 408.0000 - tn: 840.0000 - fn: 408.0000 - val_loss: 0.6211 - val_accuracy: 0.7019 - val_precision: 0.6130 - val_recall: 0.0065 - val_mse: 0.2144 - val_mae: 0.4349 - val_auc: 0.7002 - val_f1_score: 0.4226 - val_tp: 219.0000 - val_fp: 93.0000 - val_tn: 219.0000 - val_fn: 93.0000
# Epoch 4/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6278 - accuracy: 0.6731 - precision: 0.6217 - recall: 0.0071 - mse: 0.2181 - mae: 0.4360 - auc: 0.6847 - f1_score: 0.4268 - tp: 840.0000 - fp: 408.0000 - tn: 840.0000 - fn: 408.0000 - val_loss: 0.6241 - val_accuracy: 0.7019 - val_precision: 0.6205 - val_recall: 0.0073 - val_mse: 0.2157 - val_mae: 0.4368 - val_auc: 0.6996 - val_f1_score: 0.4324 - val_tp: 219.0000 - val_fp: 93.0000 - val_tn: 219.0000 - val_fn: 93.0000
# Epoch 5/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6262 - accuracy: 0.6731 - precision: 0.6257 - recall: 0.0081 - mse: 0.2175 - mae: 0.4350 - auc: 0.6893 - f1_score: 0.4351 - tp: 840.0000 - fp: 408.0000 - tn: 840.0000 - fn: 408.0000 - val_loss: 0.6242 - val_accuracy: 0.6987 - val_precision: 0.6210 - val_recall: 0.0082 - val_mse: 0.2156 - val_mae: 0.4354 - val_auc: 0.6983 - val_f1_score: 0.4214 - val_tp: 218.0000 - val_fp: 94.0000 - val_tn: 218.0000 - val_fn: 94.0000
#
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6315 - accuracy: 0.6607 - precision: 0.6271 - recall: 0.0084 - mse: 0.2201 - mae: 0.4392 - auc: 0.6970 - f1_score: 0.4251 - tp: 257.0000 - fp: 132.0000 - tn: 257.0000 - fn: 132.0000
# accuracy: 66.07%
#
# ___________________________________________________________________________________
#
#
#
# Model : LSTM
# Model Summary
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 38, 64)            64000
#
#  lstm (LSTM)                 (None, 38, 100)           66000
#
#  lstm_1 (LSTM)               (None, 128)               117248
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 247,506
# Trainable params: 247,506
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# /var/folders/33/v0__8kvs301dg744qmtfs33w0000gn/T/ipykernel_5045/2981902032.py:18: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_model = KerasClassifier(build_fn=model_)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /opt/anaconda3/lib/python3.9/site-packages/keras_metrics/metrics.py:26: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return object.__getattribute__(self, name)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 20/20 [==============================] - ETA: 0s - loss: 0.6994 - accuracy: 0.6632 - precision: 0.6298 - recall: 0.0083 - mse: 0.2507 - mae: 0.4739 - auc: 0.6208 - f1_score: 0.4056 - tp: 1085.0000 - fp: 551.0000 - tn: 1085.0000 - fn: 551.0000WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 20/20 [==============================] - 6s 134ms/step - loss: 0.6994 - accuracy: 0.6632 - precision: 0.6298 - recall: 0.0083 - mse: 0.2507 - mae: 0.4739 - auc: 0.6208 - f1_score: 0.4056 - tp: 1085.0000 - fp: 551.0000 - tn: 1085.0000 - fn: 551.0000 - val_loss: 0.6232 - val_accuracy: 0.7212 - val_precision: 0.6298 - val_recall: 0.0081 - val_mse: 0.2154 - val_mae: 0.4552 - val_auc: 0.7187 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 2/5
# 20/20 [==============================] - 2s 102ms/step - loss: 0.6543 - accuracy: 0.6640 - precision: 0.6298 - recall: 0.0080 - mse: 0.2307 - mae: 0.4743 - auc: 0.6437 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.6342 - val_accuracy: 0.7212 - val_precision: 0.6298 - val_recall: 0.0079 - val_mse: 0.2208 - val_mae: 0.4642 - val_auc: 0.7331 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 3/5
# 20/20 [==============================] - 2s 93ms/step - loss: 0.6612 - accuracy: 0.6640 - precision: 0.6298 - recall: 0.0077 - mse: 0.2339 - mae: 0.4702 - auc: 0.5843 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.6105 - val_accuracy: 0.7212 - val_precision: 0.6298 - val_recall: 0.0076 - val_mse: 0.2094 - val_mae: 0.4426 - val_auc: 0.7271 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 4/5
# 20/20 [==============================] - 2s 102ms/step - loss: 0.6549 - accuracy: 0.6640 - precision: 0.6298 - recall: 0.0075 - mse: 0.2305 - mae: 0.4554 - auc: 0.5906 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.6048 - val_accuracy: 0.7212 - val_precision: 0.6298 - val_recall: 0.0073 - val_mse: 0.2068 - val_mae: 0.4358 - val_auc: 0.7263 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 5/5
# 20/20 [==============================] - 2s 109ms/step - loss: 0.6462 - accuracy: 0.6640 - precision: 0.6298 - recall: 0.0073 - mse: 0.2267 - mae: 0.4550 - auc: 0.6041 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.6065 - val_accuracy: 0.7212 - val_precision: 0.6298 - val_recall: 0.0071 - val_mse: 0.2076 - val_mae: 0.4379 - val_auc: 0.7245 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
#
# 13/13 [==============================] - 0s 18ms/step - loss: 0.6490 - accuracy: 0.6462 - precision: 0.6298 - recall: 0.0071 - mse: 0.2282 - mae: 0.4587 - auc: 0.6553 - f1_score: 0.3925 - tp: 252.0000 - fp: 138.0000 - tn: 252.0000 - fn: 138.0000
# accuracy: 64.62%
#
# Epoch 1/5
# 20/20 [==============================] - 2s 121ms/step - loss: 0.6570 - accuracy: 0.6447 - precision: 0.6298 - recall: 0.0070 - mse: 0.2319 - mae: 0.4604 - auc: 0.5921 - f1_score: 0.3920 - tp: 804.0000 - fp: 443.0000 - tn: 804.0000 - fn: 443.0000 - val_loss: 0.6294 - val_accuracy: 0.6827 - val_precision: 0.6298 - val_recall: 0.0068 - val_mse: 0.2187 - val_mae: 0.4502 - val_auc: 0.6781 - val_f1_score: 0.4057 - val_tp: 213.0000 - val_fp: 99.0000 - val_tn: 213.0000 - val_fn: 99.0000
# Epoch 2/5
# 20/20 [==============================] - 2s 124ms/step - loss: 0.6562 - accuracy: 0.6447 - precision: 0.6298 - recall: 0.0067 - mse: 0.2316 - mae: 0.4617 - auc: 0.5988 - f1_score: 0.3920 - tp: 804.0000 - fp: 443.0000 - tn: 804.0000 - fn: 443.0000 - val_loss: 0.6299 - val_accuracy: 0.6827 - val_precision: 0.6298 - val_recall: 0.0066 - val_mse: 0.2189 - val_mae: 0.4511 - val_auc: 0.6882 - val_f1_score: 0.4057 - val_tp: 213.0000 - val_fp: 99.0000 - val_tn: 213.0000 - val_fn: 99.0000
# Epoch 3/5
# 20/20 [==============================] - 2s 124ms/step - loss: 0.6564 - accuracy: 0.6447 - precision: 0.6298 - recall: 0.0065 - mse: 0.2317 - mae: 0.4617 - auc: 0.5971 - f1_score: 0.3920 - tp: 804.0000 - fp: 443.0000 - tn: 804.0000 - fn: 443.0000 - val_loss: 0.6296 - val_accuracy: 0.6827 - val_precision: 0.6298 - val_recall: 0.0064 - val_mse: 0.2188 - val_mae: 0.4506 - val_auc: 0.6886 - val_f1_score: 0.4057 - val_tp: 213.0000 - val_fp: 99.0000 - val_tn: 213.0000 - val_fn: 99.0000
# Epoch 4/5
# 20/20 [==============================] - 2s 109ms/step - loss: 0.6562 - accuracy: 0.6447 - precision: 0.6298 - recall: 0.0063 - mse: 0.2316 - mae: 0.4612 - auc: 0.6020 - f1_score: 0.3920 - tp: 804.0000 - fp: 443.0000 - tn: 804.0000 - fn: 443.0000 - val_loss: 0.6294 - val_accuracy: 0.6827 - val_precision: 0.6298 - val_recall: 0.0062 - val_mse: 0.2187 - val_mae: 0.4502 - val_auc: 0.6862 - val_f1_score: 0.4057 - val_tp: 213.0000 - val_fp: 99.0000 - val_tn: 213.0000 - val_fn: 99.0000
# Epoch 5/5
# 20/20 [==============================] - 2s 88ms/step - loss: 0.6557 - accuracy: 0.6447 - precision: 0.6298 - recall: 0.0061 - mse: 0.2313 - mae: 0.4609 - auc: 0.6047 - f1_score: 0.3920 - tp: 804.0000 - fp: 443.0000 - tn: 804.0000 - fn: 443.0000 - val_loss: 0.6294 - val_accuracy: 0.6827 - val_precision: 0.6298 - val_recall: 0.0060 - val_mse: 0.2187 - val_mae: 0.4501 - val_auc: 0.6863 - val_f1_score: 0.4057 - val_tp: 213.0000 - val_fp: 99.0000 - val_tn: 213.0000 - val_fn: 99.0000
#
# 13/13 [==============================] - 0s 20ms/step - loss: 0.5975 - accuracy: 0.7385 - precision: 0.6298 - recall: 0.0060 - mse: 0.2032 - mae: 0.4346 - auc: 0.7655 - f1_score: 0.4248 - tp: 288.0000 - fp: 102.0000 - tn: 288.0000 - fn: 102.0000
# accuracy: 73.85%
#
# Epoch 1/5
# 20/20 [==============================] - 2s 105ms/step - loss: 0.6495 - accuracy: 0.6640 - precision: 0.6298 - recall: 0.0059 - mse: 0.2281 - mae: 0.4548 - auc: 0.6045 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5973 - val_accuracy: 0.7276 - val_precision: 0.6298 - val_recall: 0.0059 - val_mse: 0.2033 - val_mae: 0.4302 - val_auc: 0.7410 - val_f1_score: 0.4212 - val_tp: 227.0000 - val_fp: 85.0000 - val_tn: 227.0000 - val_fn: 85.0000
# Epoch 2/5
# 20/20 [==============================] - 2s 124ms/step - loss: 0.6453 - accuracy: 0.6640 - precision: 0.6298 - recall: 0.0058 - mse: 0.2262 - mae: 0.4523 - auc: 0.6201 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5983 - val_accuracy: 0.7276 - val_precision: 0.6298 - val_recall: 0.0057 - val_mse: 0.2037 - val_mae: 0.4315 - val_auc: 0.7440 - val_f1_score: 0.4212 - val_tp: 227.0000 - val_fp: 85.0000 - val_tn: 227.0000 - val_fn: 85.0000
# Epoch 3/5
# 20/20 [==============================] - 3s 125ms/step - loss: 0.6454 - accuracy: 0.6640 - precision: 0.6298 - recall: 0.0056 - mse: 0.2263 - mae: 0.4531 - auc: 0.6193 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5985 - val_accuracy: 0.7276 - val_precision: 0.6298 - val_recall: 0.0056 - val_mse: 0.2038 - val_mae: 0.4318 - val_auc: 0.7442 - val_f1_score: 0.4212 - val_tp: 227.0000 - val_fp: 85.0000 - val_tn: 227.0000 - val_fn: 85.0000
# Epoch 4/5
# 20/20 [==============================] - 2s 123ms/step - loss: 0.6453 - accuracy: 0.6640 - precision: 0.6298 - recall: 0.0055 - mse: 0.2262 - mae: 0.4528 - auc: 0.6204 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5980 - val_accuracy: 0.7276 - val_precision: 0.6298 - val_recall: 0.0054 - val_mse: 0.2036 - val_mae: 0.4312 - val_auc: 0.7468 - val_f1_score: 0.4212 - val_tp: 227.0000 - val_fp: 85.0000 - val_tn: 227.0000 - val_fn: 85.0000
# Epoch 5/5
# 20/20 [==============================] - 3s 131ms/step - loss: 0.6449 - accuracy: 0.6640 - precision: 0.6298 - recall: 0.0054 - mse: 0.2261 - mae: 0.4522 - auc: 0.6241 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5977 - val_accuracy: 0.7276 - val_precision: 0.6298 - val_recall: 0.0053 - val_mse: 0.2035 - val_mae: 0.4308 - val_auc: 0.7467 - val_f1_score: 0.4212 - val_tp: 227.0000 - val_fp: 85.0000 - val_tn: 227.0000 - val_fn: 85.0000
#
# 13/13 [==============================] - 0s 28ms/step - loss: 0.6510 - accuracy: 0.6410 - precision: 0.6298 - recall: 0.0053 - mse: 0.2293 - mae: 0.4566 - auc: 0.6626 - f1_score: 0.3906 - tp: 250.0000 - fp: 140.0000 - tn: 250.0000 - fn: 140.0000
# accuracy: 64.10%
#
# Epoch 1/5
# 20/20 [==============================] - 3s 140ms/step - loss: 0.6467 - accuracy: 0.6560 - precision: 0.6298 - recall: 0.0052 - mse: 0.2270 - mae: 0.4548 - auc: 0.6369 - f1_score: 0.3961 - tp: 818.0000 - fp: 429.0000 - tn: 818.0000 - fn: 429.0000 - val_loss: 0.6049 - val_accuracy: 0.7212 - val_precision: 0.6298 - val_recall: 0.0051 - val_mse: 0.2068 - val_mae: 0.4364 - val_auc: 0.7306 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 2/5
# 20/20 [==============================] - 3s 125ms/step - loss: 0.6487 - accuracy: 0.6560 - precision: 0.6298 - recall: 0.0051 - mse: 0.2279 - mae: 0.4547 - auc: 0.6260 - f1_score: 0.3961 - tp: 818.0000 - fp: 429.0000 - tn: 818.0000 - fn: 429.0000 - val_loss: 0.6026 - val_accuracy: 0.7212 - val_precision: 0.6298 - val_recall: 0.0050 - val_mse: 0.2058 - val_mae: 0.4335 - val_auc: 0.7283 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 3/5
# 20/20 [==============================] - 2s 95ms/step - loss: 0.6482 - accuracy: 0.6560 - precision: 0.6298 - recall: 0.0050 - mse: 0.2277 - mae: 0.4528 - auc: 0.6309 - f1_score: 0.3961 - tp: 818.0000 - fp: 429.0000 - tn: 818.0000 - fn: 429.0000 - val_loss: 0.6019 - val_accuracy: 0.7212 - val_precision: 0.6298 - val_recall: 0.0049 - val_mse: 0.2055 - val_mae: 0.4325 - val_auc: 0.7305 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 4/5
# 20/20 [==============================] - 2s 94ms/step - loss: 0.6476 - accuracy: 0.6560 - precision: 0.6298 - recall: 0.0049 - mse: 0.2274 - mae: 0.4526 - auc: 0.6337 - f1_score: 0.3961 - tp: 818.0000 - fp: 429.0000 - tn: 818.0000 - fn: 429.0000 - val_loss: 0.6022 - val_accuracy: 0.7212 - val_precision: 0.6298 - val_recall: 0.0048 - val_mse: 0.2056 - val_mae: 0.4328 - val_auc: 0.7299 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 5/5
# 20/20 [==============================] - 2s 107ms/step - loss: 0.6474 - accuracy: 0.6560 - precision: 0.6298 - recall: 0.0048 - mse: 0.2273 - mae: 0.4526 - auc: 0.6369 - f1_score: 0.3961 - tp: 818.0000 - fp: 429.0000 - tn: 818.0000 - fn: 429.0000 - val_loss: 0.6020 - val_accuracy: 0.7212 - val_precision: 0.6298 - val_recall: 0.0047 - val_mse: 0.2056 - val_mae: 0.4326 - val_auc: 0.7299 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
#
# 13/13 [==============================] - 0s 32ms/step - loss: 0.6331 - accuracy: 0.6718 - precision: 0.6298 - recall: 0.0047 - mse: 0.2206 - mae: 0.4481 - auc: 0.6805 - f1_score: 0.4018 - tp: 262.0000 - fp: 128.0000 - tn: 262.0000 - fn: 128.0000
# accuracy: 67.18%
#
# Epoch 1/5
# 20/20 [==============================] - 2s 124ms/step - loss: 0.6428 - accuracy: 0.6683 - precision: 0.6298 - recall: 0.0046 - mse: 0.2249 - mae: 0.4488 - auc: 0.6350 - f1_score: 0.4006 - tp: 834.0000 - fp: 414.0000 - tn: 834.0000 - fn: 414.0000 - val_loss: 0.6164 - val_accuracy: 0.6987 - val_precision: 0.6298 - val_recall: 0.0046 - val_mse: 0.2125 - val_mae: 0.4372 - val_auc: 0.7072 - val_f1_score: 0.4113 - val_tp: 218.0000 - val_fp: 94.0000 - val_tn: 218.0000 - val_fn: 94.0000
# Epoch 2/5
# 20/20 [==============================] - 3s 136ms/step - loss: 0.6416 - accuracy: 0.6683 - precision: 0.6298 - recall: 0.0046 - mse: 0.2244 - mae: 0.4465 - auc: 0.6392 - f1_score: 0.4006 - tp: 834.0000 - fp: 414.0000 - tn: 834.0000 - fn: 414.0000 - val_loss: 0.6161 - val_accuracy: 0.6987 - val_precision: 0.6298 - val_recall: 0.0045 - val_mse: 0.2124 - val_mae: 0.4364 - val_auc: 0.7033 - val_f1_score: 0.4113 - val_tp: 218.0000 - val_fp: 94.0000 - val_tn: 218.0000 - val_fn: 94.0000
# Epoch 3/5
# 20/20 [==============================] - 2s 123ms/step - loss: 0.6408 - accuracy: 0.6683 - precision: 0.6298 - recall: 0.0045 - mse: 0.2240 - mae: 0.4463 - auc: 0.6411 - f1_score: 0.4006 - tp: 834.0000 - fp: 414.0000 - tn: 834.0000 - fn: 414.0000 - val_loss: 0.6162 - val_accuracy: 0.6987 - val_precision: 0.6298 - val_recall: 0.0044 - val_mse: 0.2124 - val_mae: 0.4365 - val_auc: 0.7057 - val_f1_score: 0.4113 - val_tp: 218.0000 - val_fp: 94.0000 - val_tn: 218.0000 - val_fn: 94.0000
# Epoch 4/5
# 20/20 [==============================] - 3s 134ms/step - loss: 0.6404 - accuracy: 0.6683 - precision: 0.6298 - recall: 0.0044 - mse: 0.2239 - mae: 0.4459 - auc: 0.6442 - f1_score: 0.4006 - tp: 834.0000 - fp: 414.0000 - tn: 834.0000 - fn: 414.0000 - val_loss: 0.6161 - val_accuracy: 0.6987 - val_precision: 0.6298 - val_recall: 0.0043 - val_mse: 0.2124 - val_mae: 0.4361 - val_auc: 0.7043 - val_f1_score: 0.4113 - val_tp: 218.0000 - val_fp: 94.0000 - val_tn: 218.0000 - val_fn: 94.0000
# Epoch 5/5
# 20/20 [==============================] - 3s 150ms/step - loss: 0.6405 - accuracy: 0.6683 - precision: 0.6298 - recall: 0.0043 - mse: 0.2239 - mae: 0.4457 - auc: 0.6434 - f1_score: 0.4006 - tp: 834.0000 - fp: 414.0000 - tn: 834.0000 - fn: 414.0000 - val_loss: 0.6161 - val_accuracy: 0.6987 - val_precision: 0.6298 - val_recall: 0.0042 - val_mse: 0.2124 - val_mae: 0.4360 - val_auc: 0.7041 - val_f1_score: 0.4113 - val_tp: 218.0000 - val_fp: 94.0000 - val_tn: 218.0000 - val_fn: 94.0000
#
# 13/13 [==============================] - 0s 22ms/step - loss: 0.6423 - accuracy: 0.6504 - precision: 0.6298 - recall: 0.0042 - mse: 0.2251 - mae: 0.4488 - auc: 0.6830 - f1_score: 0.3941 - tp: 253.0000 - fp: 136.0000 - tn: 253.0000 - fn: 136.0000
# accuracy: 65.04%
#
# ___________________________________________________________________________________
#
#
#
# Model : GRU
# Model Summary
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 38, 64)            64000
#
#  gru (GRU)                   (None, 128)               74496
#
#  dense_2 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 138,754
# Trainable params: 138,754
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# /var/folders/33/v0__8kvs301dg744qmtfs33w0000gn/T/ipykernel_5045/2981902032.py:18: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_model = KerasClassifier(build_fn=model_)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /opt/anaconda3/lib/python3.9/site-packages/keras_metrics/metrics.py:26: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return object.__getattribute__(self, name)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 20/20 [==============================] - ETA: 0s - loss: 0.6914 - accuracy: 0.6614 - precision: 0.6235 - recall: 0.0044 - mse: 0.2475 - mae: 0.4739 - auc: 0.5988 - f1_score: 0.4099 - tp: 1082.0000 - fp: 554.0000 - tn: 1082.0000 - fn: 554.0000WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 20/20 [==============================] - 4s 84ms/step - loss: 0.6914 - accuracy: 0.6614 - precision: 0.6235 - recall: 0.0044 - mse: 0.2475 - mae: 0.4739 - auc: 0.5988 - f1_score: 0.4099 - tp: 1082.0000 - fp: 554.0000 - tn: 1082.0000 - fn: 554.0000 - val_loss: 0.5986 - val_accuracy: 0.7212 - val_precision: 0.6237 - val_recall: 0.0044 - val_mse: 0.2040 - val_mae: 0.4277 - val_auc: 0.7412 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 2/5
# 20/20 [==============================] - 1s 50ms/step - loss: 0.6431 - accuracy: 0.6640 - precision: 0.6237 - recall: 0.0044 - mse: 0.2252 - mae: 0.4501 - auc: 0.6338 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.6026 - val_accuracy: 0.7212 - val_precision: 0.6237 - val_recall: 0.0043 - val_mse: 0.2058 - val_mae: 0.4337 - val_auc: 0.7331 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 3/5
# 20/20 [==============================] - 1s 56ms/step - loss: 0.6465 - accuracy: 0.6640 - precision: 0.6237 - recall: 0.0043 - mse: 0.2267 - mae: 0.4508 - auc: 0.6210 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.6003 - val_accuracy: 0.7212 - val_precision: 0.6237 - val_recall: 0.0042 - val_mse: 0.2048 - val_mae: 0.4304 - val_auc: 0.7411 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 4/5
# 20/20 [==============================] - 1s 55ms/step - loss: 0.6454 - accuracy: 0.6640 - precision: 0.6237 - recall: 0.0042 - mse: 0.2262 - mae: 0.4486 - auc: 0.6246 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5997 - val_accuracy: 0.7212 - val_precision: 0.6237 - val_recall: 0.0042 - val_mse: 0.2045 - val_mae: 0.4294 - val_auc: 0.7371 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 5/5
# 20/20 [==============================] - 1s 59ms/step - loss: 0.6445 - accuracy: 0.6640 - precision: 0.6237 - recall: 0.0041 - mse: 0.2258 - mae: 0.4482 - auc: 0.6297 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5998 - val_accuracy: 0.7212 - val_precision: 0.6237 - val_recall: 0.0041 - val_mse: 0.2045 - val_mae: 0.4295 - val_auc: 0.7368 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
#
# 13/13 [==============================] - 0s 9ms/step - loss: 0.6486 - accuracy: 0.6462 - precision: 0.6237 - recall: 0.0041 - mse: 0.2281 - mae: 0.4533 - auc: 0.6590 - f1_score: 0.3925 - tp: 252.0000 - fp: 138.0000 - tn: 252.0000 - fn: 138.0000
# accuracy: 64.62%
#
# Epoch 1/5
# 20/20 [==============================] - 1s 52ms/step - loss: 0.6530 - accuracy: 0.6447 - precision: 0.6237 - recall: 0.0040 - mse: 0.2300 - mae: 0.4549 - auc: 0.6283 - f1_score: 0.3920 - tp: 804.0000 - fp: 443.0000 - tn: 804.0000 - fn: 443.0000 - val_loss: 0.6254 - val_accuracy: 0.6827 - val_precision: 0.6237 - val_recall: 0.0040 - val_mse: 0.2169 - val_mae: 0.4451 - val_auc: 0.7069 - val_f1_score: 0.4057 - val_tp: 213.0000 - val_fp: 99.0000 - val_tn: 213.0000 - val_fn: 99.0000
# Epoch 2/5
# 20/20 [==============================] - 1s 49ms/step - loss: 0.6533 - accuracy: 0.6447 - precision: 0.6237 - recall: 0.0040 - mse: 0.2302 - mae: 0.4576 - auc: 0.6224 - f1_score: 0.3920 - tp: 804.0000 - fp: 443.0000 - tn: 804.0000 - fn: 443.0000 - val_loss: 0.6259 - val_accuracy: 0.6827 - val_precision: 0.6237 - val_recall: 0.0039 - val_mse: 0.2171 - val_mae: 0.4464 - val_auc: 0.7045 - val_f1_score: 0.4057 - val_tp: 213.0000 - val_fp: 99.0000 - val_tn: 213.0000 - val_fn: 99.0000
# Epoch 3/5
# 20/20 [==============================] - 1s 53ms/step - loss: 0.6538 - accuracy: 0.6447 - precision: 0.6237 - recall: 0.0039 - mse: 0.2304 - mae: 0.4581 - auc: 0.6222 - f1_score: 0.3920 - tp: 804.0000 - fp: 443.0000 - tn: 804.0000 - fn: 443.0000 - val_loss: 0.6255 - val_accuracy: 0.6827 - val_precision: 0.6237 - val_recall: 0.0039 - val_mse: 0.2169 - val_mae: 0.4459 - val_auc: 0.7074 - val_f1_score: 0.4057 - val_tp: 213.0000 - val_fp: 99.0000 - val_tn: 213.0000 - val_fn: 99.0000
# Epoch 4/5
# 20/20 [==============================] - 1s 50ms/step - loss: 0.6536 - accuracy: 0.6447 - precision: 0.6237 - recall: 0.0038 - mse: 0.2303 - mae: 0.4576 - auc: 0.6227 - f1_score: 0.3920 - tp: 804.0000 - fp: 443.0000 - tn: 804.0000 - fn: 443.0000 - val_loss: 0.6252 - val_accuracy: 0.6827 - val_precision: 0.6237 - val_recall: 0.0038 - val_mse: 0.2168 - val_mae: 0.4455 - val_auc: 0.7041 - val_f1_score: 0.4057 - val_tp: 213.0000 - val_fp: 99.0000 - val_tn: 213.0000 - val_fn: 99.0000
# Epoch 5/5
# 20/20 [==============================] - 1s 52ms/step - loss: 0.6533 - accuracy: 0.6472 - precision: 0.6264 - recall: 0.0038 - mse: 0.2301 - mae: 0.4573 - auc: 0.6234 - f1_score: 0.3993 - tp: 807.0000 - fp: 440.0000 - tn: 807.0000 - fn: 440.0000 - val_loss: 0.6250 - val_accuracy: 0.6763 - val_precision: 0.6277 - val_recall: 0.0038 - val_mse: 0.2167 - val_mae: 0.4453 - val_auc: 0.7047 - val_f1_score: 0.4128 - val_tp: 211.0000 - val_fp: 101.0000 - val_tn: 211.0000 - val_fn: 101.0000
#
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5992 - accuracy: 0.7308 - precision: 0.6179 - recall: 0.0038 - mse: 0.2041 - mae: 0.4329 - auc: 0.7476 - f1_score: 0.4222 - tp: 285.0000 - fp: 105.0000 - tn: 285.0000 - fn: 105.0000
# accuracy: 73.08%
#
# Epoch 1/5
# 20/20 [==============================] - 1s 51ms/step - loss: 0.6474 - accuracy: 0.6624 - precision: 0.6106 - recall: 0.0038 - mse: 0.2271 - mae: 0.4521 - auc: 0.6252 - f1_score: 0.4007 - tp: 826.0000 - fp: 421.0000 - tn: 826.0000 - fn: 421.0000 - val_loss: 0.5927 - val_accuracy: 0.7244 - val_precision: 0.6048 - val_recall: 0.0038 - val_mse: 0.2012 - val_mae: 0.4255 - val_auc: 0.7549 - val_f1_score: 0.4311 - val_tp: 226.0000 - val_fp: 86.0000 - val_tn: 226.0000 - val_fn: 86.0000
# Epoch 2/5
# 20/20 [==============================] - 1s 58ms/step - loss: 0.6442 - accuracy: 0.6640 - precision: 0.6019 - recall: 0.0038 - mse: 0.2257 - mae: 0.4493 - auc: 0.6372 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5935 - val_accuracy: 0.7276 - val_precision: 0.6019 - val_recall: 0.0038 - val_mse: 0.2016 - val_mae: 0.4263 - val_auc: 0.7557 - val_f1_score: 0.4212 - val_tp: 227.0000 - val_fp: 85.0000 - val_tn: 227.0000 - val_fn: 85.0000
# Epoch 3/5
# 20/20 [==============================] - 1s 54ms/step - loss: 0.6438 - accuracy: 0.6640 - precision: 0.6019 - recall: 0.0038 - mse: 0.2255 - mae: 0.4497 - auc: 0.6346 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5945 - val_accuracy: 0.7276 - val_precision: 0.6019 - val_recall: 0.0037 - val_mse: 0.2021 - val_mae: 0.4273 - val_auc: 0.7540 - val_f1_score: 0.4212 - val_tp: 227.0000 - val_fp: 85.0000 - val_tn: 227.0000 - val_fn: 85.0000
# Epoch 4/5
# 20/20 [==============================] - 1s 70ms/step - loss: 0.6437 - accuracy: 0.6640 - precision: 0.6019 - recall: 0.0037 - mse: 0.2255 - mae: 0.4500 - auc: 0.6354 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5950 - val_accuracy: 0.7276 - val_precision: 0.6019 - val_recall: 0.0037 - val_mse: 0.2023 - val_mae: 0.4276 - val_auc: 0.7520 - val_f1_score: 0.4212 - val_tp: 227.0000 - val_fp: 85.0000 - val_tn: 227.0000 - val_fn: 85.0000
# Epoch 5/5
# 20/20 [==============================] - 1s 67ms/step - loss: 0.6436 - accuracy: 0.6640 - precision: 0.6019 - recall: 0.0037 - mse: 0.2254 - mae: 0.4498 - auc: 0.6355 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5952 - val_accuracy: 0.7276 - val_precision: 0.6019 - val_recall: 0.0036 - val_mse: 0.2024 - val_mae: 0.4276 - val_auc: 0.7506 - val_f1_score: 0.4212 - val_tp: 227.0000 - val_fp: 85.0000 - val_tn: 227.0000 - val_fn: 85.0000
#
# 13/13 [==============================] - 0s 10ms/step - loss: 0.6495 - accuracy: 0.6410 - precision: 0.6019 - recall: 0.0036 - mse: 0.2286 - mae: 0.4539 - auc: 0.6685 - f1_score: 0.3906 - tp: 250.0000 - fp: 140.0000 - tn: 250.0000 - fn: 140.0000
# accuracy: 64.10%
#
# Epoch 1/5
# 20/20 [==============================] - 1s 57ms/step - loss: 0.6456 - accuracy: 0.6560 - precision: 0.6019 - recall: 0.0036 - mse: 0.2265 - mae: 0.4521 - auc: 0.6462 - f1_score: 0.3961 - tp: 818.0000 - fp: 429.0000 - tn: 818.0000 - fn: 429.0000 - val_loss: 0.6022 - val_accuracy: 0.7212 - val_precision: 0.6019 - val_recall: 0.0036 - val_mse: 0.2056 - val_mae: 0.4330 - val_auc: 0.7388 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 2/5
# 20/20 [==============================] - 1s 50ms/step - loss: 0.6475 - accuracy: 0.6560 - precision: 0.6019 - recall: 0.0035 - mse: 0.2273 - mae: 0.4527 - auc: 0.6373 - f1_score: 0.3961 - tp: 818.0000 - fp: 429.0000 - tn: 818.0000 - fn: 429.0000 - val_loss: 0.6012 - val_accuracy: 0.7212 - val_precision: 0.6019 - val_recall: 0.0035 - val_mse: 0.2052 - val_mae: 0.4311 - val_auc: 0.7387 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 3/5
# 20/20 [==============================] - 1s 65ms/step - loss: 0.6470 - accuracy: 0.6560 - precision: 0.6019 - recall: 0.0035 - mse: 0.2271 - mae: 0.4512 - auc: 0.6412 - f1_score: 0.3961 - tp: 818.0000 - fp: 429.0000 - tn: 818.0000 - fn: 429.0000 - val_loss: 0.6010 - val_accuracy: 0.7212 - val_precision: 0.6019 - val_recall: 0.0035 - val_mse: 0.2051 - val_mae: 0.4302 - val_auc: 0.7321 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 4/5
# 20/20 [==============================] - 1s 51ms/step - loss: 0.6463 - accuracy: 0.6560 - precision: 0.6019 - recall: 0.0034 - mse: 0.2268 - mae: 0.4506 - auc: 0.6461 - f1_score: 0.3961 - tp: 818.0000 - fp: 429.0000 - tn: 818.0000 - fn: 429.0000 - val_loss: 0.6014 - val_accuracy: 0.7212 - val_precision: 0.6019 - val_recall: 0.0034 - val_mse: 0.2053 - val_mae: 0.4302 - val_auc: 0.7248 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 5/5
# 20/20 [==============================] - 1s 51ms/step - loss: 0.6460 - accuracy: 0.6560 - precision: 0.6019 - recall: 0.0034 - mse: 0.2267 - mae: 0.4504 - auc: 0.6495 - f1_score: 0.3961 - tp: 818.0000 - fp: 429.0000 - tn: 818.0000 - fn: 429.0000 - val_loss: 0.6019 - val_accuracy: 0.7212 - val_precision: 0.6019 - val_recall: 0.0034 - val_mse: 0.2055 - val_mae: 0.4304 - val_auc: 0.7225 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
#
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6325 - accuracy: 0.6718 - precision: 0.6019 - recall: 0.0034 - mse: 0.2203 - mae: 0.4460 - auc: 0.6826 - f1_score: 0.4018 - tp: 262.0000 - fp: 128.0000 - tn: 262.0000 - fn: 128.0000
# accuracy: 67.18%
#
# Epoch 1/5
# 20/20 [==============================] - 1s 40ms/step - loss: 0.6405 - accuracy: 0.6683 - precision: 0.6019 - recall: 0.0033 - mse: 0.2239 - mae: 0.4465 - auc: 0.6514 - f1_score: 0.4006 - tp: 834.0000 - fp: 414.0000 - tn: 834.0000 - fn: 414.0000 - val_loss: 0.6183 - val_accuracy: 0.6987 - val_precision: 0.6019 - val_recall: 0.0033 - val_mse: 0.2134 - val_mae: 0.4359 - val_auc: 0.6943 - val_f1_score: 0.4113 - val_tp: 218.0000 - val_fp: 94.0000 - val_tn: 218.0000 - val_fn: 94.0000
# Epoch 2/5
# 20/20 [==============================] - 1s 39ms/step - loss: 0.6396 - accuracy: 0.6683 - precision: 0.6019 - recall: 0.0033 - mse: 0.2235 - mae: 0.4440 - auc: 0.6584 - f1_score: 0.4006 - tp: 834.0000 - fp: 414.0000 - tn: 834.0000 - fn: 414.0000 - val_loss: 0.6183 - val_accuracy: 0.6987 - val_precision: 0.6019 - val_recall: 0.0033 - val_mse: 0.2134 - val_mae: 0.4347 - val_auc: 0.6954 - val_f1_score: 0.4113 - val_tp: 218.0000 - val_fp: 94.0000 - val_tn: 218.0000 - val_fn: 94.0000
# Epoch 3/5
# 20/20 [==============================] - 1s 42ms/step - loss: 0.6385 - accuracy: 0.6683 - precision: 0.6019 - recall: 0.0032 - mse: 0.2230 - mae: 0.4431 - auc: 0.6632 - f1_score: 0.4006 - tp: 834.0000 - fp: 414.0000 - tn: 834.0000 - fn: 414.0000 - val_loss: 0.6188 - val_accuracy: 0.6987 - val_precision: 0.6019 - val_recall: 0.0032 - val_mse: 0.2136 - val_mae: 0.4346 - val_auc: 0.6912 - val_f1_score: 0.4113 - val_tp: 218.0000 - val_fp: 94.0000 - val_tn: 218.0000 - val_fn: 94.0000
# Epoch 4/5
# 20/20 [==============================] - 1s 55ms/step - loss: 0.6380 - accuracy: 0.6683 - precision: 0.6019 - recall: 0.0032 - mse: 0.2228 - mae: 0.4427 - auc: 0.6671 - f1_score: 0.4006 - tp: 834.0000 - fp: 414.0000 - tn: 834.0000 - fn: 414.0000 - val_loss: 0.6192 - val_accuracy: 0.6987 - val_precision: 0.6019 - val_recall: 0.0032 - val_mse: 0.2138 - val_mae: 0.4347 - val_auc: 0.6873 - val_f1_score: 0.4113 - val_tp: 218.0000 - val_fp: 94.0000 - val_tn: 218.0000 - val_fn: 94.0000
# Epoch 5/5
# 20/20 [==============================] - 1s 52ms/step - loss: 0.6375 - accuracy: 0.6683 - precision: 0.6019 - recall: 0.0032 - mse: 0.2226 - mae: 0.4424 - auc: 0.6688 - f1_score: 0.4006 - tp: 834.0000 - fp: 414.0000 - tn: 834.0000 - fn: 414.0000 - val_loss: 0.6197 - val_accuracy: 0.6987 - val_precision: 0.6019 - val_recall: 0.0031 - val_mse: 0.2140 - val_mae: 0.4346 - val_auc: 0.6882 - val_f1_score: 0.4113 - val_tp: 218.0000 - val_fp: 94.0000 - val_tn: 218.0000 - val_fn: 94.0000
#
# 13/13 [==============================] - 0s 11ms/step - loss: 0.6457 - accuracy: 0.6504 - precision: 0.6019 - recall: 0.0031 - mse: 0.2266 - mae: 0.4475 - auc: 0.6626 - f1_score: 0.3941 - tp: 253.0000 - fp: 136.0000 - tn: 253.0000 - fn: 136.0000
# accuracy: 65.04%
#
# ___________________________________________________________________________________

# %%
output_df
# Out:
#        model  accuracy  precision    recall       mse       mae       auc  \
# 0  SimpleRNN  0.671621   0.384850  0.003297  0.219673  0.444909  0.694026
# 1       LSTM  0.669564   0.629834  0.005456  0.221280  0.449341  0.689364
# 2        GRU  0.668026   0.609460  0.003608  0.221529  0.446728  0.684053
#
#    f1_score  prediction time
# 0  0.411203         0.080592
# 1  0.400770         0.458152
# 2  0.400258         0.180088

# %% [markdown]
# <h3>Traditional Methodologies</h3>

# %%
stemmer = PorterStemmer()
analyzer = CountVectorizer().build_analyzer()
def stemmed_words(doc):
    stemmed_words = [stemmer.stem(w) for w in analyzer(doc)]
    non_stop_words = [word for word in stemmed_words]
    return non_stop_words

# %%
count_vectorizer = CountVectorizer(stop_words= stop_words, max_features= 1000)
feature_vector = count_vectorizer.fit(data_v1['Text'])
train_ds_features = count_vectorizer.transform(data_v1['Text'])
features = feature_vector.get_feature_names()
features_counts = np.sum(train_ds_features.toarray(), axis = 0)
features_counts = pd.DataFrame(dict(features =  features, counts = features_counts))
features_counts = features_counts.sort_values("counts", ascending= False)[0:15]
features_counts
# Out:
#      features  counts
# 333      euro    1461
# 329       eur    1374
# 675     pound    1217
# 420       gbp    1119
# 924       usd    1055
# 297    dollar     580
# 381     forex     410
# 379  forecast     384
# 187   british     374
# 684     price     364
# 711      rate     342
# 265  currency     256
# 308       ecb     242
# 337    eurusd     236
# 627   outlook     226

# %%
train_x, test_x, train_y, test_y =  train_test_split(train_ds_features, data_v1['Sentiment'], test_size = 0.3, random_state = 42)

# %%
x = train_ds_features
y = data_v1['Sentiment']

# %%
tsa_classifiers
# Out:
# [('SimpleRNN',
#   <keras.wrappers.scikit_learn.KerasClassifier at 0x7fe922eba9a0>),
#  ('LSTM', <keras.wrappers.scikit_learn.KerasClassifier at 0x7fe951d5c850>),
#  ('GRU', <keras.wrappers.scikit_learn.KerasClassifier at 0x7fe92316eb20>)]

# %%
classifiers = {
    "BernoulliNB": BernoulliNB(),
    "ComplementNB": ComplementNB(),
    "MultinomialNB": MultinomialNB(),
    "LogisticRegression": LogisticRegression(),
    "KNeighborsClassifier": KNeighborsClassifier(),
    "DecisionTreeClassifier": DecisionTreeClassifier(),
    "RandomForestClassifier": RandomForestClassifier(),
    "MLPClassifier": MLPClassifier(max_iter=1000),
    "AdaBoostClassifier": AdaBoostClassifier()
}
estimators = []
for name, sklearn_classifier in classifiers.items():
    estimators.append((name,sklearn_classifier))

'''for tsa in tsa_classifiers:
    estimators.append((tsa[0], tsa[1]))'''
    
voting_clf = VotingClassifier(
        estimators=estimators,
        voting="hard")
classifiers['VotingClassifier'] = voting_clf
classifiers
# Out:
# {'BernoulliNB': BernoulliNB(),
#  'ComplementNB': ComplementNB(),
#  'MultinomialNB': MultinomialNB(),
#  'LogisticRegression': LogisticRegression(),
#  'KNeighborsClassifier': KNeighborsClassifier(),
#  'DecisionTreeClassifier': DecisionTreeClassifier(),
#  'RandomForestClassifier': RandomForestClassifier(),
#  'MLPClassifier': MLPClassifier(max_iter=1000),
#  'AdaBoostClassifier': AdaBoostClassifier(),
#  'VotingClassifier': VotingClassifier(estimators=[('BernoulliNB', BernoulliNB()),
#                               ('ComplementNB', ComplementNB()),
#                               ('MultinomialNB', MultinomialNB()),
#                               ('LogisticRegression', LogisticRegression()),
#                               ('KNeighborsClassifier', KNeighborsClassifier()),
#                               ('DecisionTreeClassifier',
#                                DecisionTreeClassifier()),
#                               ('RandomForestClassifier',
#                                RandomForestClassifier()),
#                               ('MLPClassifier', MLPClassifier(max_iter=1000)),
#                               ('AdaBoostClassifier', AdaBoostClassifier())])}

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import precision_score, \
    recall_score, confusion_matrix, classification_report, \
    accuracy_score, f1_score

for name, sklearn_classifier in classifiers.items():
    print("Classifier : ", name)
    accuracy = precision = recall = mse = mae = auc = f1_score_val = prediction_time = 0
    
    for train_index, test_index in kfold.split(x):
        train_x, test_x, train_y, test_y = x[train_index], x[test_index], y[train_index], y[test_index]       
    
        sklearn_classifier.fit(train_x.toarray(), train_y)
        start_time = time.time()
        test_ds_predicted = sklearn_classifier.predict(test_x.toarray())
        end_time = time.time() - start_time
        print(metrics.classification_report(test_y, test_ds_predicted))
        print("")
        print("Time taken to predict the model " + str(end_time))
        print("")
        tr_mae = mean_absolute_error(test_y, test_ds_predicted)
        tr_mse = mean_squared_error(test_y, test_ds_predicted)
        tr_accuracy = accuracy_score(test_y, test_ds_predicted)
        tr_f1_score = f1_score(test_y, test_ds_predicted, average='weighted')
        tr_recall = recall_score(test_y, test_ds_predicted, average='weighted')
        tr_precision = precision_score(test_y, test_ds_predicted, average='weighted')
        tr_auc = roc_auc_score(test_y, test_ds_predicted)

        accuracy += tr_accuracy
        precision += tr_precision
        recall += tr_recall
        mse += tr_mse
        mae += tr_mae
        auc += tr_auc
        f1_score_val += tr_f1_score
        prediction_time += end_time
    #print('MAE: %f' % mean_absolute_error(test_y, test_ds_predicted))
    #print('MSE: %f' % mean_squared_error(test_y, test_ds_predicted))
    #print('RMSE: %f' % sqrt(mean_squared_error(test_y, test_ds_predicted)))
    
    
    output_df = output_df.append([{'model': str(name), 'accuracy':accuracy/seed,'precision':precision/seed
                                       ,'recall':recall/seed,'mse':mse/seed,'mae':mae/seed
                                       ,'auc':auc/seed,'f1_score':f1_score_val/seed, 'prediction time': prediction_time/seed}], ignore_index=True)

    if name != 'VotingClassifier':
        yhat = sklearn_classifier.predict_proba(test_x.toarray())
        fpr_rf, tpr_rf, threshold2 = roc_curve(test_y.to_numpy(), yhat[:,1])
        plt.rcParams["figure.figsize"] = (10,7)
        plt.figure(1)
        plt.plot([0, 1], [0, 1], 'k--')
        plt.plot(fpr_rf, tpr_rf, label=str(name) + ' (area = {:.3f})'.format(tr_auc))
        plt.xlabel('False positive rate')
        plt.ylabel('True positive rate')
        plt.title('ROC curve')
        plt.legend(loc='best')
        plt.savefig('td_roc_curve.png')
    
    print("________________________________________________________")
    print("")
    print("")
plt.show()
# Out:
# Classifier :  BernoulliNB
#               precision    recall  f1-score   support
#
#            0       0.54      0.59      0.57       138
#            1       0.76      0.72      0.74       252
#
#     accuracy                           0.68       390
#    macro avg       0.65      0.66      0.65       390
# weighted avg       0.69      0.68      0.68       390
#
#
# Time taken to predict the model 0.0026361942291259766
#
#               precision    recall  f1-score   support
#
#            0       0.46      0.49      0.48       102
#            1       0.82      0.80      0.81       288
#
#     accuracy                           0.72       390
#    macro avg       0.64      0.64      0.64       390
# weighted avg       0.72      0.72      0.72       390
#
#
# Time taken to predict the model 0.005212068557739258
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.61      0.61       140
#            1       0.78      0.78      0.78       250
#
#     accuracy                           0.72       390
#    macro avg       0.69      0.69      0.69       390
# weighted avg       0.72      0.72      0.72       390
#
#
# Time taken to predict the model 0.009592771530151367
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.60      0.57       128
#            1       0.80      0.76      0.78       262
#
#     accuracy                           0.71       390
#    macro avg       0.67      0.68      0.68       390
# weighted avg       0.72      0.71      0.71       390
#
#
# Time taken to predict the model 0.0037970542907714844
#
#               precision    recall  f1-score   support
#
#            0       0.51      0.50      0.51       136
#            1       0.73      0.74      0.74       253
#
#     accuracy                           0.66       389
#    macro avg       0.62      0.62      0.62       389
# weighted avg       0.66      0.66      0.66       389
#
#
# Time taken to predict the model 0.0054569244384765625
#
# ________________________________________________________
#
#
# Classifier :  ComplementNB
#               precision    recall  f1-score   support
#
#            0       0.52      0.64      0.57       138
#            1       0.78      0.67      0.72       252
#
#     accuracy                           0.66       390
#    macro avg       0.65      0.66      0.65       390
# weighted avg       0.68      0.66      0.67       390
#
#
# Time taken to predict the model 0.0043621063232421875
#
#               precision    recall  f1-score   support
#
#            0       0.46      0.61      0.52       102
#            1       0.84      0.75      0.79       288
#
#     accuracy                           0.71       390
#    macro avg       0.65      0.68      0.66       390
# weighted avg       0.74      0.71      0.72       390
#
#
# Time taken to predict the model 0.0017158985137939453
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.69      0.64       140
#            1       0.81      0.74      0.77       250
#
#     accuracy                           0.72       390
#    macro avg       0.71      0.72      0.71       390
# weighted avg       0.74      0.72      0.73       390
#
#
# Time taken to predict the model 0.001580953598022461
#
#               precision    recall  f1-score   support
#
#            0       0.52      0.64      0.57       128
#            1       0.80      0.71      0.75       262
#
#     accuracy                           0.68       390
#    macro avg       0.66      0.67      0.66       390
# weighted avg       0.71      0.68      0.69       390
#
#
# Time taken to predict the model 0.004186868667602539
#
#               precision    recall  f1-score   support
#
#            0       0.48      0.55      0.52       136
#            1       0.74      0.68      0.71       253
#
#     accuracy                           0.64       389
#    macro avg       0.61      0.62      0.61       389
# weighted avg       0.65      0.64      0.64       389
#
#
# Time taken to predict the model 0.0015180110931396484
#
# ________________________________________________________
#
#
# Classifier :  MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.54      0.57      0.56       138
#            1       0.76      0.74      0.75       252
#
#     accuracy                           0.68       390
#    macro avg       0.65      0.66      0.65       390
# weighted avg       0.68      0.68      0.68       390
#
#
# Time taken to predict the model 0.0037708282470703125
#
#               precision    recall  f1-score   support
#
#            0       0.47      0.49      0.48       102
#            1       0.82      0.81      0.81       288
#
#     accuracy                           0.72       390
#    macro avg       0.64      0.65      0.65       390
# weighted avg       0.73      0.72      0.72       390
#
#
# Time taken to predict the model 0.0018911361694335938
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.63      0.63       140
#            1       0.79      0.79      0.79       250
#
#     accuracy                           0.73       390
#    macro avg       0.71      0.71      0.71       390
# weighted avg       0.73      0.73      0.73       390
#
#
# Time taken to predict the model 0.004235029220581055
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.57      0.56       128
#            1       0.79      0.77      0.78       262
#
#     accuracy                           0.70       390
#    macro avg       0.66      0.67      0.67       390
# weighted avg       0.71      0.70      0.70       390
#
#
# Time taken to predict the model 0.0047321319580078125
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.51      0.53       136
#            1       0.75      0.77      0.76       253
#
#     accuracy                           0.68       389
#    macro avg       0.65      0.64      0.64       389
# weighted avg       0.68      0.68      0.68       389
#
#
# Time taken to predict the model 0.001428842544555664
#
# ________________________________________________________
#
#
# Classifier :  LogisticRegression
#               precision    recall  f1-score   support
#
#            0       0.61      0.49      0.54       138
#            1       0.75      0.83      0.78       252
#
#     accuracy                           0.71       390
#    macro avg       0.68      0.66      0.66       390
# weighted avg       0.70      0.71      0.70       390
#
#
# Time taken to predict the model 0.004548072814941406
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.48      0.52       102
#            1       0.83      0.87      0.85       288
#
#     accuracy                           0.77       390
#    macro avg       0.70      0.68      0.68       390
# weighted avg       0.76      0.77      0.76       390
#
#
# Time taken to predict the model 0.001737833023071289
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.51      0.57       140
#            1       0.75      0.85      0.80       250
#
#     accuracy                           0.73       390
#    macro avg       0.70      0.68      0.68       390
# weighted avg       0.72      0.73      0.72       390
#
#
# Time taken to predict the model 0.0013439655303955078
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.41      0.47       128
#            1       0.74      0.85      0.79       262
#
#     accuracy                           0.70       390
#    macro avg       0.66      0.63      0.63       390
# weighted avg       0.69      0.70      0.69       390
#
#
# Time taken to predict the model 0.0012581348419189453
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.43      0.49       136
#            1       0.73      0.83      0.78       253
#
#     accuracy                           0.69       389
#    macro avg       0.65      0.63      0.63       389
# weighted avg       0.68      0.69      0.68       389
#
#
# Time taken to predict the model 0.0014619827270507812
#
# ________________________________________________________
#
#
# Classifier :  KNeighborsClassifier
#               precision    recall  f1-score   support
#
#            0       0.55      0.53      0.54       138
#            1       0.75      0.77      0.76       252
#
#     accuracy                           0.68       390
#    macro avg       0.65      0.65      0.65       390
# weighted avg       0.68      0.68      0.68       390
#
#
# Time taken to predict the model 0.02723097801208496
#               precision    recall  f1-score   support
#
#            0       0.41      0.49      0.45       102
#            1       0.81      0.75      0.78       288
#
#     accuracy                           0.68       390
#    macro avg       0.61      0.62      0.61       390
# weighted avg       0.70      0.68      0.69       390
#
#
# Time taken to predict the model 0.02991509437561035
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.52      0.58       140
#            1       0.76      0.84      0.80       250
#
#     accuracy                           0.73       390
#    macro avg       0.70      0.68      0.69       390
# weighted avg       0.72      0.73      0.72       390
#
#
# Time taken to predict the model 0.03126978874206543
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.38      0.46       128
#            1       0.74      0.86      0.80       262
#
#     accuracy                           0.70       390
#    macro avg       0.65      0.62      0.63       390
# weighted avg       0.68      0.70      0.68       390
#
#
# Time taken to predict the model 0.029645919799804688
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.54      0.54       136
#            1       0.75      0.77      0.76       253
#
#     accuracy                           0.69       389
#    macro avg       0.65      0.65      0.65       389
# weighted avg       0.68      0.69      0.69       389
#
#
# Time taken to predict the model 0.03020501136779785
#
# ________________________________________________________
#
#
# Classifier :  DecisionTreeClassifier
#               precision    recall  f1-score   support
#
#            0       0.59      0.53      0.56       138
#            1       0.76      0.80      0.78       252
#
#     accuracy                           0.70       390
#    macro avg       0.67      0.66      0.67       390
# weighted avg       0.70      0.70      0.70       390
#
#
# Time taken to predict the model 0.001461029052734375
#
#               precision    recall  f1-score   support
#
#            0       0.42      0.45      0.43       102
#            1       0.80      0.78      0.79       288
#
#     accuracy                           0.69       390
#    macro avg       0.61      0.61      0.61       390
# weighted avg       0.70      0.69      0.70       390
#
#
# Time taken to predict the model 0.0007221698760986328
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.59      0.59       140
#            1       0.77      0.78      0.77       250
#
#     accuracy                           0.71       390
#    macro avg       0.69      0.68      0.68       390
# weighted avg       0.71      0.71      0.71       390
#
#
# Time taken to predict the model 0.002826213836669922
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.50      0.52       128
#            1       0.77      0.80      0.78       262
#
#     accuracy                           0.70       390
#    macro avg       0.66      0.65      0.65       390
# weighted avg       0.70      0.70      0.70       390
#
#
# Time taken to predict the model 0.0012810230255126953
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.55      0.57       136
#            1       0.77      0.79      0.78       253
#
#     accuracy                           0.71       389
#    macro avg       0.68      0.67      0.67       389
# weighted avg       0.70      0.71      0.70       389
#
#
# Time taken to predict the model 0.000720977783203125
#
# ________________________________________________________
#
#
# Classifier :  RandomForestClassifier
#               precision    recall  f1-score   support
#
#            0       0.64      0.49      0.56       138
#            1       0.75      0.85      0.80       252
#
#     accuracy                           0.72       390
#    macro avg       0.70      0.67      0.68       390
# weighted avg       0.71      0.72      0.71       390
#
#
# Time taken to predict the model 0.019243955612182617
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.40      0.46       102
#            1       0.81      0.88      0.84       288
#
#     accuracy                           0.76       390
#    macro avg       0.68      0.64      0.65       390
# weighted avg       0.74      0.76      0.74       390
#
#
# Time taken to predict the model 0.018383264541625977
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.53      0.60       140
#            1       0.77      0.87      0.81       250
#
#     accuracy                           0.75       390
#    macro avg       0.73      0.70      0.71       390
# weighted avg       0.74      0.75      0.74       390
#
#
# Time taken to predict the model 0.02091217041015625
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.42      0.53       128
#            1       0.76      0.92      0.83       262
#
#     accuracy                           0.75       390
#    macro avg       0.74      0.67      0.68       390
# weighted avg       0.75      0.75      0.73       390
#
#
# Time taken to predict the model 0.01715397834777832
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.45      0.55       136
#            1       0.75      0.90      0.82       253
#
#     accuracy                           0.74       389
#    macro avg       0.73      0.67      0.68       389
# weighted avg       0.74      0.74      0.73       389
#
#
# Time taken to predict the model 0.01809525489807129
#
# ________________________________________________________
#
#
# Classifier :  MLPClassifier
#               precision    recall  f1-score   support
#
#            0       0.57      0.50      0.53       138
#            1       0.74      0.79      0.77       252
#
#     accuracy                           0.69       390
#    macro avg       0.65      0.64      0.65       390
# weighted avg       0.68      0.69      0.68       390
#
#
# Time taken to predict the model 0.0024569034576416016
#
#               precision    recall  f1-score   support
#
#            0       0.52      0.47      0.49       102
#            1       0.82      0.85      0.83       288
#
#     accuracy                           0.75       390
#    macro avg       0.67      0.66      0.66       390
# weighted avg       0.74      0.75      0.74       390
#
#
# Time taken to predict the model 0.0036568641662597656
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.55      0.57       140
#            1       0.76      0.79      0.77       250
#
#     accuracy                           0.70       390
#    macro avg       0.68      0.67      0.67       390
# weighted avg       0.70      0.70      0.70       390
#
#
# Time taken to predict the model 0.0024309158325195312
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.55      0.56       128
#            1       0.78      0.81      0.79       262
#
#     accuracy                           0.72       390
#    macro avg       0.68      0.68      0.68       390
# weighted avg       0.72      0.72      0.72       390
#
#
# Time taken to predict the model 0.001895904541015625
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.54      0.55       136
#            1       0.76      0.78      0.77       253
#
#     accuracy                           0.70       389
#    macro avg       0.66      0.66      0.66       389
# weighted avg       0.69      0.70      0.69       389
#
#
# Time taken to predict the model 0.001741170883178711
#
# ________________________________________________________
#
#
# Classifier :  AdaBoostClassifier
#               precision    recall  f1-score   support
#
#            0       0.77      0.36      0.49       138
#            1       0.73      0.94      0.82       252
#
#     accuracy                           0.74       390
#    macro avg       0.75      0.65      0.66       390
# weighted avg       0.74      0.74      0.71       390
#
#
# Time taken to predict the model 0.034523963928222656
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.30      0.40       102
#            1       0.79      0.92      0.85       288
#
#     accuracy                           0.76       390
#    macro avg       0.68      0.61      0.62       390
# weighted avg       0.73      0.76      0.73       390
#
#
# Time taken to predict the model 0.02672600746154785
#               precision    recall  f1-score   support
#
#            0       0.66      0.34      0.45       140
#            1       0.71      0.90      0.79       250
#
#     accuracy                           0.70       390
#    macro avg       0.68      0.62      0.62       390
# weighted avg       0.69      0.70      0.67       390
#
#
# Time taken to predict the model 0.03254890441894531
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.26      0.37       128
#            1       0.72      0.94      0.81       262
#
#     accuracy                           0.71       390
#    macro avg       0.69      0.60      0.59       390
# weighted avg       0.70      0.71      0.67       390
#
#
# Time taken to predict the model 0.029742002487182617
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.30      0.41       136
#            1       0.71      0.91      0.80       253
#
#     accuracy                           0.70       389
#    macro avg       0.68      0.61      0.60       389
# weighted avg       0.69      0.70      0.66       389
#
#
# Time taken to predict the model 0.03161215782165527
#
# ________________________________________________________
#
#
# Classifier :  VotingClassifier
#               precision    recall  f1-score   support
#
#            0       0.60      0.52      0.56       138
#            1       0.76      0.81      0.78       252
#
#     accuracy                           0.71       390
#    macro avg       0.68      0.67      0.67       390
# weighted avg       0.70      0.71      0.70       390
#
#
# Time taken to predict the model 0.11062026023864746
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.42      0.48       102
#            1       0.81      0.88      0.84       288
#
#     accuracy                           0.76       390
#    macro avg       0.68      0.65      0.66       390
# weighted avg       0.74      0.76      0.75       390
#
#
# Time taken to predict the model 0.08426308631896973
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.58      0.64       140
#            1       0.79      0.87      0.83       250
#
#     accuracy                           0.76       390
#    macro avg       0.75      0.72      0.73       390
# weighted avg       0.76      0.76      0.76       390
#
#
# Time taken to predict the model 0.09252500534057617
#
#               precision    recall  f1-score   support
#
#            0       0.63      0.50      0.56       128
#            1       0.78      0.85      0.81       262
#
#     accuracy                           0.74       390
#    macro avg       0.70      0.68      0.69       390
# weighted avg       0.73      0.74      0.73       390
#
#
# Time taken to predict the model 0.08716607093811035
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.43      0.49       136
#            1       0.73      0.83      0.78       253
#
#     accuracy                           0.69       389
#    macro avg       0.65      0.63      0.63       389
# weighted avg       0.68      0.69      0.68       389
#
#
# Time taken to predict the model 0.08432602882385254
#
# ________________________________________________________

# %%
output_df
# Out:
#                      model  accuracy  precision    recall       mse       mae  \
# 0                SimpleRNN  0.671621   0.384850  0.003297  0.219673  0.444909
# 1                     LSTM  0.669564   0.629834  0.005456  0.221280  0.449341
# 2                      GRU  0.668026   0.609460  0.003608  0.221529  0.446728
# 3              BernoulliNB  0.695722   0.699594  0.695722  0.304278  0.304278
# 4             ComplementNB  0.683404   0.703822  0.683404  0.316596  0.316596
# 5            MultinomialNB  0.703426   0.704713  0.703426  0.296574  0.296574
# 6       LogisticRegression  0.718815   0.707197  0.718815  0.281185  0.281185
# 7     KNeighborsClassifier  0.695737   0.693563  0.695737  0.304263  0.304263
# 8   DecisionTreeClassifier  0.702927   0.701141  0.702927  0.297073  0.297073
# 9   RandomForestClassifier  0.744484   0.735233  0.744484  0.255516  0.255516
# 10           MLPClassifier  0.711126   0.705789  0.711126  0.288874  0.288874
# 11      AdaBoostClassifier  0.721384   0.711211  0.721384  0.278616  0.278616
# 12        VotingClassifier  0.731635   0.721310  0.731635  0.268365  0.268365
#
#          auc  f1_score  prediction time
# 0   0.694026  0.411203         0.080592
# 1   0.689364  0.400770         0.458152
# 2   0.684053  0.400258         0.180088
# 3   0.659656  0.697312         0.005339
# 4   0.668479  0.690060         0.002673
# 5   0.664243  0.703886         0.003212
# 6   0.653870  0.708709         0.002070
# 7   0.644164  0.691724         0.029653
# 8   0.656773  0.701594         0.001402
# 9   0.671006  0.730530         0.018758
# 10  0.661708  0.707915         0.002436
# 11  0.617715  0.687670         0.031031
# 12  0.669275  0.722995         0.091780

# %%
output_df.to_csv('classifiers_output_result.csv', sep='\t')
