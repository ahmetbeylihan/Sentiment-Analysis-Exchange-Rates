# %%
import re
from TextCleaner import TextCleaner
import pandas as pd
import numpy as np
import time
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sn
import keras_metrics as km
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold
from numpy import sqrt 
# %matplotlib inline
import nltk
from langdetect import detect
import contractions
from nltk.corpus import stopwords
from textblob import Word
from sklearn.preprocessing import LabelEncoder
from collections import Counter
from wordcloud import WordCloud
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem.snowball import PorterStemmer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import TimeSeriesSplit

from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, GRU, SimpleRNN, SpatialDropout1D
from tensorflow.keras.layers import SpatialDropout1D
from tensorflow.keras.layers import Embedding
from tensorflow.python.keras.metrics import Metric
import tensorflow as tf    
import tensorflow_addons as tfa
from tensorflow import keras 
from keras.metrics import Precision, Recall

# Classifiers
from sklearn.naive_bayes import BernoulliNB
from sklearn import metrics
from sklearn.naive_bayes import (
    BernoulliNB,
    ComplementNB,
    MultinomialNB,
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
pd.options.mode.chained_assignment = None  # default='warn'

# %%
df = pd.read_csv('sentiment.csv')
df = df.drop(df.columns[0], axis=1)
df
# Out:
#                Author                                               Text  \
# 0            yusobays  @elonmusk @elonmusk  please Come to TRY₺ #turk...
# 1       BtcTurkDestek  @DrBatal  Hello, if you have registered using ...
# 2      RisingValhalla  “I trade weekly bars. You?”\n\n200 day moving ...
# 3        Erda55203615  @elonmusk Try turkish lira its at the bottom m...
# 4        Erda55203615            @ImTooRealForU TRY FUCKING TURKISH LIRA
# ...               ...                                                ...
# 1944  flyingstocksman  For those of you who missed it last night with...
# 1945         alpeshbp  GBP/USD Weekly Price Forecast – The British Po...
# 1946     campsbay_com  20.0142 ZAR for 1 GBP @ December 31, 2020 at 0...
# 1947       MajorFXNow  GBP/EUR: Pound Lifted by UK Approval of AstraZ...
# 1948     trader_blitz  GBP/JPY | $GBPJPY | $GBP $JPY\n\nBRITISH POUND...
#
#                            Time  Like Count Currency ISO Code  \
# 0     2021-01-31 22:21:58+00:00           1               TRY
# 1     2021-01-30 18:07:15+00:00           0               TRY
# 2     2021-01-30 03:29:59+00:00           0               TRY
# 3     2021-01-29 20:20:49+00:00           0               TRY
# 4     2021-01-29 20:19:36+00:00           0               TRY
# ...                         ...         ...               ...
# 1944  2021-01-01 09:24:17+00:00           0               GBP
# 1945  2021-01-01 07:13:32+00:00           0               GBP
# 1946  2021-01-01 04:20:02+00:00           0               GBP
# 1947  2021-01-01 02:32:32+00:00           0               GBP
# 1948  2021-01-01 00:42:01+00:00           0               GBP
#
#                                                     Url  target
# 0     https://twitter.com/yusobays/status/1356004827...     0.0
# 1     https://twitter.com/BtcTurkDestek/status/13555...     0.0
# 2     https://twitter.com/RisingValhalla/status/1355...     0.0
# 3     https://twitter.com/Erda55203615/status/135524...    -1.0
# 4     https://twitter.com/Erda55203615/status/135524...    -1.0
# ...                                                 ...     ...
# 1944  https://twitter.com/flyingstocksman/status/134...     0.0
# 1945  https://twitter.com/alpeshbp/status/1344904575...     0.0
# 1946  https://twitter.com/campsbay_com/status/134486...     0.0
# 1947  https://twitter.com/MajorFXNow/status/13448338...     0.0
# 1948  https://twitter.com/trader_blitz/status/134480...     0.0
#
# [1949 rows x 7 columns]

# %%
def sentiments(df):
    if df['target'] >= 0:
        return 'Positive'
    elif df['target'] < 0:
        return 'Negative'

# %%
df['Sentiment'] = df.apply(sentiments, axis=1)

# %%
df
# Out:
#                Author                                               Text  \
# 0            yusobays  @elonmusk @elonmusk  please Come to TRY₺ #turk...
# 1       BtcTurkDestek  @DrBatal  Hello, if you have registered using ...
# 2      RisingValhalla  “I trade weekly bars. You?”\n\n200 day moving ...
# 3        Erda55203615  @elonmusk Try turkish lira its at the bottom m...
# 4        Erda55203615            @ImTooRealForU TRY FUCKING TURKISH LIRA
# ...               ...                                                ...
# 1944  flyingstocksman  For those of you who missed it last night with...
# 1945         alpeshbp  GBP/USD Weekly Price Forecast – The British Po...
# 1946     campsbay_com  20.0142 ZAR for 1 GBP @ December 31, 2020 at 0...
# 1947       MajorFXNow  GBP/EUR: Pound Lifted by UK Approval of AstraZ...
# 1948     trader_blitz  GBP/JPY | $GBPJPY | $GBP $JPY\n\nBRITISH POUND...
#
#                            Time  Like Count Currency ISO Code  \
# 0     2021-01-31 22:21:58+00:00           1               TRY
# 1     2021-01-30 18:07:15+00:00           0               TRY
# 2     2021-01-30 03:29:59+00:00           0               TRY
# 3     2021-01-29 20:20:49+00:00           0               TRY
# 4     2021-01-29 20:19:36+00:00           0               TRY
# ...                         ...         ...               ...
# 1944  2021-01-01 09:24:17+00:00           0               GBP
# 1945  2021-01-01 07:13:32+00:00           0               GBP
# 1946  2021-01-01 04:20:02+00:00           0               GBP
# 1947  2021-01-01 02:32:32+00:00           0               GBP
# 1948  2021-01-01 00:42:01+00:00           0               GBP
#
#                                                     Url  target Sentiment
# 0     https://twitter.com/yusobays/status/1356004827...     0.0  Positive
# 1     https://twitter.com/BtcTurkDestek/status/13555...     0.0  Positive
# 2     https://twitter.com/RisingValhalla/status/1355...     0.0  Positive
# 3     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# 4     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# ...                                                 ...     ...       ...
# 1944  https://twitter.com/flyingstocksman/status/134...     0.0  Positive
# 1945  https://twitter.com/alpeshbp/status/1344904575...     0.0  Positive
# 1946  https://twitter.com/campsbay_com/status/134486...     0.0  Positive
# 1947  https://twitter.com/MajorFXNow/status/13448338...     0.0  Positive
# 1948  https://twitter.com/trader_blitz/status/134480...     0.0  Positive
#
# [1949 rows x 8 columns]

# %%
data_v1 = df[['Text','Sentiment']]
data_v1.isnull().sum()
# Out:
# Text         0
# Sentiment    0
# dtype: int64

# %%
plt.figure(figsize=(7,8))
plt.title("Number of records of positive and negative sentiments")
plot = sn.countplot(x = 'Sentiment', data = data_v1)
for p in plot.patches:
    plot.annotate(p.get_height(),(p.get_x() + 0.2 ,p.get_height()+80))

# %%
clean = TextCleaner()
text = clean.convert_emoji_to_text("Hilarious 😂. The feeling of making a sale 😎, The feeling of actually fulfilling orders 😒")
print(text)

text4 = "Hello :-) :-)"
resp = clean.convert_emoticons(text4)
print(resp)
# Out:
# Hilarious face with tears of joy. The feeling of making a sale smiling face with sunglasses, The feeling of actually fulfilling orders unamused face
# Hello Happy face smiley Happy face smiley

# %%
df
# Out:
#                Author                                               Text  \
# 0            yusobays  @elonmusk @elonmusk  please Come to TRY₺ #turk...
# 1       BtcTurkDestek  @DrBatal  Hello, if you have registered using ...
# 2      RisingValhalla  “I trade weekly bars. You?”\n\n200 day moving ...
# 3        Erda55203615  @elonmusk Try turkish lira its at the bottom m...
# 4        Erda55203615            @ImTooRealForU TRY FUCKING TURKISH LIRA
# ...               ...                                                ...
# 1944  flyingstocksman  For those of you who missed it last night with...
# 1945         alpeshbp  GBP/USD Weekly Price Forecast – The British Po...
# 1946     campsbay_com  20.0142 ZAR for 1 GBP @ December 31, 2020 at 0...
# 1947       MajorFXNow  GBP/EUR: Pound Lifted by UK Approval of AstraZ...
# 1948     trader_blitz  GBP/JPY | $GBPJPY | $GBP $JPY\n\nBRITISH POUND...
#
#                            Time  Like Count Currency ISO Code  \
# 0     2021-01-31 22:21:58+00:00           1               TRY
# 1     2021-01-30 18:07:15+00:00           0               TRY
# 2     2021-01-30 03:29:59+00:00           0               TRY
# 3     2021-01-29 20:20:49+00:00           0               TRY
# 4     2021-01-29 20:19:36+00:00           0               TRY
# ...                         ...         ...               ...
# 1944  2021-01-01 09:24:17+00:00           0               GBP
# 1945  2021-01-01 07:13:32+00:00           0               GBP
# 1946  2021-01-01 04:20:02+00:00           0               GBP
# 1947  2021-01-01 02:32:32+00:00           0               GBP
# 1948  2021-01-01 00:42:01+00:00           0               GBP
#
#                                                     Url  target Sentiment
# 0     https://twitter.com/yusobays/status/1356004827...     0.0  Positive
# 1     https://twitter.com/BtcTurkDestek/status/13555...     0.0  Positive
# 2     https://twitter.com/RisingValhalla/status/1355...     0.0  Positive
# 3     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# 4     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# ...                                                 ...     ...       ...
# 1944  https://twitter.com/flyingstocksman/status/134...     0.0  Positive
# 1945  https://twitter.com/alpeshbp/status/1344904575...     0.0  Positive
# 1946  https://twitter.com/campsbay_com/status/134486...     0.0  Positive
# 1947  https://twitter.com/MajorFXNow/status/13448338...     0.0  Positive
# 1948  https://twitter.com/trader_blitz/status/134480...     0.0  Positive
#
# [1949 rows x 8 columns]

# %%
def remove_url(text):
    result = re.sub(r'https?:\/\/\S*', '', text, flags=re.MULTILINE)
    return result

def replace_contractions(text):
    return contractions.fix(text)

abbs =  {"eur": "euro", "usd": "dollar", "gbp" : "pound", "u":"you", "tryeur":"turkish lira euro", "try":" turkish lira", "gt":"greater than","lt": "less than","btc":"bitcoin",
        "gbpusd": "pound dollar", "usdtry":"dollar turkish lira", "fx":"forex", "u":"you", "eurusd":"euro usd", "eurgbp":"euro pound", "jpy":"japanese yen","cny":"chinese yuan","uk":"united kingdom"}

def replace_currency(text):
    val = ''
    for i in text.split():
        if abbs.get(i.lower().strip()) is not None:
            #print(abbs.get(i.lower().strip()))
            val = val + str(abbs.get(i.lower().strip())) + ' '
        else:
            val = val + i + ' '
    return val

# %%
print(remove_url(df['Text'].iloc[1942]))
# Out:
# Visit  to check the latest #bitcoin price in #gbp #uk #pound. You can also use our free $GBP to $BTC price converter.

# %%
print(replace_currency("@elonmusk Try turkish lira its at the bottom"))
# Out:
# @elonmusk  turkish lira turkish lira its at the bottom

# %%
clean = TextCleaner()

def cleaning(df_cl, stop_words):
    
    # Removing URLs
    df_cl["Text"] = df_cl["Text"].apply(lambda x: remove_url(x))
    
     # Removing mentioned author names
    df_cl["Text"] = df_cl["Text"].apply(lambda x: re.sub("@[A-Za-z0-9]+","", x))
    
    # Lowercase
    df_cl['Text'] = df_cl['Text'].apply(lambda x: ' '.join(x.lower() for x in x.split()))
    
    df_cl["Text"] = df_cl["Text"].apply(lambda x: replace_contractions(x))
    
    df_cl["Text"] = df_cl["Text"].apply(lambda x: replace_currency(x))
    
     # Remove Non -letters
    df_cl['Text'] = df_cl['Text'].apply(lambda x: re.sub(r"[^a-zA-Z0-9]", ' ', x))
    
    # Removing Punctuation
    df_cl["Text"] = df_cl["Text"].apply(lambda x: re.sub(r'[^\w\s]','', x))
    
    # Removing stop words
    df_cl['Text'] = df_cl['Text'].apply(lambda x:' '.join(x for x in x.split() if x not in stop_words))
    
    # Lemmatization
    df_cl['Text'] = df_cl['Text'].apply(lambda x:' '.join([Word(x).lemmatize() for x in x.split()]))
    
    # Emoticons
    df_cl['Text'] = df_cl['Text'].apply(lambda x: clean.convert_emoji_to_text(x))
    
    # Emojis
    df_cl['Text'] = df_cl['Text'].apply(lambda x: clean.convert_emoji_to_text(x))    
    
    # Stemming
    #df_cl['Text'] = df_cl['Text'].apply(lambda x: port_stemmer(x))
    return df_cl

stop_words = stopwords.words('english')

# %%
data_v1 = cleaning(data_v1, stop_words)

# %%
data_v1
# Out:
#                                                    Text Sentiment
# 0                           please come try turkishlira  Positive
# 1     hello registered using turkish citizenship id ...  Positive
# 2     trade weekly bar 200 day moving average breach...  Positive
# 3       turkish lira turkish lira bottom maybe would go  Negative
# 4                     turkish lira fucking turkish lira  Negative
# ...                                                 ...       ...
# 1944  missed last night nye potentially important tw...  Positive
# 1945  gbp usd weekly price forecast british pound lo...  Positive
# 1946  20 0142 zar 1 pound december 31 2020 06 20am s...  Positive
# 1947  gbp eur pound lifted united kingdom approval a...  Positive
# 1948  gbp jpy gbpjpy gbp jpy british pound brexit br...  Positive
#
# [1949 rows x 2 columns]

# %%
common_words = ''
for i in data_v1.Text:
    i = str(i)
    tokens = i.split()
    common_words += " ".join(tokens)+" "
wordcloud = WordCloud(width=1600, height=800).generate(common_words)
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
lb = LabelEncoder()
data_v1['Sentiment'] = lb.fit_transform(data_v1['Sentiment'])

# %%
tokenizer = Tokenizer(num_words=1000, split=' ', lower=True) 
tokenizer.fit_on_texts(data_v1['Text'].values)
X = tokenizer.texts_to_sequences(df['Text'].values)
X = pad_sequences(X)

# %%
y = pd.get_dummies(data_v1['Sentiment'])

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# <h3>Time Series Methodologies</h3>
# <h4>Defining Models</h4>

# %%
models = [ 'SimpleRNN', 'LSTM', 'GRU']

# %%
METRICS = [ 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      km.binary_precision(), 
      km.binary_recall(),
      'mse', 
      'mae', 
      keras.metrics.AUC(name='auc'),
      tfa.metrics.F1Score(num_classes=2, threshold=0.5, average='macro'),
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn')
]
# Out:
# 2022-03-20 17:34:03.855745: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def build_model(nb_words, _model="SimpleRNN", embedding_matrix=None):
    model = Sequential()
    model.add(Embedding(input_dim=1000, output_dim=64, input_length = nb_words))
    if _model == "SimpleRNN":
        model.add(SimpleRNN(128, dropout=0.1, recurrent_dropout=0.1, activation='relu'))
    elif _model == "LSTM":
        model.add(LSTM(100, return_sequences=True))
        model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.1, activation='relu'))
    elif _model == "GRU":
        model.add(GRU(128))
    model.add(Dense(2, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=[METRICS])
    return model

# %%
print(X.shape)
print(y.shape)
# Out:
# (1949, 38)
# (1949, 2)

# %%
x1=np.array(X)
y1=np.array(y)

# %%
tsa_classifiers = []

# %%
output_df = pd.DataFrame(columns=['model', 'accuracy', 'precision', 'recall', 'mse', 'mae', 'auc', 'f1_score', 'prediction time'])

# %%
batch_size = 64
seed = 5
tscv = TimeSeriesSplit(n_splits = seed)

# %%
for idx, mdl in enumerate(models):
    
    accuracy = precision = recall = mse = mae = auc = f1_score_val = prediction_time = 0
    
    print("Model : " + str(mdl))
    model_ = build_model(X.shape[1], mdl, None)
    
    keras_model = KerasClassifier(build_fn=model_)
    keras_model._estimator_type = "classifier"    
    tsa_classifiers.append(( str(mdl), keras_model  ))
    
    print("Model Summary")
    print(model_.summary())
    
    for train_index, test_index in tscv.split(x1,y1):
        X_train, X_test, y_train, y_test = x1[train_index], x1[test_index], y1[train_index], y1[test_index]   
        model_.fit(X_train, y_train, epochs=5, validation_split=0.2, batch_size=batch_size, verbose = 'auto', shuffle=False, validation_data=(X_test,y_test))
        
        start_time = time.time()
        y_pred = model_.predict(X_test)
        end_time = time.time() - start_time
        print("")

        scores = model_.evaluate(X_test, y_test)
        print("%s: %.2f%%" % (model_.metrics_names[1], scores[1]*100))    
        print("")
        accuracy += scores[1]
        precision += scores[2]
        recall += scores[3]
        mse += scores[4]
        mae += scores[5]
        auc += scores[6]
        f1_score_val += scores[7]
        prediction_time += end_time
        
        #print("")
        #print("Time taken to predict the model " + str(end_time))

    output_df = output_df.append([{'model': str(mdl), 'accuracy':accuracy/seed,'precision':precision/seed
                                       ,'recall':recall/seed,'mse':mse/seed,'mae':mae/seed
                                       ,'auc':auc/seed,'f1_score':f1_score_val/seed, 'prediction time': prediction_time/seed}], ignore_index=True)

    yhat = model_.predict_on_batch(X_test)
    #print("yhat[:,1]",yhat[:,1])
    #print("y_test",y_test)
    fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test[:,1], yhat[:,1])
    plt.rcParams["figure.figsize"] = (10,7)
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr_rf, tpr_rf, label=str(mdl) + ' (area = {:.3f})'.format(auc/seed))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.savefig('tsa_roc_curve.png')

    #print(classification_report(y_test.values.argmax(axis=1), y_pred.argmax(axis=1)))
    print("___________________________________________________________________________________")
    print("")
    print("")
    print("")
    
plt.show()
# Out:
# Model : SimpleRNN
# Model Summary
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_11 (Embedding)    (None, 38, 64)            64000
#
#  simple_rnn_5 (SimpleRNN)    (None, 128)               24704
#
#  dense_11 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 88,962
# Trainable params: 88,962
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# /var/folders/33/v0__8kvs301dg744qmtfs33w0000gn/T/ipykernel_9818/2325353505.py:8: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_model = KerasClassifier(build_fn=model_)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /opt/anaconda3/lib/python3.9/site-packages/keras_metrics/metrics.py:26: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return object.__getattribute__(self, name)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 5/5 [==============================] - ETA: 0s - loss: 0.7002 - accuracy: 0.5960 - precision: 0.2604 - recall: 0.0049 - mse: 0.2535 - mae: 0.5032 - auc: 0.6549 - f1_score: 0.4845 - tp: 419.0000 - fp: 284.0000 - tn: 419.0000 - fn: 284.0000WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 5/5 [==============================] - 2s 152ms/step - loss: 0.7002 - accuracy: 0.5960 - precision: 0.2604 - recall: 0.0049 - mse: 0.2535 - mae: 0.5032 - auc: 0.6549 - f1_score: 0.4845 - tp: 419.0000 - fp: 284.0000 - tn: 419.0000 - fn: 284.0000 - val_loss: 0.6542 - val_accuracy: 1.0000 - val_precision: 0.2508 - val_recall: 0.0050 - val_mse: 0.2305 - val_mae: 0.4801 - val_auc: 1.0000 - val_f1_score: 0.5000 - val_tp: 79.0000 - val_fp: 0.0000e+00 - val_tn: 79.0000 - val_fn: 0.0000e+00
# Epoch 2/5
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6334 - accuracy: 0.8503 - precision: 0.2508 - recall: 0.0050 - mse: 0.2202 - mae: 0.4685 - auc: 0.9389 - f1_score: 0.4596 - tp: 267.0000 - fp: 47.0000 - tn: 267.0000 - fn: 47.0000 - val_loss: 0.5609 - val_accuracy: 1.0000 - val_precision: 0.2508 - val_recall: 0.0050 - val_mse: 0.1843 - val_mae: 0.4292 - val_auc: 1.0000 - val_f1_score: 0.5000 - val_tp: 79.0000 - val_fp: 0.0000e+00 - val_tn: 79.0000 - val_fn: 0.0000e+00
# Epoch 3/5
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5425 - accuracy: 0.8503 - precision: 0.2508 - recall: 0.0050 - mse: 0.1763 - mae: 0.4134 - auc: 0.9398 - f1_score: 0.4596 - tp: 267.0000 - fp: 47.0000 - tn: 267.0000 - fn: 47.0000 - val_loss: 0.3690 - val_accuracy: 1.0000 - val_precision: 0.2508 - val_recall: 0.0050 - val_mse: 0.0954 - val_mae: 0.3083 - val_auc: 1.0000 - val_f1_score: 0.5000 - val_tp: 79.0000 - val_fp: 0.0000e+00 - val_tn: 79.0000 - val_fn: 0.0000e+00
# Epoch 4/5
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3876 - accuracy: 0.8503 - precision: 0.2508 - recall: 0.0050 - mse: 0.1166 - mae: 0.2772 - auc: 0.9250 - f1_score: 0.4596 - tp: 267.0000 - fp: 47.0000 - tn: 267.0000 - fn: 47.0000 - val_loss: 0.0676 - val_accuracy: 1.0000 - val_precision: 0.2508 - val_recall: 0.0050 - val_mse: 0.0045 - val_mae: 0.0652 - val_auc: 1.0000 - val_f1_score: 0.5000 - val_tp: 79.0000 - val_fp: 0.0000e+00 - val_tn: 79.0000 - val_fn: 0.0000e+00
# 20/20 [==============================] - 0s 14ms/step - loss: 0.5912 - accuracy: 0.7276 - precision: 0.2623 - recall: 0.0049 - mse: 0.2006 - mae: 0.4137 - auc: 0.7290 - f1_score: 0.4430 - tp: 908.0000 - fp: 340.0000 - tn: 908.0000 - fn: 340.0000 - val_loss: 0.8623 - val_accuracy: 0.4006 - val_precision: 0.2625 - val_recall: 0.0049 - val_mse: 0.3280 - val_mae: 0.5361 - val_auc: 0.4223 - val_f1_score: 0.2860 - val_tp: 125.0000 - val_fp: 187.0000 - val_tn: 125.0000 - val_fn: 187.0000
# Epoch 4/5
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5876 - accuracy: 0.7284 - precision: 0.2669 - recall: 0.0050 - mse: 0.1990 - mae: 0.4070 - auc: 0.7315 - f1_score: 0.4407 - tp: 909.0000 - fp: 339.0000 - tn: 909.0000 - fn: 339.0000 - val_loss: 0.8755 - val_accuracy: 0.4006 - val_precision: 0.2671 - val_recall: 0.0050 - val_mse: 0.3335 - val_mae: 0.5377 - val_auc: 0.4229 - val_f1_score: 0.2860 - val_tp: 125.0000 - val_fp: 187.0000 - val_tn: 125.0000 - val_fn: 187.0000
# Epoch 5/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.5855 - accuracy: 0.7276 - precision: 0.2717 - recall: 0.0051 - mse: 0.1981 - mae: 0.4056 - auc: 0.7400 - f1_score: 0.4404 - tp: 908.0000 - fp: 340.0000 - tn: 908.0000 - fn: 340.0000 - val_loss: 0.8725 - val_accuracy: 0.4006 - val_precision: 0.2714 - val_recall: 0.0051 - val_mse: 0.3322 - val_mae: 0.5375 - val_auc: 0.4195 - val_f1_score: 0.2860 - val_tp: 125.0000 - val_fp: 187.0000 - val_tn: 125.0000 - val_fn: 187.0000
#
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6031 - accuracy: 0.7095 - precision: 0.2714 - recall: 0.0051 - mse: 0.2064 - mae: 0.4138 - auc: 0.7193 - f1_score: 0.4150 - tp: 276.0000 - fp: 113.0000 - tn: 276.0000 - fn: 113.0000
# accuracy: 70.95%
#
# ___________________________________________________________________________________
#
#
#
# Model : LSTM
# Model Summary
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_12 (Embedding)    (None, 38, 64)            64000
#
#  lstm_6 (LSTM)               (None, 38, 100)           66000
#
#  lstm_7 (LSTM)               (None, 128)               117248
#
#  dense_12 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 247,506
# Trainable params: 247,506
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# /var/folders/33/v0__8kvs301dg744qmtfs33w0000gn/T/ipykernel_9818/2325353505.py:8: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_model = KerasClassifier(build_fn=model_)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /opt/anaconda3/lib/python3.9/site-packages/keras_metrics/metrics.py:26: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return object.__getattribute__(self, name)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 5/5 [==============================] - ETA: 0s - loss: 0.6645 - accuracy: 0.7511 - precision: 0.2740 - recall: 0.0053 - mse: 0.2357 - mae: 0.4853 - auc: 0.7560 - f1_score: 0.5003 - tp: 528.0000 - fp: 175.0000 - tn: 528.0000 - fn: 175.0000WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 5/5 [==============================] - 5s 342ms/step - loss: 0.6645 - accuracy: 0.7511 - precision: 0.2740 - recall: 0.0053 - mse: 0.2357 - mae: 0.4853 - auc: 0.7560 - f1_score: 0.5003 - tp: 528.0000 - fp: 175.0000 - tn: 528.0000 - fn: 175.0000 - val_loss: 0.5880 - val_accuracy: 1.0000 - val_precision: 0.2740 - val_recall: 0.0053 - val_mse: 0.1976 - val_mae: 0.4445 - val_auc: 1.0000 - val_f1_score: 0.5000 - val_tp: 79.0000 - val_fp: 0.0000e+00 - val_tn: 79.0000 - val_fn: 0.0000e+00
# Epoch 2/5
# 5/5 [==============================] - 1s 112ms/step - loss: 0.5064 - accuracy: 0.8503 - precision: 0.2740 - recall: 0.0053 - mse: 0.1610 - mae: 0.3888 - auc: 0.9390 - f1_score: 0.4596 - tp: 267.0000 - fp: 47.0000 - tn: 267.0000 - fn: 47.0000 - val_loss: 0.1191 - val_accuracy: 1.0000 - val_precision: 0.2740 - val_recall: 0.0053 - val_mse: 0.0129 - val_mae: 0.1120 - val_auc: 1.0000 - val_f1_score: 0.5000 - val_tp: 79.0000 - val_fp: 0.0000e+00 - val_tn: 79.0000 - val_fn: 0.0000e+00
# Epoch 3/5
# 5/5 [==============================] - 0s 90ms/step - loss: 0.4755 - accuracy: 0.8503 - precision: 0.2740 - recall: 0.0053 - mse: 0.1407 - mae: 0.2718 - auc: 0.7718 - f1_score: 0.4596 - tp: 267.0000 - fp: 47.0000 - tn: 267.0000 - fn: 47.0000 - val_loss: 0.1947 - val_accuracy: 1.0000 - val_precision: 0.2740 - val_recall: 0.0053 - val_mse: 0.0315 - val_mae: 0.1767 - val_auc: 1.0000 - val_f1_score: 0.5000 - val_tp: 79.0000 - val_fp: 0.0000e+00 - val_tn: 79.0000 - val_fn: 0.0000e+00
# Epoch 4/5
# Epoch 3/5
# 20/20 [==============================] - 2s 103ms/step - loss: 0.5971 - accuracy: 0.7236 - precision: 0.2740 - recall: 0.0049 - mse: 0.2032 - mae: 0.4189 - auc: 0.7090 - f1_score: 0.4198 - tp: 903.0000 - fp: 345.0000 - tn: 903.0000 - fn: 345.0000 - val_loss: 0.8663 - val_accuracy: 0.4038 - val_precision: 0.2740 - val_recall: 0.0049 - val_mse: 0.3301 - val_mae: 0.5378 - val_auc: 0.4240 - val_f1_score: 0.2877 - val_tp: 126.0000 - val_fp: 186.0000 - val_tn: 126.0000 - val_fn: 186.0000
# Epoch 4/5
# 20/20 [==============================] - 2s 111ms/step - loss: 0.5924 - accuracy: 0.7236 - precision: 0.2740 - recall: 0.0049 - mse: 0.2011 - mae: 0.4100 - auc: 0.7157 - f1_score: 0.4198 - tp: 903.0000 - fp: 345.0000 - tn: 903.0000 - fn: 345.0000 - val_loss: 0.8775 - val_accuracy: 0.4038 - val_precision: 0.2740 - val_recall: 0.0049 - val_mse: 0.3347 - val_mae: 0.5392 - val_auc: 0.4265 - val_f1_score: 0.2877 - val_tp: 126.0000 - val_fp: 186.0000 - val_tn: 126.0000 - val_fn: 186.0000
# Epoch 5/5
# 20/20 [==============================] - 3s 135ms/step - loss: 0.5912 - accuracy: 0.7236 - precision: 0.2740 - recall: 0.0049 - mse: 0.2006 - mae: 0.4099 - auc: 0.7217 - f1_score: 0.4198 - tp: 903.0000 - fp: 345.0000 - tn: 903.0000 - fn: 345.0000 - val_loss: 0.8715 - val_accuracy: 0.4038 - val_precision: 0.2740 - val_recall: 0.0048 - val_mse: 0.3322 - val_mae: 0.5384 - val_auc: 0.4230 - val_f1_score: 0.2877 - val_tp: 126.0000 - val_fp: 186.0000 - val_tn: 126.0000 - val_fn: 186.0000
#
# 13/13 [==============================] - 0s 24ms/step - loss: 0.6026 - accuracy: 0.7095 - precision: 0.2740 - recall: 0.0048 - mse: 0.2061 - mae: 0.4133 - auc: 0.7130 - f1_score: 0.4150 - tp: 276.0000 - fp: 113.0000 - tn: 276.0000 - fn: 113.0000
# accuracy: 70.95%
#
# ___________________________________________________________________________________
#
#
#
# Model : GRU
# Model Summary
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_13 (Embedding)    (None, 38, 64)            64000
#
#  gru_3 (GRU)                 (None, 128)               74496
#
#  dense_13 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 138,754
# Trainable params: 138,754
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# /var/folders/33/v0__8kvs301dg744qmtfs33w0000gn/T/ipykernel_9818/2325353505.py:8: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_model = KerasClassifier(build_fn=model_)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /opt/anaconda3/lib/python3.9/site-packages/keras_metrics/metrics.py:26: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return object.__getattribute__(self, name)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 5/5 [==============================] - ETA: 0s - loss: 0.6353 - accuracy: 0.7354 - precision: 0.2753 - recall: 0.0051 - mse: 0.2212 - mae: 0.4694 - auc: 0.7531 - f1_score: 0.5061 - tp: 517.0000 - fp: 186.0000 - tn: 517.0000 - fn: 186.0000WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 5/5 [==============================] - 4s 263ms/step - loss: 0.6353 - accuracy: 0.7354 - precision: 0.2753 - recall: 0.0051 - mse: 0.2212 - mae: 0.4694 - auc: 0.7531 - f1_score: 0.5061 - tp: 517.0000 - fp: 186.0000 - tn: 517.0000 - fn: 186.0000 - val_loss: 0.5167 - val_accuracy: 1.0000 - val_precision: 0.2753 - val_recall: 0.0051 - val_mse: 0.1629 - val_mae: 0.4034 - val_auc: 1.0000 - val_f1_score: 0.5000 - val_tp: 79.0000 - val_fp: 0.0000e+00 - val_tn: 79.0000 - val_fn: 0.0000e+00
# Epoch 2/5
# 5/5 [==============================] - 0s 53ms/step - loss: 0.5036 - accuracy: 0.8503 - precision: 0.2753 - recall: 0.0051 - mse: 0.1587 - mae: 0.3868 - auc: 0.9442 - f1_score: 0.4596 - tp: 267.0000 - fp: 47.0000 - tn: 267.0000 - fn: 47.0000 - val_loss: 0.2982 - val_accuracy: 1.0000 - val_precision: 0.2753 - val_recall: 0.0051 - val_mse: 0.0669 - val_mae: 0.2574 - val_auc: 1.0000 - val_f1_score: 0.5000 - val_tp: 79.0000 - val_fp: 0.0000e+00 - val_tn: 79.0000 - val_fn: 0.0000e+00
# Epoch 3/5
# Epoch 3/5
# 10/10 [==============================] - 1s 52ms/step - loss: 0.5569 - accuracy: 0.7504 - precision: 0.2753 - recall: 0.0051 - mse: 0.1852 - mae: 0.3842 - auc: 0.7654 - f1_score: 0.4287 - tp: 469.0000 - fp: 156.0000 - tn: 469.0000 - fn: 156.0000 - val_loss: 0.5146 - val_accuracy: 0.8025 - val_precision: 0.2753 - val_recall: 0.0051 - val_mse: 0.1656 - val_mae: 0.3661 - val_auc: 0.8361 - val_f1_score: 0.4452 - val_tp: 126.0000 - val_fp: 31.0000 - val_tn: 126.0000 - val_fn: 31.0000
# Epoch 4/5
# 10/10 [==============================] - 1s 55ms/step - loss: 0.5593 - accuracy: 0.7504 - precision: 0.2753 - recall: 0.0050 - mse: 0.1860 - mae: 0.3827 - auc: 0.7565 - f1_score: 0.4287 - tp: 469.0000 - fp: 156.0000 - tn: 469.0000 - fn: 156.0000 - val_loss: 0.5084 - val_accuracy: 0.8025 - val_precision: 0.2753 - val_recall: 0.0050 - val_mse: 0.1633 - val_mae: 0.3559 - val_auc: 0.8240 - val_f1_score: 0.4452 - val_tp: 126.0000 - val_fp: 31.0000 - val_tn: 126.0000 - val_fn: 31.0000
# Epoch 5/5
# 10/10 [==============================] - 0s 46ms/step - loss: 0.5578 - accuracy: 0.7504 - precision: 0.2753 - recall: 0.0050 - mse: 0.1853 - mae: 0.3729 - auc: 0.7568 - f1_score: 0.4287 - tp: 469.0000 - fp: 156.0000 - tn: 469.0000 - fn: 156.0000 - val_loss: 0.5035 - val_accuracy: 0.8025 - val_precision: 0.2753 - val_recall: 0.0050 - val_mse: 0.1614 - val_mae: 0.3455 - val_auc: 0.8251 - val_f1_score: 0.4452 - val_tp: 126.0000 - val_fp: 31.0000 - val_tn: 126.0000 - val_fn: 31.0000
#
# 13/13 [==============================] - 0s 8ms/step - loss: 0.6276 - accuracy: 0.6967 - precision: 0.2753 - recall: 0.0050 - mse: 0.2163 - mae: 0.3985 - auc: 0.6971 - f1_score: 0.4187 - tp: 271.0000 - fp: 118.0000 - tn: 271.0000 - fn: 118.0000
# accuracy: 69.67%
#
# Epoch 1/5
# 15/15 [==============================] - 1s 56ms/step - loss: 0.5144 - accuracy: 0.7895 - precision: 0.2758 - recall: 0.0050 - mse: 0.1661 - mae: 0.3467 - auc: 0.7992 - f1_score: 0.4461 - tp: 739.0000 - fp: 197.0000 - tn: 739.0000 - fn: 197.0000 - val_loss: 0.8135 - val_accuracy: 0.5447 - val_precision: 0.2761 - val_recall: 0.0050 - val_mse: 0.2981 - val_mae: 0.4761 - val_auc: 0.5399 - val_f1_score: 0.3610 - val_tp: 128.0000 - val_fp: 107.0000 - val_tn: 128.0000 - val_fn: 107.0000
# Epoch 2/5
# Epoch 2/5
# 20/20 [==============================] - 1s 49ms/step - loss: 0.5873 - accuracy: 0.7236 - precision: 0.2808 - recall: 0.0051 - mse: 0.1992 - mae: 0.4104 - auc: 0.7487 - f1_score: 0.4281 - tp: 903.0000 - fp: 345.0000 - tn: 903.0000 - fn: 345.0000 - val_loss: 0.8400 - val_accuracy: 0.4038 - val_precision: 0.2815 - val_recall: 0.0051 - val_mse: 0.3187 - val_mae: 0.5333 - val_auc: 0.4249 - val_f1_score: 0.2877 - val_tp: 126.0000 - val_fp: 186.0000 - val_tn: 126.0000 - val_fn: 186.0000
# Epoch 3/5
# 20/20 [==============================] - 1s 55ms/step - loss: 0.5958 - accuracy: 0.7244 - precision: 0.2819 - recall: 0.0051 - mse: 0.2026 - mae: 0.4169 - auc: 0.7162 - f1_score: 0.4229 - tp: 904.0000 - fp: 344.0000 - tn: 904.0000 - fn: 344.0000 - val_loss: 0.8651 - val_accuracy: 0.4038 - val_precision: 0.2821 - val_recall: 0.0050 - val_mse: 0.3293 - val_mae: 0.5369 - val_auc: 0.4245 - val_f1_score: 0.2877 - val_tp: 126.0000 - val_fp: 186.0000 - val_tn: 126.0000 - val_fn: 186.0000
# Epoch 4/5
# 20/20 [==============================] - 1s 56ms/step - loss: 0.5921 - accuracy: 0.7236 - precision: 0.2821 - recall: 0.0050 - mse: 0.2010 - mae: 0.4094 - auc: 0.7196 - f1_score: 0.4198 - tp: 903.0000 - fp: 345.0000 - tn: 903.0000 - fn: 345.0000 - val_loss: 0.8786 - val_accuracy: 0.4038 - val_precision: 0.2821 - val_recall: 0.0050 - val_mse: 0.3349 - val_mae: 0.5388 - val_auc: 0.4216 - val_f1_score: 0.2877 - val_tp: 126.0000 - val_fp: 186.0000 - val_tn: 126.0000 - val_fn: 186.0000
# Epoch 5/5
# 20/20 [==============================] - 1s 61ms/step - loss: 0.5903 - accuracy: 0.7236 - precision: 0.2821 - recall: 0.0050 - mse: 0.2003 - mae: 0.4078 - auc: 0.7274 - f1_score: 0.4198 - tp: 903.0000 - fp: 345.0000 - tn: 903.0000 - fn: 345.0000 - val_loss: 0.8764 - val_accuracy: 0.4038 - val_precision: 0.2821 - val_recall: 0.0050 - val_mse: 0.3340 - val_mae: 0.5387 - val_auc: 0.4242 - val_f1_score: 0.2877 - val_tp: 126.0000 - val_fp: 186.0000 - val_tn: 126.0000 - val_fn: 186.0000
#
# 13/13 [==============================] - 0s 16ms/step - loss: 0.6020 - accuracy: 0.7095 - precision: 0.2821 - recall: 0.0049 - mse: 0.2059 - mae: 0.4115 - auc: 0.7248 - f1_score: 0.4150 - tp: 276.0000 - fp: 113.0000 - tn: 276.0000 - fn: 113.0000
# accuracy: 70.95%
#
# ___________________________________________________________________________________

# %%
output_df
# Out:
#        model  accuracy  precision    recall       mse       mae       auc  \
# 0  SimpleRNN  0.616324   0.249307  0.005510  0.266941  0.443911  0.631003
# 1       LSTM  0.616324   0.249307  0.004660  0.267550  0.442977  0.625981
# 2        GRU  0.616324   0.261745  0.004374  0.284660  0.441078  0.631099
# 3  SimpleRNN  0.616324   0.255928  0.004917  0.261225  0.444737  0.628431
# 4       LSTM  0.616324   0.274025  0.005098  0.268403  0.437332  0.627854
# 5        GRU  0.615681   0.277980  0.005029  0.272429  0.437300  0.630511
#
#    f1_score  prediction time
# 0  0.377707         0.082429
# 1  0.377707         0.310780
# 2  0.377707         0.144457
# 3  0.377707         0.073767
# 4  0.377707         0.344053
# 5  0.380404         0.202638

# %% [markdown]
# <h3>Traditional Methodologies</h3>

# %%
stemmer = PorterStemmer()
analyzer = CountVectorizer().build_analyzer()
def stemmed_words(doc):
    stemmed_words = [stemmer.stem(w) for w in analyzer(doc)]
    non_stop_words = [word for word in stemmed_words]
    return non_stop_words

# %%
count_vectorizer = CountVectorizer(stop_words= stop_words, max_features= 1000)
feature_vector = count_vectorizer.fit(data_v1['Text'])
train_ds_features = count_vectorizer.transform(data_v1['Text'])
features = feature_vector.get_feature_names()
features_counts = np.sum(train_ds_features.toarray(), axis = 0)
features_counts = pd.DataFrame(dict(features =  features, counts = features_counts))
features_counts = features_counts.sort_values("counts", ascending= False)[0:15]
features_counts
# Out:
#      features  counts
# 333      euro    1461
# 329       eur    1374
# 675     pound    1217
# 420       gbp    1119
# 924       usd    1055
# 297    dollar     580
# 381     forex     410
# 379  forecast     384
# 187   british     374
# 684     price     364
# 711      rate     342
# 265  currency     256
# 308       ecb     242
# 337    eurusd     236
# 627   outlook     226

# %%
train_x, test_x, train_y, test_y =  train_test_split(train_ds_features, data_v1['Sentiment'], test_size = 0.3, random_state = 42)

# %%
x = train_ds_features
y = data_v1['Sentiment']

# %%
tsa_classifiers
# Out:
# [('SimpleRNN',
#   <keras.wrappers.scikit_learn.KerasClassifier at 0x7fb8c98727f0>),
#  ('LSTM', <keras.wrappers.scikit_learn.KerasClassifier at 0x7fb8ea7f8160>),
#  ('GRU', <keras.wrappers.scikit_learn.KerasClassifier at 0x7fb88a911c40>)]

# %%
classifiers = {
    "BernoulliNB": BernoulliNB(),
    "ComplementNB": ComplementNB(),
    "MultinomialNB": MultinomialNB(),
    "LogisticRegression": LogisticRegression(),
    "KNeighborsClassifier": KNeighborsClassifier(),
    "DecisionTreeClassifier": DecisionTreeClassifier(),
    "RandomForestClassifier": RandomForestClassifier(),
    "MLPClassifier": MLPClassifier(max_iter=1000),
    "AdaBoostClassifier": AdaBoostClassifier()
}
estimators = []
for name, sklearn_classifier in classifiers.items():
    estimators.append((name,sklearn_classifier))

stacking_clf = StackingClassifier(estimators=estimators, final_estimator=RandomForestClassifier())

voting_clf = VotingClassifier(
        estimators=estimators,
        voting="hard")
classifiers['VotingClassifier'] = voting_clf
classifiers['StackingClassifier'] = stacking_clf
classifiers
# Out:
# {'BernoulliNB': BernoulliNB(),
#  'ComplementNB': ComplementNB(),
#  'MultinomialNB': MultinomialNB(),
#  'LogisticRegression': LogisticRegression(),
#  'KNeighborsClassifier': KNeighborsClassifier(),
#  'DecisionTreeClassifier': DecisionTreeClassifier(),
#  'RandomForestClassifier': RandomForestClassifier(),
#  'MLPClassifier': MLPClassifier(max_iter=1000),
#  'AdaBoostClassifier': AdaBoostClassifier(),
#  'VotingClassifier': VotingClassifier(estimators=[('BernoulliNB', BernoulliNB()),
#                               ('ComplementNB', ComplementNB()),
#                               ('MultinomialNB', MultinomialNB()),
#                               ('LogisticRegression', LogisticRegression()),
#                               ('KNeighborsClassifier', KNeighborsClassifier()),
#                               ('DecisionTreeClassifier',
#                                DecisionTreeClassifier()),
#                               ('RandomForestClassifier',
#                                RandomForestClassifier()),
#                               ('MLPClassifier', MLPClassifier(max_iter=1000)),
#                               ('AdaBoostClassifier', AdaBoostClassifier())]),
#  'StackingClassifier': StackingClassifier(estimators=[('BernoulliNB', BernoulliNB()),
#                                 ('ComplementNB', ComplementNB()),
#                                 ('MultinomialNB', MultinomialNB()),
#                                 ('LogisticRegression', LogisticRegression()),
#                                 ('KNeighborsClassifier', KNeighborsClassifier()),
#                                 ('DecisionTreeClassifier',
#                                  DecisionTreeClassifier()),
#                                 ('RandomForestClassifier',
#                                  RandomForestClassifier()),
#                                 ('MLPClassifier', MLPClassifier(max_iter=1000)),
#                                 ('AdaBoostClassifier', AdaBoostClassifier())],
#                     final_estimator=RandomForestClassifier())}

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import precision_score, \
    recall_score, confusion_matrix, classification_report, \
    accuracy_score, f1_score

kfold = KFold(seed, True, 7)
#cvscores = []

for name, sklearn_classifier in classifiers.items():
    print("Classifier : ", name)
    accuracy = precision = recall = mse = mae = auc = f1_score_val = prediction_time = 0
    
    for train_index, test_index in kfold.split(x):
        train_x, test_x, train_y, test_y = x[train_index], x[test_index], y[train_index], y[test_index]       
    
        sklearn_classifier.fit(train_x.toarray(), train_y)
        start_time = time.time()
        test_ds_predicted = sklearn_classifier.predict(test_x.toarray())
        end_time = time.time() - start_time
        print(metrics.classification_report(test_y, test_ds_predicted))
        print("")
        print("Time taken to predict the model " + str(end_time))
        print("")
        tr_mae = mean_absolute_error(test_y, test_ds_predicted)
        tr_mse = mean_squared_error(test_y, test_ds_predicted)
        tr_accuracy = accuracy_score(test_y, test_ds_predicted)
        tr_f1_score = f1_score(test_y, test_ds_predicted, average='weighted')
        tr_recall = recall_score(test_y, test_ds_predicted, average='weighted')
        tr_precision = precision_score(test_y, test_ds_predicted, average='weighted')
        tr_auc = roc_auc_score(test_y, test_ds_predicted)

        accuracy += tr_accuracy
        precision += tr_precision
        recall += tr_recall
        mse += tr_mse
        mae += tr_mae
        auc += tr_auc
        f1_score_val += tr_f1_score
        prediction_time += end_time
    #print('MAE: %f' % mean_absolute_error(test_y, test_ds_predicted))
    #print('MSE: %f' % mean_squared_error(test_y, test_ds_predicted))
    #print('RMSE: %f' % sqrt(mean_squared_error(test_y, test_ds_predicted)))
    
    
    output_df = output_df.append([{'model': str(name), 'accuracy':accuracy/seed,'precision':precision/seed
                                       ,'recall':recall/seed,'mse':mse/seed,'mae':mae/seed
                                       ,'auc':auc/seed,'f1_score':f1_score_val/seed, 'prediction time': prediction_time/seed}], ignore_index=True)

    if name != 'VotingClassifier':
        yhat = sklearn_classifier.predict_proba(test_x.toarray())
        fpr_rf, tpr_rf, threshold2 = roc_curve(test_y.to_numpy(), yhat[:,1])
        plt.rcParams["figure.figsize"] = (10,7)
        plt.figure(1)
        plt.plot([0, 1], [0, 1], 'k--')
        plt.plot(fpr_rf, tpr_rf, label=str(name) + ' (area = {:.3f})'.format(tr_auc))
        plt.xlabel('False positive rate')
        plt.ylabel('True positive rate')
        plt.title('ROC curve')
        plt.legend(loc='best')
        plt.savefig('td_roc_curve.png')
    
    print("________________________________________________________")
    print("")
    print("")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass shuffle=True, random_state=7 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# Classifier :  BernoulliNB
#               precision    recall  f1-score   support
#
#            0       0.51      0.52      0.51       306
#            1       0.78      0.77      0.77       669
#
#     accuracy                           0.69       975
#    macro avg       0.64      0.64      0.64       975
# weighted avg       0.69      0.69      0.69       975
#
#
# Time taken to predict the model 0.00513911247253418
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.52      0.55       338
#            1       0.76      0.80      0.78       636
#
#     accuracy                           0.70       974
#    macro avg       0.67      0.66      0.66       974
# weighted avg       0.69      0.70      0.70       974
#
#
# Time taken to predict the model 0.008443117141723633
#
# ________________________________________________________
#
#
# Classifier :  ComplementNB
#               precision    recall  f1-score   support
#
#            0       0.50      0.62      0.55       306
#            1       0.80      0.72      0.76       669
#
#     accuracy                           0.69       975
#    macro avg       0.65      0.67      0.66       975
# weighted avg       0.71      0.69      0.69       975
#
#
# Time taken to predict the model 0.00426793098449707
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.59      0.56       338
#            1       0.77      0.73      0.75       636
#
#     accuracy                           0.68       974
#    macro avg       0.65      0.66      0.66       974
# weighted avg       0.69      0.68      0.68       974
#
#
# Time taken to predict the model 0.004647016525268555
#
# ________________________________________________________
#
#
# Classifier :  MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.51      0.54      0.52       306
#            1       0.78      0.76      0.77       669
#
#     accuracy                           0.69       975
#    macro avg       0.64      0.65      0.65       975
# weighted avg       0.70      0.69      0.69       975
#
#
# Time taken to predict the model 0.0058939456939697266
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.52      0.55       338
#            1       0.76      0.80      0.78       636
#
#     accuracy                           0.70       974
#    macro avg       0.67      0.66      0.66       974
# weighted avg       0.70      0.70      0.70       974
#
#
# Time taken to predict the model 0.003958225250244141
#
# ________________________________________________________
#
#
# Classifier :  LogisticRegression
#               precision    recall  f1-score   support
#
#            0       0.58      0.48      0.52       306
#            1       0.78      0.84      0.81       669
#
#     accuracy                           0.73       975
#    macro avg       0.68      0.66      0.67       975
# weighted avg       0.72      0.73      0.72       975
#
#
# Time taken to predict the model 0.0027573108673095703
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.41      0.50       338
#            1       0.74      0.88      0.80       636
#
#     accuracy                           0.72       974
#    macro avg       0.69      0.64      0.65       974
# weighted avg       0.70      0.72      0.70       974
#
#
# Time taken to predict the model 0.0013928413391113281
#
# ________________________________________________________
#
#
# Classifier :  KNeighborsClassifier
#               precision    recall  f1-score   support
#
#            0       0.46      0.46      0.46       306
#            1       0.75      0.75      0.75       669
#
#     accuracy                           0.66       975
#    macro avg       0.60      0.61      0.61       975
# weighted avg       0.66      0.66      0.66       975
#
#
# Time taken to predict the model 0.044450998306274414
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.39      0.47       338
#            1       0.72      0.85      0.78       636
#
#     accuracy                           0.69       974
#    macro avg       0.65      0.62      0.62       974
# weighted avg       0.67      0.69      0.67       974
#
#
# Time taken to predict the model 0.05437278747558594
#
# ________________________________________________________
#
#
# Classifier :  DecisionTreeClassifier
#               precision    recall  f1-score   support
#
#            0       0.48      0.53      0.50       306
#            1       0.77      0.74      0.76       669
#
#     accuracy                           0.67       975
#    macro avg       0.63      0.63      0.63       975
# weighted avg       0.68      0.67      0.68       975
#
#
# Time taken to predict the model 0.004487752914428711
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.46      0.50       338
#            1       0.74      0.81      0.77       636
#
#     accuracy                           0.69       974
#    macro avg       0.65      0.63      0.64       974
# weighted avg       0.68      0.69      0.68       974
#
#
# Time taken to predict the model 0.004307985305786133
#
# ________________________________________________________
#
#
# Classifier :  RandomForestClassifier
#               precision    recall  f1-score   support
#
#            0       0.60      0.44      0.51       306
#            1       0.77      0.87      0.82       669
#
#     accuracy                           0.73       975
#    macro avg       0.69      0.65      0.66       975
# weighted avg       0.72      0.73      0.72       975
#
#
# Time taken to predict the model 0.029386043548583984
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.42      0.53       338
#            1       0.75      0.92      0.82       636
#
#     accuracy                           0.74       974
#    macro avg       0.74      0.67      0.68       974
# weighted avg       0.74      0.74      0.72       974
#
#
# Time taken to predict the model 0.026875972747802734
#
# ________________________________________________________
#
#
# Classifier :  MLPClassifier
#               precision    recall  f1-score   support
#
#            0       0.54      0.50      0.52       306
#            1       0.78      0.81      0.79       669
#
#     accuracy                           0.71       975
#    macro avg       0.66      0.65      0.66       975
# weighted avg       0.71      0.71      0.71       975
#
#
# Time taken to predict the model 0.0041730403900146484
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.53      0.57       338
#            1       0.77      0.82      0.79       636
#
#     accuracy                           0.72       974
#    macro avg       0.69      0.67      0.68       974
# weighted avg       0.71      0.72      0.71       974
#
#
# Time taken to predict the model 0.006789207458496094
#
# ________________________________________________________
#
#
# Classifier :  AdaBoostClassifier
#               precision    recall  f1-score   support
#
#            0       0.54      0.33      0.41       306
#            1       0.74      0.87      0.80       669
#
#     accuracy                           0.70       975
#    macro avg       0.64      0.60      0.61       975
# weighted avg       0.68      0.70      0.68       975
#
#
# Time taken to predict the model 0.12121272087097168
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.25      0.37       338
#            1       0.70      0.94      0.80       636
#
#     accuracy                           0.70       974
#    macro avg       0.69      0.59      0.58       974
# weighted avg       0.69      0.70      0.65       974
#
#
# Time taken to predict the model 0.09916520118713379
#
# ________________________________________________________
#
#
# Classifier :  VotingClassifier
#               precision    recall  f1-score   support
#
#            0       0.53      0.46      0.49       306
#            1       0.77      0.82      0.79       669
#
#     accuracy                           0.70       975
#    macro avg       0.65      0.64      0.64       975
# weighted avg       0.69      0.70      0.70       975
#
#
# Time taken to predict the model 0.17263007164001465
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.44      0.53       338
#            1       0.75      0.88      0.81       636
#
#     accuracy                           0.73       974
#    macro avg       0.71      0.66      0.67       974
# weighted avg       0.72      0.73      0.71       974
#
#
# Time taken to predict the model 0.16195297241210938
#
# ________________________________________________________
#
#
# Classifier :  StackingClassifier
#               precision    recall  f1-score   support
#
#            0       0.43      0.24      0.31       306
#            1       0.71      0.86      0.78       669
#
#     accuracy                           0.66       975
#    macro avg       0.57      0.55      0.54       975
# weighted avg       0.62      0.66      0.63       975
#
#
# Time taken to predict the model 0.15459299087524414
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.25      0.35       338
#            1       0.69      0.90      0.78       636
#
#     accuracy                           0.68       974
#    macro avg       0.63      0.58      0.57       974
# weighted avg       0.65      0.68      0.63       974
#
#
# Time taken to predict the model 0.15219497680664062
#
# ________________________________________________________

# %%
output_df
# Out:
#                      model  accuracy  precision    recall       mse       mae  \
# 0                SimpleRNN  0.624037   0.267442  0.016916  0.252407  0.437068
# 1                     LSTM  0.624037   0.267442  0.004582  0.256348  0.433975
# 2                      GRU  0.624037   0.320000  0.003824  0.253851  0.435903
# 3              BernoulliNB  0.696257   0.694001  0.696257  0.303743  0.303743
# 4             ComplementNB  0.683939   0.699234  0.683939  0.316061  0.316061
# 5            MultinomialNB  0.696771   0.696257  0.696771  0.303229  0.303229
# 6       LogisticRegression  0.721393   0.709925  0.721393  0.278607  0.278607
# 7     KNeighborsClassifier  0.674713   0.667270  0.674713  0.325287  0.325287
# 8   DecisionTreeClassifier  0.679326   0.678616  0.679326  0.320674  0.320674
# 9   RandomForestClassifier  0.738330   0.729375  0.738330  0.261670  0.261670
# 10           MLPClassifier  0.715240   0.708322  0.715240  0.284760  0.284760
# 11      AdaBoostClassifier  0.700359   0.685763  0.700359  0.299641  0.299641
# 12        VotingClassifier  0.716784   0.706864  0.716784  0.283216  0.283216
# 13      StackingClassifier  0.669064   0.637821  0.669064  0.330936  0.330936
#
#          auc  f1_score  prediction time
# 0   0.632586  0.384245         0.127459
# 1   0.626197  0.384245         0.662915
# 2   0.631715  0.384245         0.334584
# 3   0.651477  0.694646         0.006791
# 4   0.664103  0.689361         0.004457
# 5   0.654549  0.695848         0.004926
# 6   0.651127  0.707670         0.002075
# 7   0.612803  0.665882         0.049412
# 8   0.633599  0.677383         0.004398
# 9   0.660395  0.721043         0.028131
# 10  0.663570  0.710660         0.005481
# 11  0.597525  0.664631         0.110189
# 12  0.650304  0.705618         0.167292
# 13  0.561872  0.631400         0.153394

# %%
output_df.to_csv('classifiers_output_result.csv', sep='\t')
