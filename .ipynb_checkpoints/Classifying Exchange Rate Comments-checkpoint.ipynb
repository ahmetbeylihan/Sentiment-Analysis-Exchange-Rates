# %%
import re
from TextCleaner import TextCleaner
import pandas as pd
import numpy as np
import time
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sn
import keras_metrics as km
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold
from numpy import sqrt 
# %matplotlib inline
import nltk
from langdetect import detect
import contractions
from nltk.corpus import stopwords
from textblob import Word
from sklearn.preprocessing import LabelEncoder
from collections import Counter
from wordcloud import WordCloud
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem.snowball import PorterStemmer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, GRU, SimpleRNN, SpatialDropout1D
from tensorflow.keras.layers import SpatialDropout1D
from tensorflow.keras.layers import Embedding
from tensorflow.python.keras.metrics import Metric
import tensorflow as tf    
import tensorflow_addons as tfa
from tensorflow import keras 
from keras.metrics import Precision, Recall

# Classifiers
from sklearn.naive_bayes import BernoulliNB
from sklearn import metrics
from sklearn.naive_bayes import (
    BernoulliNB,
    ComplementNB,
    MultinomialNB,
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
pd.options.mode.chained_assignment = None  # default='warn'

# %%
df = pd.read_csv('sentiment.csv')
df = df.drop(df.columns[0], axis=1)
df
# Out:
#                Author                                               Text  \
# 0            yusobays  @elonmusk @elonmusk  please Come to TRY₺ #turk...
# 1       BtcTurkDestek  @DrBatal  Hello, if you have registered using ...
# 2      RisingValhalla  “I trade weekly bars. You?”\n\n200 day moving ...
# 3        Erda55203615  @elonmusk Try turkish lira its at the bottom m...
# 4        Erda55203615            @ImTooRealForU TRY FUCKING TURKISH LIRA
# ...               ...                                                ...
# 1944  flyingstocksman  For those of you who missed it last night with...
# 1945         alpeshbp  GBP/USD Weekly Price Forecast – The British Po...
# 1946     campsbay_com  20.0142 ZAR for 1 GBP @ December 31, 2020 at 0...
# 1947       MajorFXNow  GBP/EUR: Pound Lifted by UK Approval of AstraZ...
# 1948     trader_blitz  GBP/JPY | $GBPJPY | $GBP $JPY\n\nBRITISH POUND...
#
#                            Time  Like Count Currency ISO Code  \
# 0     2021-01-31 22:21:58+00:00           1               TRY
# 1     2021-01-30 18:07:15+00:00           0               TRY
# 2     2021-01-30 03:29:59+00:00           0               TRY
# 3     2021-01-29 20:20:49+00:00           0               TRY
# 4     2021-01-29 20:19:36+00:00           0               TRY
# ...                         ...         ...               ...
# 1944  2021-01-01 09:24:17+00:00           0               GBP
# 1945  2021-01-01 07:13:32+00:00           0               GBP
# 1946  2021-01-01 04:20:02+00:00           0               GBP
# 1947  2021-01-01 02:32:32+00:00           0               GBP
# 1948  2021-01-01 00:42:01+00:00           0               GBP
#
#                                                     Url  target
# 0     https://twitter.com/yusobays/status/1356004827...     0.0
# 1     https://twitter.com/BtcTurkDestek/status/13555...     0.0
# 2     https://twitter.com/RisingValhalla/status/1355...     0.0
# 3     https://twitter.com/Erda55203615/status/135524...    -1.0
# 4     https://twitter.com/Erda55203615/status/135524...    -1.0
# ...                                                 ...     ...
# 1944  https://twitter.com/flyingstocksman/status/134...     0.0
# 1945  https://twitter.com/alpeshbp/status/1344904575...     0.0
# 1946  https://twitter.com/campsbay_com/status/134486...     0.0
# 1947  https://twitter.com/MajorFXNow/status/13448338...     0.0
# 1948  https://twitter.com/trader_blitz/status/134480...     0.0
#
# [1949 rows x 7 columns]

# %%
def sentiments(df):
    if df['target'] >= 0:
        return 'Positive'
    elif df['target'] < 0:
        return 'Negative'

# %%
df['Sentiment'] = df.apply(sentiments, axis=1)

# %%
df
# Out:
#                Author                                               Text  \
# 0            yusobays  @elonmusk @elonmusk  please Come to TRY₺ #turk...
# 1       BtcTurkDestek  @DrBatal  Hello, if you have registered using ...
# 2      RisingValhalla  “I trade weekly bars. You?”\n\n200 day moving ...
# 3        Erda55203615  @elonmusk Try turkish lira its at the bottom m...
# 4        Erda55203615            @ImTooRealForU TRY FUCKING TURKISH LIRA
# ...               ...                                                ...
# 1944  flyingstocksman  For those of you who missed it last night with...
# 1945         alpeshbp  GBP/USD Weekly Price Forecast – The British Po...
# 1946     campsbay_com  20.0142 ZAR for 1 GBP @ December 31, 2020 at 0...
# 1947       MajorFXNow  GBP/EUR: Pound Lifted by UK Approval of AstraZ...
# 1948     trader_blitz  GBP/JPY | $GBPJPY | $GBP $JPY\n\nBRITISH POUND...
#
#                            Time  Like Count Currency ISO Code  \
# 0     2021-01-31 22:21:58+00:00           1               TRY
# 1     2021-01-30 18:07:15+00:00           0               TRY
# 2     2021-01-30 03:29:59+00:00           0               TRY
# 3     2021-01-29 20:20:49+00:00           0               TRY
# 4     2021-01-29 20:19:36+00:00           0               TRY
# ...                         ...         ...               ...
# 1944  2021-01-01 09:24:17+00:00           0               GBP
# 1945  2021-01-01 07:13:32+00:00           0               GBP
# 1946  2021-01-01 04:20:02+00:00           0               GBP
# 1947  2021-01-01 02:32:32+00:00           0               GBP
# 1948  2021-01-01 00:42:01+00:00           0               GBP
#
#                                                     Url  target Sentiment
# 0     https://twitter.com/yusobays/status/1356004827...     0.0  Positive
# 1     https://twitter.com/BtcTurkDestek/status/13555...     0.0  Positive
# 2     https://twitter.com/RisingValhalla/status/1355...     0.0  Positive
# 3     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# 4     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# ...                                                 ...     ...       ...
# 1944  https://twitter.com/flyingstocksman/status/134...     0.0  Positive
# 1945  https://twitter.com/alpeshbp/status/1344904575...     0.0  Positive
# 1946  https://twitter.com/campsbay_com/status/134486...     0.0  Positive
# 1947  https://twitter.com/MajorFXNow/status/13448338...     0.0  Positive
# 1948  https://twitter.com/trader_blitz/status/134480...     0.0  Positive
#
# [1949 rows x 8 columns]

# %%
data_v1 = df[['Text','Sentiment']]
data_v1.isnull().sum()
# Out:
# Text         0
# Sentiment    0
# dtype: int64

# %%
plt.figure(figsize=(7,8))
plt.title("Number of records of positive and negative sentiments")
plot = sn.countplot(x = 'Sentiment', data = data_v1)
for p in plot.patches:
    plot.annotate(p.get_height(),(p.get_x() + 0.2 ,p.get_height()+80))

# %%
clean = TextCleaner()
text = clean.convert_emoji_to_text("Hilarious 😂. The feeling of making a sale 😎, The feeling of actually fulfilling orders 😒")
print(text)

text4 = "Hello :-) :-)"
resp = clean.convert_emoticons(text4)
print(resp)
# Out:
# Hilarious face with tears of joy. The feeling of making a sale smiling face with sunglasses, The feeling of actually fulfilling orders unamused face
# Hello Happy face smiley Happy face smiley

# %%
df
# Out:
#                Author                                               Text  \
# 0            yusobays  @elonmusk @elonmusk  please Come to TRY₺ #turk...
# 1       BtcTurkDestek  @DrBatal  Hello, if you have registered using ...
# 2      RisingValhalla  “I trade weekly bars. You?”\n\n200 day moving ...
# 3        Erda55203615  @elonmusk Try turkish lira its at the bottom m...
# 4        Erda55203615            @ImTooRealForU TRY FUCKING TURKISH LIRA
# ...               ...                                                ...
# 1944  flyingstocksman  For those of you who missed it last night with...
# 1945         alpeshbp  GBP/USD Weekly Price Forecast – The British Po...
# 1946     campsbay_com  20.0142 ZAR for 1 GBP @ December 31, 2020 at 0...
# 1947       MajorFXNow  GBP/EUR: Pound Lifted by UK Approval of AstraZ...
# 1948     trader_blitz  GBP/JPY | $GBPJPY | $GBP $JPY\n\nBRITISH POUND...
#
#                            Time  Like Count Currency ISO Code  \
# 0     2021-01-31 22:21:58+00:00           1               TRY
# 1     2021-01-30 18:07:15+00:00           0               TRY
# 2     2021-01-30 03:29:59+00:00           0               TRY
# 3     2021-01-29 20:20:49+00:00           0               TRY
# 4     2021-01-29 20:19:36+00:00           0               TRY
# ...                         ...         ...               ...
# 1944  2021-01-01 09:24:17+00:00           0               GBP
# 1945  2021-01-01 07:13:32+00:00           0               GBP
# 1946  2021-01-01 04:20:02+00:00           0               GBP
# 1947  2021-01-01 02:32:32+00:00           0               GBP
# 1948  2021-01-01 00:42:01+00:00           0               GBP
#
#                                                     Url  target Sentiment
# 0     https://twitter.com/yusobays/status/1356004827...     0.0  Positive
# 1     https://twitter.com/BtcTurkDestek/status/13555...     0.0  Positive
# 2     https://twitter.com/RisingValhalla/status/1355...     0.0  Positive
# 3     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# 4     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# ...                                                 ...     ...       ...
# 1944  https://twitter.com/flyingstocksman/status/134...     0.0  Positive
# 1945  https://twitter.com/alpeshbp/status/1344904575...     0.0  Positive
# 1946  https://twitter.com/campsbay_com/status/134486...     0.0  Positive
# 1947  https://twitter.com/MajorFXNow/status/13448338...     0.0  Positive
# 1948  https://twitter.com/trader_blitz/status/134480...     0.0  Positive
#
# [1949 rows x 8 columns]

# %%
def remove_url(text):
    result = re.sub(r'https?:\/\/\S*', '', text, flags=re.MULTILINE)
    return result

def replace_contractions(text):
    return contractions.fix(text)

abbs =  {"eur": "euro", "usd": "dollar", "gbp" : "pound", "u":"you", "tryeur":"turkish lira euro", "try":" turkish lira", "gt":"greater than","lt": "less than","btc":"bitcoin",
        "gbpusd": "pound dollar", "usdtry":"dollar turkish lira", "fx":"forex", "u":"you", "eurusd":"euro usd", "eurgbp":"euro pound", "jpy":"japanese yen","cny":"chinese yuan","uk":"united kingdom"}

def replace_currency(text):
    val = ''
    for i in text.split():
        if abbs.get(i.lower().strip()) is not None:
            #print(abbs.get(i.lower().strip()))
            val = val + str(abbs.get(i.lower().strip())) + ' '
        else:
            val = val + i + ' '
    return val

# %%
print(remove_url(df['Text'].iloc[1942]))
# Out:
# Visit  to check the latest #bitcoin price in #gbp #uk #pound. You can also use our free $GBP to $BTC price converter.

# %%
print(replace_currency("@elonmusk Try turkish lira its at the bottom"))
# Out:
# @elonmusk  turkish lira turkish lira its at the bottom

# %%
clean = TextCleaner()

def cleaning(df_cl, stop_words):
    
    # Removing URLs
    df_cl["Text"] = df_cl["Text"].apply(lambda x: remove_url(x))
    
     # Removing mentioned author names
    df_cl["Text"] = df_cl["Text"].apply(lambda x: re.sub("@[A-Za-z0-9]+","", x))
    
    # Lowercase
    df_cl['Text'] = df_cl['Text'].apply(lambda x: ' '.join(x.lower() for x in x.split()))
    
    df_cl["Text"] = df_cl["Text"].apply(lambda x: replace_contractions(x))
    
    df_cl["Text"] = df_cl["Text"].apply(lambda x: replace_currency(x))
    
     # Remove Non -letters
    df_cl['Text'] = df_cl['Text'].apply(lambda x: re.sub(r"[^a-zA-Z0-9]", ' ', x))
    
    # Removing Punctuation
    df_cl["Text"] = df_cl["Text"].apply(lambda x: re.sub(r'[^\w\s]','', x))
    
    # Removing stop words
    df_cl['Text'] = df_cl['Text'].apply(lambda x:' '.join(x for x in x.split() if x not in stop_words))
    
    # Lemmatization
    df_cl['Text'] = df_cl['Text'].apply(lambda x:' '.join([Word(x).lemmatize() for x in x.split()]))
    
    # Emoticons
    df_cl['Text'] = df_cl['Text'].apply(lambda x: clean.convert_emoji_to_text(x))
    
    # Emojis
    df_cl['Text'] = df_cl['Text'].apply(lambda x: clean.convert_emoji_to_text(x))    
    
    # Stemming
    #df_cl['Text'] = df_cl['Text'].apply(lambda x: port_stemmer(x))
    return df_cl

stop_words = stopwords.words('english')

# %%
data_v1 = cleaning(data_v1, stop_words)

# %%
data_v1
# Out:
#                                                    Text Sentiment
# 0                           please come try turkishlira  Positive
# 1     hello registered using turkish citizenship id ...  Positive
# 2     trade weekly bar 200 day moving average breach...  Positive
# 3       turkish lira turkish lira bottom maybe would go  Negative
# 4                     turkish lira fucking turkish lira  Negative
# ...                                                 ...       ...
# 1944  missed last night nye potentially important tw...  Positive
# 1945  gbp usd weekly price forecast british pound lo...  Positive
# 1946  20 0142 zar 1 pound december 31 2020 06 20am s...  Positive
# 1947  gbp eur pound lifted united kingdom approval a...  Positive
# 1948  gbp jpy gbpjpy gbp jpy british pound brexit br...  Positive
#
# [1949 rows x 2 columns]

# %%
common_words = ''
for i in data_v1.Text:
    i = str(i)
    tokens = i.split()
    common_words += " ".join(tokens)+" "
wordcloud = WordCloud(width=1600, height=800).generate(common_words)
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
lb = LabelEncoder()
data_v1['Sentiment'] = lb.fit_transform(data_v1['Sentiment'])

# %%
tokenizer = Tokenizer(num_words=1000, split=' ', lower=True) 
tokenizer.fit_on_texts(data_v1['Text'].values)
X = tokenizer.texts_to_sequences(df['Text'].values)
X = pad_sequences(X)

# %%
y = pd.get_dummies(data_v1['Sentiment'])

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# <h3>Time Series Methodologies</h3>
# <h4>Defining Models</h4>

# %%
models = [ 'SimpleRNN', 'LSTM', 'GRU']

# %%
METRICS = [ 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      km.binary_precision(), 
      km.binary_recall(),
      'mse', 
      'mae', 
      keras.metrics.AUC(name='auc'),
      tfa.metrics.F1Score(num_classes=2, threshold=0.5, average='macro'),
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn')
]
# Out:
# 2022-03-14 20:37:30.718396: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def build_model(nb_words, _model="SimpleRNN", embedding_matrix=None):
    model = Sequential()
    model.add(Embedding(input_dim=1000, output_dim=64, input_length = nb_words))
    if _model == "SimpleRNN":
        model.add(SimpleRNN(128, dropout=0.1, recurrent_dropout=0.1, activation='relu'))
    elif _model == "LSTM":
        model.add(LSTM(100, return_sequences=True))
        model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.1, activation='relu'))
    elif _model == "GRU":
        model.add(GRU(128))
    model.add(Dense(2, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=[METRICS])
    return model

# %%
print(X.shape)
print(y.shape)
# Out:
# (1949, 38)
# (1949, 2)

# %%
output_df = pd.DataFrame(columns=['model', 'accuracy', 'precision', 'recall', 'mse', 'mae', 'auc', 'f1_score', 'prediction time'])

seed = 5
kfold = KFold(seed, True, 7)
cvscores = []

batch_size = 64

x1=np.array(X)
y1=np.array(y)

for idx, mdl in enumerate(models):
    accuracy = precision = recall = mse = mae = auc = f1_score_val = prediction_time = 0
    
    print("Model : " + str(mdl))
    model_ = build_model(X.shape[1], mdl, None)
    print("Model Summary")
    print(model_.summary())
    
    for train, test in kfold.split(x1,y1):
        X_train, X_test, y_train, y_test = train_test_split(x1, y1, test_size = 0.2, random_state = 0)
        model_.fit(X_train, y_train, epochs=5, validation_split=0.2, batch_size=batch_size, verbose = 'auto', shuffle=False, validation_data=(X_test,y_test))
    
        start_time = time.time()
        y_pred = model_.predict(X_test)
        end_time = time.time() - start_time
        print("")

        scores = model_.evaluate(X_test, y_test)
        print("%s: %.2f%%" % (model_.metrics_names[1], scores[1]*100))    
        print("")
        accuracy += scores[1]
        precision += scores[2]
        recall += scores[3]
        mse += scores[4]
        mae += scores[5]
        auc += scores[6]
        f1_score_val += scores[7]
        prediction_time += end_time
        
        #print("")
        #print("Time taken to predict the model " + str(end_time))

    output_df = output_df.append([{'model': str(mdl), 'accuracy':accuracy/seed,'precision':precision/seed
                                       ,'recall':recall/seed,'mse':mse/seed,'mae':mae/seed
                                       ,'auc':auc/seed,'f1_score':f1_score_val/seed, 'prediction time': prediction_time/seed}], ignore_index=True)

    yhat = model_.predict_on_batch(X_test)
    #print("yhat[:,1]",yhat[:,1])
    #print("y_test",y_test)
    fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test[:,1], yhat[:,1])
    plt.rcParams["figure.figsize"] = (10,7)
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr_rf, tpr_rf, label=str(mdl) + ' (area = {:.3f})'.format(auc/seed))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.savefig('tsa_roc_curve.png')

    #print(classification_report(y_test.values.argmax(axis=1), y_pred.argmax(axis=1)))
    print("___________________________________________________________________________________")

    print("")
    print("")
    print("")
    
plt.show()
# Out:
# Model : SimpleRNN
# Model Summary
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 38, 64)            64000
#
#  simple_rnn (SimpleRNN)      (None, 128)               24704
#
#  dense (Dense)               (None, 2)                 258
#
# =================================================================
# Total params: 88,962
# Trainable params: 88,962
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass shuffle=True, random_state=7 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /opt/anaconda3/lib/python3.9/site-packages/keras_metrics/metrics.py:26: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return object.__getattribute__(self, name)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 20/20 [==============================] - ETA: 0s - loss: 0.6460 - accuracy: 0.6536 - precision: 0.3595 - recall: 0.2134 - mse: 0.2264 - mae: 0.4503 - auc: 0.6816 - f1_score: 0.4514 - tp: 815.0000 - fp: 432.0000 - tn: 815.0000 - fn: 432.0000WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 20/20 [==============================] - 3s 42ms/step - loss: 0.6460 - accuracy: 0.6536 - precision: 0.3595 - recall: 0.2134 - mse: 0.2264 - mae: 0.4503 - auc: 0.6816 - f1_score: 0.4514 - tp: 815.0000 - fp: 432.0000 - tn: 815.0000 - fn: 432.0000 - val_loss: 0.6422 - val_accuracy: 0.6603 - val_precision: 0.3625 - val_recall: 0.0615 - val_mse: 0.2249 - val_mae: 0.4567 - val_auc: 0.6743 - val_f1_score: 0.3977 - val_tp: 206.0000 - val_fp: 106.0000 - val_tn: 206.0000 - val_fn: 106.0000
# Epoch 2/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6339 - accuracy: 0.6712 - precision: 0.3625 - recall: 0.0402 - mse: 0.2210 - mae: 0.4498 - auc: 0.6815 - f1_score: 0.4016 - tp: 837.0000 - fp: 410.0000 - tn: 837.0000 - fn: 410.0000 - val_loss: 0.6431 - val_accuracy: 0.6603 - val_precision: 0.3625 - val_recall: 0.0293 - val_mse: 0.2253 - val_mae: 0.4393 - val_auc: 0.6683 - val_f1_score: 0.3977 - val_tp: 206.0000 - val_fp: 106.0000 - val_tn: 206.0000 - val_fn: 106.0000
# Epoch 3/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6332 - accuracy: 0.6712 - precision: 0.3625 - recall: 0.0233 - mse: 0.2206 - mae: 0.4384 - auc: 0.6761 - f1_score: 0.4016 - tp: 837.0000 - fp: 410.0000 - tn: 837.0000 - fn: 410.0000 - val_loss: 0.6420 - val_accuracy: 0.6603 - val_precision: 0.3625 - val_recall: 0.0193 - val_mse: 0.2248 - val_mae: 0.4426 - val_auc: 0.6642 - val_f1_score: 0.3977 - val_tp: 206.0000 - val_fp: 106.0000 - val_tn: 206.0000 - val_fn: 106.0000
# Epoch 4/5
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6325 - accuracy: 0.6712 - precision: 0.3625 - recall: 0.0164 - mse: 0.2202 - mae: 0.4400 - auc: 0.6772 - f1_score: 0.4016 - tp: 837.0000 - fp: 410.0000 - tn: 837.0000 - fn: 410.0000 - val_loss: 0.6423 - val_accuracy: 0.6603 - val_precision: 0.3625 - val_recall: 0.0143 - val_mse: 0.2250 - val_mae: 0.4414 - val_auc: 0.6719 - val_f1_score: 0.3977 - val_tp: 206.0000 - val_fp: 106.0000 - val_tn: 206.0000 - val_fn: 106.0000
# Epoch 5/5
# Epoch 4/5
# 20/20 [==============================] - 0s 13ms/step - loss: 0.5949 - accuracy: 0.6872 - precision: 0.5960 - recall: 0.0454 - mse: 0.2038 - mae: 0.4080 - auc: 0.7447 - f1_score: 0.5208 - tp: 857.0000 - fp: 390.0000 - tn: 857.0000 - fn: 390.0000 - val_loss: 0.6590 - val_accuracy: 0.6410 - val_precision: 0.5934 - val_recall: 0.0472 - val_mse: 0.2317 - val_mae: 0.4411 - val_auc: 0.6607 - val_f1_score: 0.4431 - val_tp: 200.0000 - val_fp: 112.0000 - val_tn: 200.0000 - val_fn: 112.0000
# Epoch 5/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.5882 - accuracy: 0.7017 - precision: 0.5966 - recall: 0.0490 - mse: 0.2006 - mae: 0.4091 - auc: 0.7527 - f1_score: 0.5361 - tp: 875.0000 - fp: 372.0000 - tn: 875.0000 - fn: 372.0000 - val_loss: 0.6765 - val_accuracy: 0.6378 - val_precision: 0.5971 - val_recall: 0.0508 - val_mse: 0.2371 - val_mae: 0.4328 - val_auc: 0.6624 - val_f1_score: 0.4541 - val_tp: 199.0000 - val_fp: 113.0000 - val_tn: 199.0000 - val_fn: 113.0000
#
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6481 - accuracy: 0.6692 - precision: 0.5936 - recall: 0.0513 - mse: 0.2254 - mae: 0.4222 - auc: 0.6851 - f1_score: 0.4952 - tp: 261.0000 - fp: 129.0000 - tn: 261.0000 - fn: 129.0000
# accuracy: 66.92%
#
# ___________________________________________________________________________________
#
#
#
# Model : LSTM
# Model Summary
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 38, 64)            64000
#
#  lstm (LSTM)                 (None, 38, 100)           66000
#
#  lstm_1 (LSTM)               (None, 128)               117248
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 247,506
# Trainable params: 247,506
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /opt/anaconda3/lib/python3.9/site-packages/keras_metrics/metrics.py:26: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return object.__getattribute__(self, name)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 20/20 [==============================] - ETA: 0s - loss: 0.6425 - accuracy: 0.6707 - precision: 0.5924 - recall: 0.0508 - mse: 0.2249 - mae: 0.4461 - auc: 0.6823 - f1_score: 0.4283 - tp: 1098.0000 - fp: 539.0000 - tn: 1098.0000 - fn: 539.0000WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 20/20 [==============================] - 6s 146ms/step - loss: 0.6425 - accuracy: 0.6707 - precision: 0.5924 - recall: 0.0508 - mse: 0.2249 - mae: 0.4461 - auc: 0.6823 - f1_score: 0.4283 - tp: 1098.0000 - fp: 539.0000 - tn: 1098.0000 - fn: 539.0000 - val_loss: 0.6432 - val_accuracy: 0.6603 - val_precision: 0.5924 - val_recall: 0.0499 - val_mse: 0.2254 - val_mae: 0.4592 - val_auc: 0.6699 - val_f1_score: 0.3977 - val_tp: 206.0000 - val_fp: 106.0000 - val_tn: 206.0000 - val_fn: 106.0000
# Epoch 2/5
# 20/20 [==============================] - 2s 102ms/step - loss: 0.6368 - accuracy: 0.6712 - precision: 0.5924 - recall: 0.0489 - mse: 0.2223 - mae: 0.4501 - auc: 0.6795 - f1_score: 0.4016 - tp: 837.0000 - fp: 410.0000 - tn: 837.0000 - fn: 410.0000 - val_loss: 0.6474 - val_accuracy: 0.6603 - val_precision: 0.5924 - val_recall: 0.0481 - val_mse: 0.2271 - val_mae: 0.4320 - val_auc: 0.6721 - val_f1_score: 0.3977 - val_tp: 206.0000 - val_fp: 106.0000 - val_tn: 206.0000 - val_fn: 106.0000
# Epoch 3/5
# 20/20 [==============================] - 2s 89ms/step - loss: 0.6372 - accuracy: 0.6712 - precision: 0.5924 - recall: 0.0472 - mse: 0.2224 - mae: 0.4466 - auc: 0.6640 - f1_score: 0.4016 - tp: 837.0000 - fp: 410.0000 - tn: 837.0000 - fn: 410.0000 - val_loss: 0.6419 - val_accuracy: 0.6603 - val_precision: 0.5924 - val_recall: 0.0465 - val_mse: 0.2248 - val_mae: 0.4429 - val_auc: 0.6729 - val_f1_score: 0.3977 - val_tp: 206.0000 - val_fp: 106.0000 - val_tn: 206.0000 - val_fn: 106.0000
# Epoch 4/5
# Epoch 4/5
# 20/20 [==============================] - 3s 140ms/step - loss: 0.6315 - accuracy: 0.6720 - precision: 0.5900 - recall: 0.0392 - mse: 0.2198 - mae: 0.4391 - auc: 0.6854 - f1_score: 0.4089 - tp: 838.0000 - fp: 409.0000 - tn: 838.0000 - fn: 409.0000 - val_loss: 0.6457 - val_accuracy: 0.6538 - val_precision: 0.5896 - val_recall: 0.0388 - val_mse: 0.2266 - val_mae: 0.4405 - val_auc: 0.6758 - val_f1_score: 0.3953 - val_tp: 204.0000 - val_fp: 108.0000 - val_tn: 204.0000 - val_fn: 108.0000
# Epoch 5/5
# 20/20 [==============================] - 2s 111ms/step - loss: 0.6314 - accuracy: 0.6720 - precision: 0.5889 - recall: 0.0383 - mse: 0.2198 - mae: 0.4387 - auc: 0.6862 - f1_score: 0.4111 - tp: 838.0000 - fp: 409.0000 - tn: 838.0000 - fn: 409.0000 - val_loss: 0.6457 - val_accuracy: 0.6538 - val_precision: 0.5885 - val_recall: 0.0380 - val_mse: 0.2267 - val_mae: 0.4412 - val_auc: 0.6759 - val_f1_score: 0.3953 - val_tp: 204.0000 - val_fp: 108.0000 - val_tn: 204.0000 - val_fn: 108.0000
#
# 13/13 [==============================] - 0s 16ms/step - loss: 0.6301 - accuracy: 0.6692 - precision: 0.5880 - recall: 0.0378 - mse: 0.2191 - mae: 0.4337 - auc: 0.6853 - f1_score: 0.4082 - tp: 261.0000 - fp: 129.0000 - tn: 261.0000 - fn: 129.0000
# accuracy: 66.92%
#
# Epoch 1/5
# 20/20 [==============================] - 2s 90ms/step - loss: 0.6313 - accuracy: 0.6712 - precision: 0.5868 - recall: 0.0373 - mse: 0.2198 - mae: 0.4384 - auc: 0.6869 - f1_score: 0.4108 - tp: 837.0000 - fp: 410.0000 - tn: 837.0000 - fn: 410.0000 - val_loss: 0.6458 - val_accuracy: 0.6506 - val_precision: 0.5859 - val_recall: 0.0370 - val_mse: 0.2267 - val_mae: 0.4410 - val_auc: 0.6765 - val_f1_score: 0.3942 - val_tp: 203.0000 - val_fp: 109.0000 - val_tn: 203.0000 - val_fn: 109.0000
# Epoch 2/5
# 20/20 [==============================] - 2s 90ms/step - loss: 0.6309 - accuracy: 0.6712 - precision: 0.5848 - recall: 0.0365 - mse: 0.2195 - mae: 0.4385 - auc: 0.6885 - f1_score: 0.4108 - tp: 837.0000 - fp: 410.0000 - tn: 837.0000 - fn: 410.0000 - val_loss: 0.6457 - val_accuracy: 0.6506 - val_precision: 0.5840 - val_recall: 0.0362 - val_mse: 0.2267 - val_mae: 0.4410 - val_auc: 0.6775 - val_f1_score: 0.3942 - val_tp: 203.0000 - val_fp: 109.0000 - val_tn: 203.0000 - val_fn: 109.0000
# Epoch 3/5
# Epoch 3/5
# 20/20 [==============================] - 2s 108ms/step - loss: 0.6258 - accuracy: 0.6736 - precision: 0.5614 - recall: 0.0319 - mse: 0.2177 - mae: 0.4350 - auc: 0.6982 - f1_score: 0.4292 - tp: 840.0000 - fp: 407.0000 - tn: 840.0000 - fn: 407.0000 - val_loss: 0.6408 - val_accuracy: 0.6538 - val_precision: 0.5613 - val_recall: 0.0317 - val_mse: 0.2245 - val_mae: 0.4403 - val_auc: 0.6840 - val_f1_score: 0.3953 - val_tp: 204.0000 - val_fp: 108.0000 - val_tn: 204.0000 - val_fn: 108.0000
# Epoch 4/5
# 20/20 [==============================] - 2s 119ms/step - loss: 0.6263 - accuracy: 0.6728 - precision: 0.5610 - recall: 0.0314 - mse: 0.2176 - mae: 0.4337 - auc: 0.7012 - f1_score: 0.4114 - tp: 839.0000 - fp: 408.0000 - tn: 839.0000 - fn: 408.0000 - val_loss: 0.6421 - val_accuracy: 0.6538 - val_precision: 0.5610 - val_recall: 0.0313 - val_mse: 0.2252 - val_mae: 0.4367 - val_auc: 0.6831 - val_f1_score: 0.3953 - val_tp: 204.0000 - val_fp: 108.0000 - val_tn: 204.0000 - val_fn: 108.0000
# Epoch 5/5
# 20/20 [==============================] - 3s 137ms/step - loss: 0.6251 - accuracy: 0.6704 - precision: 0.5603 - recall: 0.0310 - mse: 0.2171 - mae: 0.4343 - auc: 0.7021 - f1_score: 0.4105 - tp: 836.0000 - fp: 411.0000 - tn: 836.0000 - fn: 411.0000 - val_loss: 0.6422 - val_accuracy: 0.6506 - val_precision: 0.5592 - val_recall: 0.0308 - val_mse: 0.2254 - val_mae: 0.4356 - val_auc: 0.6814 - val_f1_score: 0.3942 - val_tp: 203.0000 - val_fp: 109.0000 - val_tn: 203.0000 - val_fn: 109.0000
#
# 13/13 [==============================] - 0s 35ms/step - loss: 0.6338 - accuracy: 0.6744 - precision: 0.5591 - recall: 0.0308 - mse: 0.2206 - mae: 0.4323 - auc: 0.6841 - f1_score: 0.4244 - tp: 263.0000 - fp: 127.0000 - tn: 263.0000 - fn: 127.0000
# accuracy: 67.44%
#
# ___________________________________________________________________________________
#
#
#
# Model : GRU
# Model Summary
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 38, 64)            64000
#
#  gru (GRU)                   (None, 128)               74496
#
#  dense_2 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 138,754
# Trainable params: 138,754
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /opt/anaconda3/lib/python3.9/site-packages/keras_metrics/metrics.py:26: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return object.__getattribute__(self, name)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 19/20 [===========================>..] - ETA: 0s - loss: 0.6449 - accuracy: 0.6687 - precision: 0.5582 - recall: 0.0306 - mse: 0.2259 - mae: 0.4463 - auc: 0.6812 - f1_score: 0.4113 - tp: 1074.0000 - fp: 532.0000 - tn: 1074.0000 - fn: 532.0000WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 20/20 [==============================] - 4s 79ms/step - loss: 0.6419 - accuracy: 0.6707 - precision: 0.5582 - recall: 0.0306 - mse: 0.2246 - mae: 0.4446 - auc: 0.6841 - f1_score: 0.4119 - tp: 1098.0000 - fp: 539.0000 - tn: 1098.0000 - fn: 539.0000 - val_loss: 0.6446 - val_accuracy: 0.6603 - val_precision: 0.5582 - val_recall: 0.0303 - val_mse: 0.2260 - val_mae: 0.4364 - val_auc: 0.6693 - val_f1_score: 0.3977 - val_tp: 206.0000 - val_fp: 106.0000 - val_tn: 206.0000 - val_fn: 106.0000
# Epoch 2/5
# 20/20 [==============================] - 1s 43ms/step - loss: 0.6352 - accuracy: 0.6712 - precision: 0.5582 - recall: 0.0300 - mse: 0.2215 - mae: 0.4485 - auc: 0.6730 - f1_score: 0.4016 - tp: 837.0000 - fp: 410.0000 - tn: 837.0000 - fn: 410.0000 - val_loss: 0.6419 - val_accuracy: 0.6603 - val_precision: 0.5582 - val_recall: 0.0297 - val_mse: 0.2248 - val_mae: 0.4452 - val_auc: 0.6711 - val_f1_score: 0.3977 - val_tp: 206.0000 - val_fp: 106.0000 - val_tn: 206.0000 - val_fn: 106.0000
# Epoch 3/5
# 20/20 [==============================] - 1s 36ms/step - loss: 0.6313 - accuracy: 0.6712 - precision: 0.5582 - recall: 0.0295 - mse: 0.2197 - mae: 0.4368 - auc: 0.6822 - f1_score: 0.4016 - tp: 837.0000 - fp: 410.0000 - tn: 837.0000 - fn: 410.0000 - val_loss: 0.6444 - val_accuracy: 0.6603 - val_precision: 0.5582 - val_recall: 0.0292 - val_mse: 0.2259 - val_mae: 0.4387 - val_auc: 0.6718 - val_f1_score: 0.3977 - val_tp: 206.0000 - val_fp: 106.0000 - val_tn: 206.0000 - val_fn: 106.0000
# Epoch 4/5
# 20/20 [==============================] - 1s 33ms/step - loss: 0.6323 - accuracy: 0.6720 - precision: 0.5580 - recall: 0.0290 - mse: 0.2201 - mae: 0.4397 - auc: 0.6767 - f1_score: 0.4089 - tp: 838.0000 - fp: 409.0000 - tn: 838.0000 - fn: 409.0000 - val_loss: 0.6435 - val_accuracy: 0.6538 - val_precision: 0.5577 - val_recall: 0.0288 - val_mse: 0.2255 - val_mae: 0.4417 - val_auc: 0.6726 - val_f1_score: 0.3953 - val_tp: 204.0000 - val_fp: 108.0000 - val_tn: 204.0000 - val_fn: 108.0000
# Epoch 5/5
# 20/20 [==============================] - 1s 39ms/step - loss: 0.6315 - accuracy: 0.6720 - precision: 0.5574 - recall: 0.0286 - mse: 0.2198 - mae: 0.4382 - auc: 0.6789 - f1_score: 0.4089 - tp: 838.0000 - fp: 409.0000 - tn: 838.0000 - fn: 409.0000 - val_loss: 0.6443 - val_accuracy: 0.6538 - val_precision: 0.5571 - val_recall: 0.0284 - val_mse: 0.2259 - val_mae: 0.4400 - val_auc: 0.6735 - val_f1_score: 0.3953 - val_tp: 204.0000 - val_fp: 108.0000 - val_tn: 204.0000 - val_fn: 108.0000
#
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6354 - accuracy: 0.6692 - precision: 0.5567 - recall: 0.0283 - mse: 0.2216 - mae: 0.4352 - auc: 0.6846 - f1_score: 0.4082 - tp: 261.0000 - fp: 129.0000 - tn: 261.0000 - fn: 129.0000
# accuracy: 66.92%
#
# Epoch 1/5
# 20/20 [==============================] - 1s 42ms/step - loss: 0.6318 - accuracy: 0.6736 - precision: 0.5564 - recall: 0.0281 - mse: 0.2199 - mae: 0.4386 - auc: 0.6790 - f1_score: 0.4140 - tp: 840.0000 - fp: 407.0000 - tn: 840.0000 - fn: 407.0000 - val_loss: 0.6441 - val_accuracy: 0.6571 - val_precision: 0.5567 - val_recall: 0.0280 - val_mse: 0.2258 - val_mae: 0.4408 - val_auc: 0.6717 - val_f1_score: 0.4053 - val_tp: 205.0000 - val_fp: 107.0000 - val_tn: 205.0000 - val_fn: 107.0000
# Epoch 2/5
# 20/20 [==============================] - 1s 42ms/step - loss: 0.6315 - accuracy: 0.6736 - precision: 0.5567 - recall: 0.0278 - mse: 0.2198 - mae: 0.4383 - auc: 0.6792 - f1_score: 0.4140 - tp: 840.0000 - fp: 407.0000 - tn: 840.0000 - fn: 407.0000 - val_loss: 0.6443 - val_accuracy: 0.6571 - val_precision: 0.5570 - val_recall: 0.0277 - val_mse: 0.2259 - val_mae: 0.4404 - val_auc: 0.6736 - val_f1_score: 0.4053 - val_tp: 205.0000 - val_fp: 107.0000 - val_tn: 205.0000 - val_fn: 107.0000
# Epoch 3/5
# Epoch 3/5
# 20/20 [==============================] - 1s 50ms/step - loss: 0.6302 - accuracy: 0.6744 - precision: 0.5582 - recall: 0.0263 - mse: 0.2192 - mae: 0.4373 - auc: 0.6873 - f1_score: 0.4166 - tp: 841.0000 - fp: 406.0000 - tn: 841.0000 - fn: 406.0000 - val_loss: 0.6446 - val_accuracy: 0.6571 - val_precision: 0.5585 - val_recall: 0.0262 - val_mse: 0.2261 - val_mae: 0.4402 - val_auc: 0.6767 - val_f1_score: 0.4053 - val_tp: 205.0000 - val_fp: 107.0000 - val_tn: 205.0000 - val_fn: 107.0000
# Epoch 4/5
# 20/20 [==============================] - 1s 47ms/step - loss: 0.6297 - accuracy: 0.6744 - precision: 0.5587 - recall: 0.0261 - mse: 0.2190 - mae: 0.4370 - auc: 0.6894 - f1_score: 0.4166 - tp: 841.0000 - fp: 406.0000 - tn: 841.0000 - fn: 406.0000 - val_loss: 0.6447 - val_accuracy: 0.6571 - val_precision: 0.5590 - val_recall: 0.0260 - val_mse: 0.2261 - val_mae: 0.4397 - val_auc: 0.6787 - val_f1_score: 0.4053 - val_tp: 205.0000 - val_fp: 107.0000 - val_tn: 205.0000 - val_fn: 107.0000
# Epoch 5/5
# 20/20 [==============================] - 1s 40ms/step - loss: 0.6291 - accuracy: 0.6728 - precision: 0.5590 - recall: 0.0259 - mse: 0.2187 - mae: 0.4365 - auc: 0.6913 - f1_score: 0.4181 - tp: 839.0000 - fp: 408.0000 - tn: 839.0000 - fn: 408.0000 - val_loss: 0.6448 - val_accuracy: 0.6571 - val_precision: 0.5588 - val_recall: 0.0259 - val_mse: 0.2261 - val_mae: 0.4390 - val_auc: 0.6779 - val_f1_score: 0.4053 - val_tp: 205.0000 - val_fp: 107.0000 - val_tn: 205.0000 - val_fn: 107.0000
#
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6363 - accuracy: 0.6692 - precision: 0.5586 - recall: 0.0258 - mse: 0.2218 - mae: 0.4349 - auc: 0.6758 - f1_score: 0.4082 - tp: 261.0000 - fp: 129.0000 - tn: 261.0000 - fn: 129.0000
# accuracy: 66.92%
#
# Epoch 1/5
# 20/20 [==============================] - 1s 37ms/step - loss: 0.6285 - accuracy: 0.6744 - precision: 0.5585 - recall: 0.0258 - mse: 0.2184 - mae: 0.4356 - auc: 0.6928 - f1_score: 0.4253 - tp: 841.0000 - fp: 406.0000 - tn: 841.0000 - fn: 406.0000 - val_loss: 0.6449 - val_accuracy: 0.6571 - val_precision: 0.5586 - val_recall: 0.0257 - val_mse: 0.2262 - val_mae: 0.4385 - val_auc: 0.6775 - val_f1_score: 0.4053 - val_tp: 205.0000 - val_fp: 107.0000 - val_tn: 205.0000 - val_fn: 107.0000
# Epoch 2/5
# Epoch 2/5
# 20/20 [==============================] - 1s 48ms/step - loss: 0.6255 - accuracy: 0.6760 - precision: 0.5566 - recall: 0.0262 - mse: 0.2171 - mae: 0.4328 - auc: 0.7015 - f1_score: 0.4485 - tp: 843.0000 - fp: 404.0000 - tn: 843.0000 - fn: 404.0000 - val_loss: 0.6430 - val_accuracy: 0.6603 - val_precision: 0.5574 - val_recall: 0.0263 - val_mse: 0.2253 - val_mae: 0.4366 - val_auc: 0.6739 - val_f1_score: 0.4151 - val_tp: 206.0000 - val_fp: 106.0000 - val_tn: 206.0000 - val_fn: 106.0000
# Epoch 3/5
# 20/20 [==============================] - 1s 58ms/step - loss: 0.6235 - accuracy: 0.6760 - precision: 0.5572 - recall: 0.0264 - mse: 0.2162 - mae: 0.4307 - auc: 0.7032 - f1_score: 0.4485 - tp: 843.0000 - fp: 404.0000 - tn: 843.0000 - fn: 404.0000 - val_loss: 0.6468 - val_accuracy: 0.6635 - val_precision: 0.5578 - val_recall: 0.0266 - val_mse: 0.2266 - val_mae: 0.4351 - val_auc: 0.6732 - val_f1_score: 0.4327 - val_tp: 207.0000 - val_fp: 105.0000 - val_tn: 207.0000 - val_fn: 105.0000
# Epoch 4/5
# 20/20 [==============================] - 1s 56ms/step - loss: 0.6271 - accuracy: 0.6744 - precision: 0.5576 - recall: 0.0268 - mse: 0.2178 - mae: 0.4350 - auc: 0.7008 - f1_score: 0.4477 - tp: 841.0000 - fp: 406.0000 - tn: 841.0000 - fn: 406.0000 - val_loss: 0.6417 - val_accuracy: 0.6538 - val_precision: 0.5573 - val_recall: 0.0268 - val_mse: 0.2247 - val_mae: 0.4384 - val_auc: 0.6780 - val_f1_score: 0.3953 - val_tp: 204.0000 - val_fp: 108.0000 - val_tn: 204.0000 - val_fn: 108.0000
# Epoch 5/5
# 20/20 [==============================] - 1s 55ms/step - loss: 0.6239 - accuracy: 0.6736 - precision: 0.5572 - recall: 0.0267 - mse: 0.2164 - mae: 0.4316 - auc: 0.7053 - f1_score: 0.4207 - tp: 840.0000 - fp: 407.0000 - tn: 840.0000 - fn: 407.0000 - val_loss: 0.6464 - val_accuracy: 0.6603 - val_precision: 0.5574 - val_recall: 0.0267 - val_mse: 0.2265 - val_mae: 0.4352 - val_auc: 0.6710 - val_f1_score: 0.4151 - val_tp: 206.0000 - val_fp: 106.0000 - val_tn: 206.0000 - val_fn: 106.0000
#
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6321 - accuracy: 0.6744 - precision: 0.5577 - recall: 0.0267 - mse: 0.2201 - mae: 0.4296 - auc: 0.6867 - f1_score: 0.4312 - tp: 263.0000 - fp: 127.0000 - tn: 263.0000 - fn: 127.0000
# accuracy: 67.44%
#
# ___________________________________________________________________________________

# %%
output_df
# Out:
#        model  accuracy  precision    recall       mse       mae       auc  \
# 0  SimpleRNN  0.671282   0.503475  0.024514  0.221250  0.430087  0.686187
# 1       LSTM  0.672821   0.575788  0.035619  0.219245  0.432190  0.687364
# 2        GRU  0.672308   0.557554  0.026722  0.221304  0.433752  0.681118
#
#    f1_score  prediction time
# 0  0.439429         0.079840
# 1  0.416665         0.451108
# 2  0.420505         0.145833

# %% [markdown]
# <h3>Traditional Methodologies</h3>

# %%
stemmer = PorterStemmer()
analyzer = CountVectorizer().build_analyzer()
def stemmed_words(doc):
    stemmed_words = [stemmer.stem(w) for w in analyzer(doc)]
    non_stop_words = [word for word in stemmed_words]
    return non_stop_words

# %%
count_vectorizer = CountVectorizer(stop_words= stop_words, max_features= 1000)
feature_vector = count_vectorizer.fit(data_v1['Text'])
train_ds_features = count_vectorizer.transform(data_v1['Text'])
features = feature_vector.get_feature_names()
features_counts = np.sum(train_ds_features.toarray(), axis = 0)
features_counts = pd.DataFrame(dict(features =  features, counts = features_counts))
features_counts = features_counts.sort_values("counts", ascending= False)[0:15]
features_counts
# Out:
#      features  counts
# 333      euro    1461
# 329       eur    1374
# 675     pound    1217
# 420       gbp    1119
# 924       usd    1055
# 297    dollar     580
# 381     forex     410
# 379  forecast     384
# 187   british     374
# 684     price     364
# 711      rate     342
# 265  currency     256
# 308       ecb     242
# 337    eurusd     236
# 627   outlook     226

# %%
train_x, test_x, train_y, test_y =  train_test_split(train_ds_features, data_v1['Sentiment'], test_size = 0.3, random_state = 42)

# %%
x = train_ds_features
y = data_v1['Sentiment']

# %%
classifiers = {
    "BernoulliNB": BernoulliNB(),
    "ComplementNB": ComplementNB(),
    "MultinomialNB": MultinomialNB(),
    "LogisticRegression": LogisticRegression(),
    "KNeighborsClassifier": KNeighborsClassifier(),
    "DecisionTreeClassifier": DecisionTreeClassifier(),
    "RandomForestClassifier": RandomForestClassifier(),
    "MLPClassifier": MLPClassifier(max_iter=1000),
    "AdaBoostClassifier": AdaBoostClassifier()
}
estimators = []
for name, sklearn_classifier in classifiers.items():
    estimators.append((name,sklearn_classifier))

voting_clf = VotingClassifier(
        estimators=estimators,
        voting="hard")
classifiers['VotingClassifier'] = voting_clf
classifiers
# Out:
# {'BernoulliNB': BernoulliNB(),
#  'ComplementNB': ComplementNB(),
#  'MultinomialNB': MultinomialNB(),
#  'LogisticRegression': LogisticRegression(),
#  'KNeighborsClassifier': KNeighborsClassifier(),
#  'DecisionTreeClassifier': DecisionTreeClassifier(),
#  'RandomForestClassifier': RandomForestClassifier(),
#  'MLPClassifier': MLPClassifier(max_iter=1000),
#  'AdaBoostClassifier': AdaBoostClassifier(),
#  'VotingClassifier': VotingClassifier(estimators=[('BernoulliNB', BernoulliNB()),
#                               ('ComplementNB', ComplementNB()),
#                               ('MultinomialNB', MultinomialNB()),
#                               ('LogisticRegression', LogisticRegression()),
#                               ('KNeighborsClassifier', KNeighborsClassifier()),
#                               ('DecisionTreeClassifier',
#                                DecisionTreeClassifier()),
#                               ('RandomForestClassifier',
#                                RandomForestClassifier()),
#                               ('MLPClassifier', MLPClassifier(max_iter=1000)),
#                               ('AdaBoostClassifier', AdaBoostClassifier())])}

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import precision_score, \
    recall_score, confusion_matrix, classification_report, \
    accuracy_score, f1_score

for name, sklearn_classifier in classifiers.items():
    print("Classifier : ", name)
    accuracy = precision = recall = mse = mae = auc = f1_score_val = prediction_time = 0
    
    for train_index, test_index in kfold.split(x):
        train_x, test_x, train_y, test_y = x[train_index], x[test_index], y[train_index], y[test_index]       
    
        sklearn_classifier.fit(train_x.toarray(), train_y)
        start_time = time.time()
        test_ds_predicted = sklearn_classifier.predict(test_x.toarray())
        end_time = time.time() - start_time
        print(metrics.classification_report(test_y, test_ds_predicted))
        print("")
        print("Time taken to predict the model " + str(end_time))
        print("")
        tr_mae = mean_absolute_error(test_y, test_ds_predicted)
        tr_mse = mean_squared_error(test_y, test_ds_predicted)
        tr_accuracy = accuracy_score(test_y, test_ds_predicted)
        tr_f1_score = f1_score(test_y, test_ds_predicted, average='weighted')
        tr_recall = recall_score(test_y, test_ds_predicted, average='weighted')
        tr_precision = precision_score(test_y, test_ds_predicted, average='weighted')
        tr_auc = roc_auc_score(test_y, test_ds_predicted)

        accuracy += tr_accuracy
        precision += tr_precision
        recall += tr_recall
        mse += tr_mse
        mae += tr_mae
        auc += tr_auc
        f1_score_val += tr_f1_score
        prediction_time += end_time
    #print('MAE: %f' % mean_absolute_error(test_y, test_ds_predicted))
    #print('MSE: %f' % mean_squared_error(test_y, test_ds_predicted))
    #print('RMSE: %f' % sqrt(mean_squared_error(test_y, test_ds_predicted)))
    
    
    output_df = output_df.append([{'model': str(name), 'accuracy':accuracy/seed,'precision':precision/seed
                                       ,'recall':recall/seed,'mse':mse/seed,'mae':mae/seed
                                       ,'auc':auc/seed,'f1_score':f1_score_val/seed, 'prediction time': prediction_time/seed}], ignore_index=True)

    if name != 'VotingClassifier':
        yhat = sklearn_classifier.predict_proba(test_x.toarray())
        fpr_rf, tpr_rf, threshold2 = roc_curve(test_y.to_numpy(), yhat[:,1])
        plt.rcParams["figure.figsize"] = (10,7)
        plt.figure(1)
        plt.plot([0, 1], [0, 1], 'k--')
        plt.plot(fpr_rf, tpr_rf, label=str(name) + ' (area = {:.3f})'.format(tr_auc))
        plt.xlabel('False positive rate')
        plt.ylabel('True positive rate')
        plt.title('ROC curve')
        plt.legend(loc='best')
        plt.savefig('td_roc_curve.png')
    
    print("________________________________________________________")
    print("")
    print("")
plt.show()
# Out:
# Classifier :  BernoulliNB
#               precision    recall  f1-score   support
#
#            0       0.54      0.59      0.57       138
#            1       0.76      0.72      0.74       252
#
#     accuracy                           0.68       390
#    macro avg       0.65      0.66      0.65       390
# weighted avg       0.69      0.68      0.68       390
#
#
# Time taken to predict the model 0.0030651092529296875
#
#               precision    recall  f1-score   support
#
#            0       0.46      0.49      0.48       102
#            1       0.82      0.80      0.81       288
#
#     accuracy                           0.72       390
#    macro avg       0.64      0.64      0.64       390
# weighted avg       0.72      0.72      0.72       390
#
#
# Time taken to predict the model 0.004211902618408203
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.61      0.61       140
#            1       0.78      0.78      0.78       250
#
#     accuracy                           0.72       390
#    macro avg       0.69      0.69      0.69       390
# weighted avg       0.72      0.72      0.72       390
#
#
# Time taken to predict the model 0.0045931339263916016
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.60      0.57       128
#            1       0.80      0.76      0.78       262
#
#     accuracy                           0.71       390
#    macro avg       0.67      0.68      0.68       390
# weighted avg       0.72      0.71      0.71       390
#
#
# Time taken to predict the model 0.0044710636138916016
#
#               precision    recall  f1-score   support
#
#            0       0.51      0.50      0.51       136
#            1       0.73      0.74      0.74       253
#
#     accuracy                           0.66       389
#    macro avg       0.62      0.62      0.62       389
# weighted avg       0.66      0.66      0.66       389
#
#
# Time taken to predict the model 0.008402824401855469
#
# ________________________________________________________
#
#
# Classifier :  ComplementNB
#               precision    recall  f1-score   support
#
#            0       0.52      0.64      0.57       138
#            1       0.78      0.67      0.72       252
#
#     accuracy                           0.66       390
#    macro avg       0.65      0.66      0.65       390
# weighted avg       0.68      0.66      0.67       390
#
#
# Time taken to predict the model 0.002271890640258789
#
#               precision    recall  f1-score   support
#
#            0       0.46      0.61      0.52       102
#            1       0.84      0.75      0.79       288
#
#     accuracy                           0.71       390
#    macro avg       0.65      0.68      0.66       390
# weighted avg       0.74      0.71      0.72       390
#
#
# Time taken to predict the model 0.0026679039001464844
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.69      0.64       140
#            1       0.81      0.74      0.77       250
#
#     accuracy                           0.72       390
#    macro avg       0.71      0.72      0.71       390
# weighted avg       0.74      0.72      0.73       390
#
#
# Time taken to predict the model 0.0010690689086914062
#
#               precision    recall  f1-score   support
#
#            0       0.52      0.64      0.57       128
#            1       0.80      0.71      0.75       262
#
#     accuracy                           0.68       390
#    macro avg       0.66      0.67      0.66       390
# weighted avg       0.71      0.68      0.69       390
#
#
# Time taken to predict the model 0.004801034927368164
#
#               precision    recall  f1-score   support
#
#            0       0.48      0.55      0.52       136
#            1       0.74      0.68      0.71       253
#
#     accuracy                           0.64       389
#    macro avg       0.61      0.62      0.61       389
# weighted avg       0.65      0.64      0.64       389
#
#
# Time taken to predict the model 0.002511262893676758
#
# ________________________________________________________
#
#
# Classifier :  MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.54      0.57      0.56       138
#            1       0.76      0.74      0.75       252
#
#     accuracy                           0.68       390
#    macro avg       0.65      0.66      0.65       390
# weighted avg       0.68      0.68      0.68       390
#
#
# Time taken to predict the model 0.0008809566497802734
#
#               precision    recall  f1-score   support
#
#            0       0.47      0.49      0.48       102
#            1       0.82      0.81      0.81       288
#
#     accuracy                           0.72       390
#    macro avg       0.64      0.65      0.65       390
# weighted avg       0.73      0.72      0.72       390
#
#
# Time taken to predict the model 0.0026929378509521484
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.63      0.63       140
#            1       0.79      0.79      0.79       250
#
#     accuracy                           0.73       390
#    macro avg       0.71      0.71      0.71       390
# weighted avg       0.73      0.73      0.73       390
#
#
# Time taken to predict the model 0.0036101341247558594
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.57      0.56       128
#            1       0.79      0.77      0.78       262
#
#     accuracy                           0.70       390
#    macro avg       0.66      0.67      0.67       390
# weighted avg       0.71      0.70      0.70       390
#
#
# Time taken to predict the model 0.005368947982788086
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.51      0.53       136
#            1       0.75      0.77      0.76       253
#
#     accuracy                           0.68       389
#    macro avg       0.65      0.64      0.64       389
# weighted avg       0.68      0.68      0.68       389
#
#
# Time taken to predict the model 0.001959085464477539
#
# ________________________________________________________
#
#
# Classifier :  LogisticRegression
#               precision    recall  f1-score   support
#
#            0       0.61      0.49      0.54       138
#            1       0.75      0.83      0.78       252
#
#     accuracy                           0.71       390
#    macro avg       0.68      0.66      0.66       390
# weighted avg       0.70      0.71      0.70       390
#
#
# Time taken to predict the model 0.0024650096893310547
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.48      0.52       102
#            1       0.83      0.87      0.85       288
#
#     accuracy                           0.77       390
#    macro avg       0.70      0.68      0.68       390
# weighted avg       0.76      0.77      0.76       390
#
#
# Time taken to predict the model 0.000698089599609375
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.51      0.57       140
#            1       0.75      0.85      0.80       250
#
#     accuracy                           0.73       390
#    macro avg       0.70      0.68      0.68       390
# weighted avg       0.72      0.73      0.72       390
#
#
# Time taken to predict the model 0.0033736228942871094
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.41      0.47       128
#            1       0.74      0.85      0.79       262
#
#     accuracy                           0.70       390
#    macro avg       0.66      0.63      0.63       390
# weighted avg       0.69      0.70      0.69       390
#
#
# Time taken to predict the model 0.0007140636444091797
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.43      0.49       136
#            1       0.73      0.83      0.78       253
#
#     accuracy                           0.69       389
#    macro avg       0.65      0.63      0.63       389
# weighted avg       0.68      0.69      0.68       389
#
#
# Time taken to predict the model 0.0049381256103515625
#
# ________________________________________________________
#
#
# Classifier :  KNeighborsClassifier
#               precision    recall  f1-score   support
#
#            0       0.55      0.53      0.54       138
#            1       0.75      0.77      0.76       252
#
#     accuracy                           0.68       390
#    macro avg       0.65      0.65      0.65       390
# weighted avg       0.68      0.68      0.68       390
#
#
# Time taken to predict the model 0.02943110466003418
#
#               precision    recall  f1-score   support
#
#            0       0.41      0.49      0.45       102
#            1       0.81      0.75      0.78       288
#
#     accuracy                           0.68       390
#    macro avg       0.61      0.62      0.61       390
# weighted avg       0.70      0.68      0.69       390
#
#
# Time taken to predict the model 0.025573015213012695
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.52      0.58       140
#            1       0.76      0.84      0.80       250
#
#     accuracy                           0.73       390
#    macro avg       0.70      0.68      0.69       390
# weighted avg       0.72      0.73      0.72       390
#
#
# Time taken to predict the model 0.029851913452148438
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.38      0.46       128
#            1       0.74      0.86      0.80       262
#
#     accuracy                           0.70       390
#    macro avg       0.65      0.62      0.63       390
# weighted avg       0.68      0.70      0.68       390
#
#
# Time taken to predict the model 0.03412294387817383
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.54      0.54       136
#            1       0.75      0.77      0.76       253
#
#     accuracy                           0.69       389
#    macro avg       0.65      0.65      0.65       389
# weighted avg       0.68      0.69      0.69       389
#
#
# Time taken to predict the model 0.032408714294433594
# ________________________________________________________
#
#
# Classifier :  DecisionTreeClassifier
#               precision    recall  f1-score   support
#
#            0       0.60      0.57      0.59       138
#            1       0.77      0.79      0.78       252
#
#     accuracy                           0.71       390
#    macro avg       0.68      0.68      0.68       390
# weighted avg       0.71      0.71      0.71       390
#
#
# Time taken to predict the model 0.002878904342651367
#
#               precision    recall  f1-score   support
#
#            0       0.41      0.42      0.42       102
#            1       0.79      0.79      0.79       288
#
#     accuracy                           0.69       390
#    macro avg       0.60      0.60      0.60       390
# weighted avg       0.69      0.69      0.69       390
#
#
# Time taken to predict the model 0.0025370121002197266
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.63      0.62       140
#            1       0.79      0.78      0.78       250
#
#     accuracy                           0.72       390
#    macro avg       0.70      0.70      0.70       390
# weighted avg       0.72      0.72      0.72       390
#
#
# Time taken to predict the model 0.0018291473388671875
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.58      0.59       128
#            1       0.80      0.82      0.81       262
#
#     accuracy                           0.74       390
#    macro avg       0.71      0.70      0.70       390
# weighted avg       0.74      0.74      0.74       390
#
#
# Time taken to predict the model 0.0011739730834960938
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.55      0.57       136
#            1       0.77      0.79      0.78       253
#
#     accuracy                           0.71       389
#    macro avg       0.68      0.67      0.67       389
# weighted avg       0.70      0.71      0.70       389
#
#
# Time taken to predict the model 0.002526998519897461
#
# ________________________________________________________
#
#
# Classifier :  RandomForestClassifier
#               precision    recall  f1-score   support
#
#            0       0.64      0.46      0.54       138
#            1       0.74      0.86      0.80       252
#
#     accuracy                           0.72       390
#    macro avg       0.69      0.66      0.67       390
# weighted avg       0.71      0.72      0.71       390
#
#
# Time taken to predict the model 0.018510818481445312
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.46      0.50       102
#            1       0.82      0.87      0.84       288
#
#     accuracy                           0.76       390
#    macro avg       0.69      0.66      0.67       390
# weighted avg       0.75      0.76      0.75       390
#
#
# Time taken to predict the model 0.01732611656188965
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.54      0.61       140
#            1       0.77      0.88      0.82       250
#
#     accuracy                           0.75       390
#    macro avg       0.74      0.71      0.71       390
# weighted avg       0.75      0.75      0.74       390
#
#
# Time taken to predict the model 0.016937971115112305
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.41      0.51       128
#            1       0.76      0.92      0.83       262
#
#     accuracy                           0.75       390
#    macro avg       0.73      0.66      0.67       390
# weighted avg       0.74      0.75      0.73       390
#
#
# Time taken to predict the model 0.01599407196044922
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.45      0.54       136
#            1       0.75      0.89      0.81       253
#
#     accuracy                           0.74       389
#    macro avg       0.72      0.67      0.68       389
# weighted avg       0.73      0.74      0.72       389
#
#
# Time taken to predict the model 0.018492937088012695
#
# ________________________________________________________
#
#
# Classifier :  MLPClassifier
#               precision    recall  f1-score   support
#
#            0       0.58      0.49      0.53       138
#            1       0.74      0.80      0.77       252
#
#     accuracy                           0.69       390
#    macro avg       0.66      0.65      0.65       390
# weighted avg       0.68      0.69      0.69       390
#
#
# Time taken to predict the model 0.0012850761413574219
#
#               precision    recall  f1-score   support
#
#            0       0.52      0.46      0.49       102
#            1       0.82      0.85      0.83       288
#
#     accuracy                           0.75       390
#    macro avg       0.67      0.65      0.66       390
# weighted avg       0.74      0.75      0.74       390
#
#
# Time taken to predict the model 0.0017080307006835938
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56       140
#            1       0.75      0.76      0.75       250
#
#     accuracy                           0.68       390
#    macro avg       0.66      0.66      0.66       390
# weighted avg       0.68      0.68      0.68       390
#
#
# Time taken to predict the model 0.0037698745727539062
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.52      0.55       128
#            1       0.78      0.82      0.80       262
#
#     accuracy                           0.72       390
#    macro avg       0.68      0.67      0.67       390
# weighted avg       0.71      0.72      0.72       390
#
#
# Time taken to predict the model 0.0021009445190429688
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.50      0.53       136
#            1       0.75      0.79      0.77       253
#
#     accuracy                           0.69       389
#    macro avg       0.65      0.65      0.65       389
# weighted avg       0.68      0.69      0.68       389
#
#
# Time taken to predict the model 0.002498149871826172
#
# ________________________________________________________
#
#
# Classifier :  AdaBoostClassifier
#               precision    recall  f1-score   support
#
#            0       0.77      0.36      0.49       138
#            1       0.73      0.94      0.82       252
#
#     accuracy                           0.74       390
#    macro avg       0.75      0.65      0.66       390
# weighted avg       0.74      0.74      0.71       390
#
#
# Time taken to predict the model 0.02628922462463379
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.30      0.40       102
#            1       0.79      0.92      0.85       288
#
#     accuracy                           0.76       390
#    macro avg       0.68      0.61      0.62       390
# weighted avg       0.73      0.76      0.73       390
#
#
# Time taken to predict the model 0.025995969772338867
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.34      0.45       140
#            1       0.71      0.90      0.79       250
#
#     accuracy                           0.70       390
#    macro avg       0.68      0.62      0.62       390
# weighted avg       0.69      0.70      0.67       390
#
#
# Time taken to predict the model 0.02610921859741211
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.26      0.37       128
#            1       0.72      0.94      0.81       262
#
#     accuracy                           0.71       390
#    macro avg       0.69      0.60      0.59       390
# weighted avg       0.70      0.71      0.67       390
#
#
# Time taken to predict the model 0.024348735809326172
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.30      0.41       136
#            1       0.71      0.91      0.80       253
#
#     accuracy                           0.70       389
#    macro avg       0.68      0.61      0.60       389
# weighted avg       0.69      0.70      0.66       389
#
#
# Time taken to predict the model 0.027650833129882812
#
# ________________________________________________________
#
#
# Classifier :  VotingClassifier
#               precision    recall  f1-score   support
#
#            0       0.60      0.52      0.56       138
#            1       0.76      0.81      0.78       252
#
#     accuracy                           0.71       390
#    macro avg       0.68      0.67      0.67       390
# weighted avg       0.70      0.71      0.70       390
#
#
# Time taken to predict the model 0.08474421501159668
#               precision    recall  f1-score   support
#
#            0       0.55      0.42      0.48       102
#            1       0.81      0.88      0.84       288
#
#     accuracy                           0.76       390
#    macro avg       0.68      0.65      0.66       390
# weighted avg       0.74      0.76      0.75       390
#
#
# Time taken to predict the model 0.08729982376098633
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.59      0.63       140
#            1       0.78      0.84      0.81       250
#
#     accuracy                           0.75       390
#    macro avg       0.73      0.71      0.72       390
# weighted avg       0.75      0.75      0.75       390
#
#
# Time taken to predict the model 0.14146900177001953
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.48      0.54       128
#            1       0.77      0.85      0.81       262
#
#     accuracy                           0.73       390
#    macro avg       0.69      0.66      0.67       390
# weighted avg       0.72      0.73      0.72       390
#
#
# Time taken to predict the model 0.08660078048706055
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.45      0.52       136
#            1       0.74      0.85      0.79       253
#
#     accuracy                           0.71       389
#    macro avg       0.68      0.65      0.65       389
# weighted avg       0.69      0.71      0.69       389
#
#
# Time taken to predict the model 0.0906369686126709
#
# ________________________________________________________

# %%
output_df
# Out:
#                      model  accuracy  precision    recall       mse       mae  \
# 0                SimpleRNN  0.671282   0.503475  0.024514  0.221250  0.430087
# 1                     LSTM  0.672821   0.575788  0.035619  0.219245  0.432190
# 2                      GRU  0.672308   0.557554  0.026722  0.221304  0.433752
# 3              BernoulliNB  0.695722   0.699594  0.695722  0.304278  0.304278
# 4             ComplementNB  0.683404   0.703822  0.683404  0.316596  0.316596
# 5            MultinomialNB  0.703426   0.704713  0.703426  0.296574  0.296574
# 6       LogisticRegression  0.718815   0.707197  0.718815  0.281185  0.281185
# 7     KNeighborsClassifier  0.695737   0.693563  0.695737  0.304263  0.304263
# 8   DecisionTreeClassifier  0.715234   0.714041  0.715234  0.284766  0.284766
# 9   RandomForestClassifier  0.743454   0.734843  0.743454  0.256546  0.256546
# 10           MLPClassifier  0.706507   0.700287  0.706507  0.293493  0.293493
# 11      AdaBoostClassifier  0.721384   0.711211  0.721384  0.278616  0.278616
# 12        VotingClassifier  0.730619   0.720250  0.730619  0.269381  0.269381
#
#          auc  f1_score  prediction time
# 0   0.686187  0.439429         0.079840
# 1   0.687364  0.416665         0.451108
# 2   0.681118  0.420505         0.145833
# 3   0.659656  0.697312         0.004949
# 4   0.668479  0.690060         0.002664
# 5   0.664243  0.703886         0.002902
# 6   0.653870  0.708709         0.002438
# 7   0.644164  0.691724         0.030278
# 8   0.671720  0.714474         0.002189
# 9   0.672160  0.729959         0.017452
# 10  0.654624  0.702518         0.002272
# 11  0.617715  0.687670         0.026079
# 12  0.668310  0.721955         0.098150

# %%
output_df.to_csv('classifiers_output_result.csv', sep='\t')
