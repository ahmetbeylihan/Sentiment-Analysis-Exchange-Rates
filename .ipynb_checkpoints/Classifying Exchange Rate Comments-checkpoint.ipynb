# %%
import re
from TextCleaner import TextCleaner
import pandas as pd
import numpy as np
import time
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sn
import keras_metrics as km
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold
from numpy import sqrt 
# %matplotlib inline
import nltk
from langdetect import detect
import contractions
from nltk.corpus import stopwords
from textblob import Word
from sklearn.preprocessing import LabelEncoder
from collections import Counter
from wordcloud import WordCloud
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem.snowball import PorterStemmer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split 

from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, GRU, SimpleRNN, SpatialDropout1D
from tensorflow.keras.layers import SpatialDropout1D
from tensorflow.keras.layers import Embedding
from tensorflow.python.keras.metrics import Metric
import tensorflow as tf    
import tensorflow_addons as tfa
from tensorflow import keras 
from keras.metrics import Precision, Recall

# Classifiers
from sklearn.naive_bayes import BernoulliNB
from sklearn import metrics
from sklearn.naive_bayes import (
    BernoulliNB,
    ComplementNB,
    MultinomialNB,
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
pd.options.mode.chained_assignment = None  # default='warn'

# %%
df = pd.read_csv('sentiment.csv')
df = df.drop(df.columns[0], axis=1)
df
# Out:
#                Author                                               Text  \
# 0            yusobays  @elonmusk @elonmusk  please Come to TRY₺ #turk...
# 1       BtcTurkDestek  @DrBatal  Hello, if you have registered using ...
# 2      RisingValhalla  “I trade weekly bars. You?”\n\n200 day moving ...
# 3        Erda55203615  @elonmusk Try turkish lira its at the bottom m...
# 4        Erda55203615            @ImTooRealForU TRY FUCKING TURKISH LIRA
# ...               ...                                                ...
# 1944  flyingstocksman  For those of you who missed it last night with...
# 1945         alpeshbp  GBP/USD Weekly Price Forecast – The British Po...
# 1946     campsbay_com  20.0142 ZAR for 1 GBP @ December 31, 2020 at 0...
# 1947       MajorFXNow  GBP/EUR: Pound Lifted by UK Approval of AstraZ...
# 1948     trader_blitz  GBP/JPY | $GBPJPY | $GBP $JPY\n\nBRITISH POUND...
#
#                            Time  Like Count Currency ISO Code  \
# 0     2021-01-31 22:21:58+00:00           1               TRY
# 1     2021-01-30 18:07:15+00:00           0               TRY
# 2     2021-01-30 03:29:59+00:00           0               TRY
# 3     2021-01-29 20:20:49+00:00           0               TRY
# 4     2021-01-29 20:19:36+00:00           0               TRY
# ...                         ...         ...               ...
# 1944  2021-01-01 09:24:17+00:00           0               GBP
# 1945  2021-01-01 07:13:32+00:00           0               GBP
# 1946  2021-01-01 04:20:02+00:00           0               GBP
# 1947  2021-01-01 02:32:32+00:00           0               GBP
# 1948  2021-01-01 00:42:01+00:00           0               GBP
#
#                                                     Url  target
# 0     https://twitter.com/yusobays/status/1356004827...     0.0
# 1     https://twitter.com/BtcTurkDestek/status/13555...     0.0
# 2     https://twitter.com/RisingValhalla/status/1355...     0.0
# 3     https://twitter.com/Erda55203615/status/135524...    -1.0
# 4     https://twitter.com/Erda55203615/status/135524...    -1.0
# ...                                                 ...     ...
# 1944  https://twitter.com/flyingstocksman/status/134...     0.0
# 1945  https://twitter.com/alpeshbp/status/1344904575...     0.0
# 1946  https://twitter.com/campsbay_com/status/134486...     0.0
# 1947  https://twitter.com/MajorFXNow/status/13448338...     0.0
# 1948  https://twitter.com/trader_blitz/status/134480...     0.0
#
# [1949 rows x 7 columns]

# %%
def sentiments(df):
    if df['target'] >= 0:
        return 'Positive'
    elif df['target'] < 0:
        return 'Negative'

# %%
df['Sentiment'] = df.apply(sentiments, axis=1)

# %%
df
# Out:
#                Author                                               Text  \
# 0            yusobays  @elonmusk @elonmusk  please Come to TRY₺ #turk...
# 1       BtcTurkDestek  @DrBatal  Hello, if you have registered using ...
# 2      RisingValhalla  “I trade weekly bars. You?”\n\n200 day moving ...
# 3        Erda55203615  @elonmusk Try turkish lira its at the bottom m...
# 4        Erda55203615            @ImTooRealForU TRY FUCKING TURKISH LIRA
# ...               ...                                                ...
# 1944  flyingstocksman  For those of you who missed it last night with...
# 1945         alpeshbp  GBP/USD Weekly Price Forecast – The British Po...
# 1946     campsbay_com  20.0142 ZAR for 1 GBP @ December 31, 2020 at 0...
# 1947       MajorFXNow  GBP/EUR: Pound Lifted by UK Approval of AstraZ...
# 1948     trader_blitz  GBP/JPY | $GBPJPY | $GBP $JPY\n\nBRITISH POUND...
#
#                            Time  Like Count Currency ISO Code  \
# 0     2021-01-31 22:21:58+00:00           1               TRY
# 1     2021-01-30 18:07:15+00:00           0               TRY
# 2     2021-01-30 03:29:59+00:00           0               TRY
# 3     2021-01-29 20:20:49+00:00           0               TRY
# 4     2021-01-29 20:19:36+00:00           0               TRY
# ...                         ...         ...               ...
# 1944  2021-01-01 09:24:17+00:00           0               GBP
# 1945  2021-01-01 07:13:32+00:00           0               GBP
# 1946  2021-01-01 04:20:02+00:00           0               GBP
# 1947  2021-01-01 02:32:32+00:00           0               GBP
# 1948  2021-01-01 00:42:01+00:00           0               GBP
#
#                                                     Url  target Sentiment
# 0     https://twitter.com/yusobays/status/1356004827...     0.0  Positive
# 1     https://twitter.com/BtcTurkDestek/status/13555...     0.0  Positive
# 2     https://twitter.com/RisingValhalla/status/1355...     0.0  Positive
# 3     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# 4     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# ...                                                 ...     ...       ...
# 1944  https://twitter.com/flyingstocksman/status/134...     0.0  Positive
# 1945  https://twitter.com/alpeshbp/status/1344904575...     0.0  Positive
# 1946  https://twitter.com/campsbay_com/status/134486...     0.0  Positive
# 1947  https://twitter.com/MajorFXNow/status/13448338...     0.0  Positive
# 1948  https://twitter.com/trader_blitz/status/134480...     0.0  Positive
#
# [1949 rows x 8 columns]

# %%
data_v1 = df[['Text','Sentiment']]
data_v1.isnull().sum()
# Out:
# Text         0
# Sentiment    0
# dtype: int64

# %%
plt.figure(figsize=(7,8))
plt.title("Number of records of positive and negative sentiments")
plot = sn.countplot(x = 'Sentiment', data = data_v1)
for p in plot.patches:
    plot.annotate(p.get_height(),(p.get_x() + 0.2 ,p.get_height()+80))

# %%
clean = TextCleaner()
text = clean.convert_emoji_to_text("Hilarious 😂. The feeling of making a sale 😎, The feeling of actually fulfilling orders 😒")
print(text)

text4 = "Hello :-) :-)"
resp = clean.convert_emoticons(text4)
print(resp)
# Out:
# Hilarious face with tears of joy. The feeling of making a sale smiling face with sunglasses, The feeling of actually fulfilling orders unamused face
# Hello Happy face smiley Happy face smiley

# %%
df
# Out:
#                Author                                               Text  \
# 0            yusobays  @elonmusk @elonmusk  please Come to TRY₺ #turk...
# 1       BtcTurkDestek  @DrBatal  Hello, if you have registered using ...
# 2      RisingValhalla  “I trade weekly bars. You?”\n\n200 day moving ...
# 3        Erda55203615  @elonmusk Try turkish lira its at the bottom m...
# 4        Erda55203615            @ImTooRealForU TRY FUCKING TURKISH LIRA
# ...               ...                                                ...
# 1944  flyingstocksman  For those of you who missed it last night with...
# 1945         alpeshbp  GBP/USD Weekly Price Forecast – The British Po...
# 1946     campsbay_com  20.0142 ZAR for 1 GBP @ December 31, 2020 at 0...
# 1947       MajorFXNow  GBP/EUR: Pound Lifted by UK Approval of AstraZ...
# 1948     trader_blitz  GBP/JPY | $GBPJPY | $GBP $JPY\n\nBRITISH POUND...
#
#                            Time  Like Count Currency ISO Code  \
# 0     2021-01-31 22:21:58+00:00           1               TRY
# 1     2021-01-30 18:07:15+00:00           0               TRY
# 2     2021-01-30 03:29:59+00:00           0               TRY
# 3     2021-01-29 20:20:49+00:00           0               TRY
# 4     2021-01-29 20:19:36+00:00           0               TRY
# ...                         ...         ...               ...
# 1944  2021-01-01 09:24:17+00:00           0               GBP
# 1945  2021-01-01 07:13:32+00:00           0               GBP
# 1946  2021-01-01 04:20:02+00:00           0               GBP
# 1947  2021-01-01 02:32:32+00:00           0               GBP
# 1948  2021-01-01 00:42:01+00:00           0               GBP
#
#                                                     Url  target Sentiment
# 0     https://twitter.com/yusobays/status/1356004827...     0.0  Positive
# 1     https://twitter.com/BtcTurkDestek/status/13555...     0.0  Positive
# 2     https://twitter.com/RisingValhalla/status/1355...     0.0  Positive
# 3     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# 4     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# ...                                                 ...     ...       ...
# 1944  https://twitter.com/flyingstocksman/status/134...     0.0  Positive
# 1945  https://twitter.com/alpeshbp/status/1344904575...     0.0  Positive
# 1946  https://twitter.com/campsbay_com/status/134486...     0.0  Positive
# 1947  https://twitter.com/MajorFXNow/status/13448338...     0.0  Positive
# 1948  https://twitter.com/trader_blitz/status/134480...     0.0  Positive
#
# [1949 rows x 8 columns]

# %%
def remove_url(text):
    result = re.sub(r'https?:\/\/\S*', '', text, flags=re.MULTILINE)
    return result

def replace_contractions(text):
    return contractions.fix(text)

abbs =  {"eur": "euro", "usd": "dollar", "gbp" : "pound", "u":"you", "tryeur":"turkish lira euro", "try":" turkish lira", "gt":"greater than","lt": "less than","btc":"bitcoin",
        "gbpusd": "pound dollar", "usdtry":"dollar turkish lira", "fx":"forex", "u":"you", "eurusd":"euro usd", "eurgbp":"euro pound", "jpy":"japanese yen","cny":"chinese yuan","uk":"united kingdom"}

def replace_currency(text):
    val = ''
    for i in text.split():
        if abbs.get(i.lower().strip()) is not None:
            #print(abbs.get(i.lower().strip()))
            val = val + str(abbs.get(i.lower().strip())) + ' '
        else:
            val = val + i + ' '
    return val

# %%
print(remove_url(df['Text'].iloc[1942]))
# Out:
# Visit  to check the latest #bitcoin price in #gbp #uk #pound. You can also use our free $GBP to $BTC price converter.

# %%
print(replace_currency("@elonmusk Try turkish lira its at the bottom"))
# Out:
# @elonmusk  turkish lira turkish lira its at the bottom

# %%
clean = TextCleaner()

def cleaning(df_cl, stop_words):
    
    # Removing URLs
    df_cl["Text"] = df_cl["Text"].apply(lambda x: remove_url(x))
    
     # Removing mentioned author names
    df_cl["Text"] = df_cl["Text"].apply(lambda x: re.sub("@[A-Za-z0-9]+","", x))
    
    # Lowercase
    df_cl['Text'] = df_cl['Text'].apply(lambda x: ' '.join(x.lower() for x in x.split()))
    
    df_cl["Text"] = df_cl["Text"].apply(lambda x: replace_contractions(x))
    
    df_cl["Text"] = df_cl["Text"].apply(lambda x: replace_currency(x))
    
     # Remove Non -letters
    df_cl['Text'] = df_cl['Text'].apply(lambda x: re.sub(r"[^a-zA-Z0-9]", ' ', x))
    
    # Removing Punctuation
    df_cl["Text"] = df_cl["Text"].apply(lambda x: re.sub(r'[^\w\s]','', x))
    
    # Removing stop words
    df_cl['Text'] = df_cl['Text'].apply(lambda x:' '.join(x for x in x.split() if x not in stop_words))
    
    # Lemmatization
    df_cl['Text'] = df_cl['Text'].apply(lambda x:' '.join([Word(x).lemmatize() for x in x.split()]))
    
    # Emoticons
    df_cl['Text'] = df_cl['Text'].apply(lambda x: clean.convert_emoji_to_text(x))
    
    # Emojis
    df_cl['Text'] = df_cl['Text'].apply(lambda x: clean.convert_emoji_to_text(x))    
    
    # Stemming
    #df_cl['Text'] = df_cl['Text'].apply(lambda x: port_stemmer(x))
    return df_cl

stop_words = stopwords.words('english')

# %%
data_v1 = cleaning(data_v1, stop_words)

# %%
data_v1
# Out:
#                                                    Text Sentiment
# 0                           please come try turkishlira  Positive
# 1     hello registered using turkish citizenship id ...  Positive
# 2     trade weekly bar 200 day moving average breach...  Positive
# 3       turkish lira turkish lira bottom maybe would go  Negative
# 4                     turkish lira fucking turkish lira  Negative
# ...                                                 ...       ...
# 1944  missed last night nye potentially important tw...  Positive
# 1945  gbp usd weekly price forecast british pound lo...  Positive
# 1946  20 0142 zar 1 pound december 31 2020 06 20am s...  Positive
# 1947  gbp eur pound lifted united kingdom approval a...  Positive
# 1948  gbp jpy gbpjpy gbp jpy british pound brexit br...  Positive
#
# [1949 rows x 2 columns]

# %%
common_words = ''
for i in data_v1.Text:
    i = str(i)
    tokens = i.split()
    common_words += " ".join(tokens)+" "
wordcloud = WordCloud(width=1600, height=800).generate(common_words)
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
lb = LabelEncoder()
data_v1['Sentiment'] = lb.fit_transform(data_v1['Sentiment'])

# %%
tokenizer = Tokenizer(num_words=1000, split=' ', lower=True) 
tokenizer.fit_on_texts(data_v1['Text'].values)
X = tokenizer.texts_to_sequences(df['Text'].values)
X = pad_sequences(X)

# %%
y = pd.get_dummies(data_v1['Sentiment'])

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# <h3>Time Series Methodologies</h3>
# <h4>Defining Models</h4>

# %%
models = [ 'SimpleRNN', 'LSTM', 'GRU']

# %%
METRICS = [ 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      km.binary_precision(), 
      km.binary_recall(),
      'mse', 
      'mae', 
      keras.metrics.AUC(name='auc'),
      tfa.metrics.F1Score(num_classes=2, threshold=0.5, average='macro'),
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn')
]
# Out:
# 2022-03-20 15:46:22.787040: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def build_model(nb_words, _model="SimpleRNN", embedding_matrix=None):
    model = Sequential()
    model.add(Embedding(input_dim=1000, output_dim=64, input_length = nb_words))
    if _model == "SimpleRNN":
        model.add(SimpleRNN(128, dropout=0.1, recurrent_dropout=0.1, activation='relu'))
    elif _model == "LSTM":
        model.add(LSTM(100, return_sequences=True))
        model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.1, activation='relu'))
    elif _model == "GRU":
        model.add(GRU(128))
    model.add(Dense(2, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=[METRICS])
    return model

# %%
print(X.shape)
print(y.shape)
# Out:
# (1949, 38)
# (1949, 2)

# %%
tsa_classifiers = []

# %%
output_df = pd.DataFrame(columns=['model', 'accuracy', 'precision', 'recall', 'mse', 'mae', 'auc', 'f1_score', 'prediction time'])

seed = 5
kfold = KFold(seed, True, 7)
cvscores = []

batch_size = 64

x1=np.array(X)
y1=np.array(y)

for idx, mdl in enumerate(models):
    accuracy = precision = recall = mse = mae = auc = f1_score_val = prediction_time = 0
    
    print("Model : " + str(mdl))
    model_ = build_model(X.shape[1], mdl, None)
    
    keras_model = KerasClassifier(build_fn=model_)
    keras_model._estimator_type = "classifier"    
    tsa_classifiers.append(( str(mdl), keras_model  ))
    
    print("Model Summary")
    print(model_.summary())
    
    for train_index, test_index in kfold.split(x1,y1):
        X_train, X_test, y_train, y_test = x1[train_index], x1[test_index], y1[train_index], y1[test_index]   
        model_.fit(X_train, y_train, epochs=5, validation_split=0.2, batch_size=batch_size, verbose = 'auto', shuffle=False, validation_data=(X_test,y_test))
        
        
        start_time = time.time()
        y_pred = model_.predict(X_test)
        end_time = time.time() - start_time
        print("")

        scores = model_.evaluate(X_test, y_test)
        print("%s: %.2f%%" % (model_.metrics_names[1], scores[1]*100))    
        print("")
        accuracy += scores[1]
        precision += scores[2]
        recall += scores[3]
        mse += scores[4]
        mae += scores[5]
        auc += scores[6]
        f1_score_val += scores[7]
        prediction_time += end_time
        
        #print("")
        #print("Time taken to predict the model " + str(end_time))

    output_df = output_df.append([{'model': str(mdl), 'accuracy':accuracy/seed,'precision':precision/seed
                                       ,'recall':recall/seed,'mse':mse/seed,'mae':mae/seed
                                       ,'auc':auc/seed,'f1_score':f1_score_val/seed, 'prediction time': prediction_time/seed}], ignore_index=True)

    yhat = model_.predict_on_batch(X_test)
    #print("yhat[:,1]",yhat[:,1])
    #print("y_test",y_test)
    fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test[:,1], yhat[:,1])
    plt.rcParams["figure.figsize"] = (10,7)
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr_rf, tpr_rf, label=str(mdl) + ' (area = {:.3f})'.format(auc/seed))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.savefig('tsa_roc_curve.png')

    #print(classification_report(y_test.values.argmax(axis=1), y_pred.argmax(axis=1)))
    print("___________________________________________________________________________________")

    print("")
    print("")
    print("")
    
plt.show()
# Out:
# Model : SimpleRNN
# Model Summary
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 38, 64)            64000
#
#  simple_rnn (SimpleRNN)      (None, 128)               24704
#
#  dense (Dense)               (None, 2)                 258
#
# =================================================================
# Total params: 88,962
# Trainable params: 88,962
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass shuffle=True, random_state=7 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /var/folders/33/v0__8kvs301dg744qmtfs33w0000gn/T/ipykernel_7461/2981902032.py:18: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_model = KerasClassifier(build_fn=model_)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /opt/anaconda3/lib/python3.9/site-packages/keras_metrics/metrics.py:26: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return object.__getattribute__(self, name)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 19/20 [===========================>..] - ETA: 0s - loss: 0.7014 - accuracy: 0.6480 - precision: 0.1538 - recall: 0.0301 - mse: 0.2525 - mae: 0.4824 - auc: 0.5736 - f1_score: 0.3976 - tp: 788.0000 - fp: 428.0000 - tn: 788.0000 - fn: 428.0000WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 20/20 [==============================] - 3s 44ms/step - loss: 0.6950 - accuracy: 0.6568 - precision: 0.1538 - recall: 0.0288 - mse: 0.2494 - mae: 0.4793 - auc: 0.5843 - f1_score: 0.4008 - tp: 819.0000 - fp: 428.0000 - tn: 819.0000 - fn: 428.0000 - val_loss: 0.6126 - val_accuracy: 0.7212 - val_precision: 0.1538 - val_recall: 0.0042 - val_mse: 0.2104 - val_mae: 0.4452 - val_auc: 0.7283 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 2/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6479 - accuracy: 0.6640 - precision: 0.1538 - recall: 0.0030 - mse: 0.2276 - mae: 0.4619 - auc: 0.6239 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.6138 - val_accuracy: 0.7212 - val_precision: 0.1538 - val_recall: 0.0020 - val_mse: 0.2110 - val_mae: 0.4464 - val_auc: 0.7302 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 3/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6513 - accuracy: 0.6640 - precision: 0.1538 - recall: 0.0017 - mse: 0.2290 - mae: 0.4572 - auc: 0.6082 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.6046 - val_accuracy: 0.7212 - val_precision: 0.1538 - val_recall: 0.0013 - val_mse: 0.2067 - val_mae: 0.4357 - val_auc: 0.7276 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 4/5
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6467 - accuracy: 0.6640 - precision: 0.1538 - recall: 0.0012 - mse: 0.2268 - mae: 0.4507 - auc: 0.6237 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.6028 - val_accuracy: 0.7212 - val_precision: 0.1538 - val_recall: 0.0010 - val_mse: 0.2059 - val_mae: 0.4331 - val_auc: 0.7279 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 4/5
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6389 - accuracy: 0.6672 - precision: 0.5957 - recall: 0.0039 - mse: 0.2232 - mae: 0.4479 - auc: 0.6647 - f1_score: 0.4093 - tp: 832.0000 - fp: 415.0000 - tn: 832.0000 - fn: 415.0000 - val_loss: 0.5992 - val_accuracy: 0.7244 - val_precision: 0.5833 - val_recall: 0.0037 - val_mse: 0.2042 - val_mae: 0.4309 - val_auc: 0.7396 - val_f1_score: 0.4201 - val_tp: 226.0000 - val_fp: 86.0000 - val_tn: 226.0000 - val_fn: 86.0000
# Epoch 5/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6381 - accuracy: 0.6680 - precision: 0.6207 - recall: 0.0044 - mse: 0.2228 - mae: 0.4469 - auc: 0.6669 - f1_score: 0.4140 - tp: 833.0000 - fp: 414.0000 - tn: 833.0000 - fn: 414.0000 - val_loss: 0.5995 - val_accuracy: 0.7244 - val_precision: 0.6071 - val_recall: 0.0043 - val_mse: 0.2043 - val_mae: 0.4313 - val_auc: 0.7425 - val_f1_score: 0.4201 - val_tp: 226.0000 - val_fp: 86.0000 - val_tn: 226.0000 - val_fn: 86.0000
#
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6441 - accuracy: 0.6385 - precision: 0.5995 - recall: 0.0043 - mse: 0.2261 - mae: 0.4526 - auc: 0.6822 - f1_score: 0.3963 - tp: 249.0000 - fp: 141.0000 - tn: 249.0000 - fn: 141.0000
# accuracy: 63.85%
#
# Epoch 1/5
# 20/20 [==============================] - 0s 15ms/step - loss: 0.6391 - accuracy: 0.6568 - precision: 0.6006 - recall: 0.0050 - mse: 0.2235 - mae: 0.4483 - auc: 0.6762 - f1_score: 0.4136 - tp: 819.0000 - fp: 428.0000 - tn: 819.0000 - fn: 428.0000 - val_loss: 0.6076 - val_accuracy: 0.7212 - val_precision: 0.5778 - val_recall: 0.0051 - val_mse: 0.2081 - val_mae: 0.4355 - val_auc: 0.7198 - val_f1_score: 0.4299 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 2/5
# 20/20 [==============================] - 0s 15ms/step - loss: 0.6378 - accuracy: 0.6632 - precision: 0.6071 - recall: 0.0060 - mse: 0.2227 - mae: 0.4456 - auc: 0.6743 - f1_score: 0.4266 - tp: 827.0000 - fp: 420.0000 - tn: 827.0000 - fn: 420.0000 - val_loss: 0.6097 - val_accuracy: 0.7212 - val_precision: 0.6097 - val_recall: 0.0063 - val_mse: 0.2091 - val_mae: 0.4355 - val_auc: 0.7168 - val_f1_score: 0.4299 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 3/5
# Epoch 3/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6230 - accuracy: 0.6811 - precision: 0.6182 - recall: 0.0181 - mse: 0.2160 - mae: 0.4350 - auc: 0.6974 - f1_score: 0.4605 - tp: 850.0000 - fp: 398.0000 - tn: 850.0000 - fn: 398.0000 - val_loss: 0.6237 - val_accuracy: 0.7019 - val_precision: 0.6204 - val_recall: 0.0186 - val_mse: 0.2158 - val_mae: 0.4381 - val_auc: 0.6963 - val_f1_score: 0.4593 - val_tp: 219.0000 - val_fp: 93.0000 - val_tn: 219.0000 - val_fn: 93.0000
# Epoch 4/5
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6224 - accuracy: 0.6739 - precision: 0.6185 - recall: 0.0196 - mse: 0.2159 - mae: 0.4305 - auc: 0.6999 - f1_score: 0.4415 - tp: 841.0000 - fp: 407.0000 - tn: 841.0000 - fn: 407.0000 - val_loss: 0.6252 - val_accuracy: 0.7051 - val_precision: 0.6208 - val_recall: 0.0196 - val_mse: 0.2164 - val_mae: 0.4372 - val_auc: 0.6939 - val_f1_score: 0.4522 - val_tp: 220.0000 - val_fp: 92.0000 - val_tn: 220.0000 - val_fn: 92.0000
# Epoch 5/5
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6167 - accuracy: 0.6755 - precision: 0.6209 - recall: 0.0208 - mse: 0.2132 - mae: 0.4270 - auc: 0.7150 - f1_score: 0.4594 - tp: 843.0000 - fp: 405.0000 - tn: 843.0000 - fn: 405.0000 - val_loss: 0.6278 - val_accuracy: 0.6955 - val_precision: 0.6174 - val_recall: 0.0213 - val_mse: 0.2176 - val_mae: 0.4367 - val_auc: 0.6928 - val_f1_score: 0.4642 - val_tp: 217.0000 - val_fp: 95.0000 - val_tn: 217.0000 - val_fn: 95.0000
#
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6122 - accuracy: 0.6735 - precision: 0.6198 - recall: 0.0219 - mse: 0.2115 - mae: 0.4286 - auc: 0.7221 - f1_score: 0.4834 - tp: 262.0000 - fp: 127.0000 - tn: 262.0000 - fn: 127.0000
# accuracy: 67.35%
#
# ___________________________________________________________________________________
#
#
#
# Model : LSTM
# Model Summary
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 38, 64)            64000
#
#  lstm (LSTM)                 (None, 38, 100)           66000
#
#  lstm_1 (LSTM)               (None, 128)               117248
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 247,506
# Trainable params: 247,506
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# /var/folders/33/v0__8kvs301dg744qmtfs33w0000gn/T/ipykernel_7461/2981902032.py:18: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_model = KerasClassifier(build_fn=model_)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /opt/anaconda3/lib/python3.9/site-packages/keras_metrics/metrics.py:26: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return object.__getattribute__(self, name)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 20/20 [==============================] - ETA: 0s - loss: 0.6995 - accuracy: 0.6650 - precision: 0.6173 - recall: 0.0219 - mse: 0.2509 - mae: 0.4753 - auc: 0.6256 - f1_score: 0.4211 - tp: 1088.0000 - fp: 548.0000 - tn: 1088.0000 - fn: 548.0000WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 20/20 [==============================] - 6s 127ms/step - loss: 0.6995 - accuracy: 0.6650 - precision: 0.6173 - recall: 0.0219 - mse: 0.2509 - mae: 0.4753 - auc: 0.6256 - f1_score: 0.4211 - tp: 1088.0000 - fp: 548.0000 - tn: 1088.0000 - fn: 548.0000 - val_loss: 0.6242 - val_accuracy: 0.7212 - val_precision: 0.6173 - val_recall: 0.0214 - val_mse: 0.2159 - val_mae: 0.4560 - val_auc: 0.7170 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 2/5
# 20/20 [==============================] - 2s 100ms/step - loss: 0.6546 - accuracy: 0.6640 - precision: 0.6173 - recall: 0.0211 - mse: 0.2308 - mae: 0.4744 - auc: 0.6381 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.6338 - val_accuracy: 0.7212 - val_precision: 0.6173 - val_recall: 0.0207 - val_mse: 0.2205 - val_mae: 0.4639 - val_auc: 0.7219 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 3/5
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 38, 64)            64000
#
#  gru (GRU)                   (None, 128)               74496
#
#  dense_2 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 138,754
# Trainable params: 138,754
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# /var/folders/33/v0__8kvs301dg744qmtfs33w0000gn/T/ipykernel_7461/2981902032.py:18: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_model = KerasClassifier(build_fn=model_)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /opt/anaconda3/lib/python3.9/site-packages/keras_metrics/metrics.py:26: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return object.__getattribute__(self, name)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 18/20 [==========================>...] - ETA: 0s - loss: 0.6841 - accuracy: 0.6697 - precision: 0.6173 - recall: 0.0110 - mse: 0.2436 - mae: 0.4653 - auc: 0.6121 - f1_score: 0.4011 - tp: 1032.0000 - fp: 509.0000 - tn: 1032.0000 - fn: 509.0000WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 20/20 [==============================] - 3s 74ms/step - loss: 0.6905 - accuracy: 0.6608 - precision: 0.6173 - recall: 0.0110 - mse: 0.2467 - mae: 0.4677 - auc: 0.6014 - f1_score: 0.3979 - tp: 1081.0000 - fp: 555.0000 - tn: 1081.0000 - fn: 555.0000 - val_loss: 0.5972 - val_accuracy: 0.7212 - val_precision: 0.6173 - val_recall: 0.0109 - val_mse: 0.2034 - val_mae: 0.4250 - val_auc: 0.7383 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 2/5
# 20/20 [==============================] - 1s 33ms/step - loss: 0.6414 - accuracy: 0.6640 - precision: 0.6173 - recall: 0.0108 - mse: 0.2245 - mae: 0.4499 - auc: 0.6434 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.6039 - val_accuracy: 0.7212 - val_precision: 0.6173 - val_recall: 0.0107 - val_mse: 0.2064 - val_mae: 0.4354 - val_auc: 0.7394 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 3/5
# 20/20 [==============================] - 1s 32ms/step - loss: 0.6472 - accuracy: 0.6640 - precision: 0.6173 - recall: 0.0106 - mse: 0.2271 - mae: 0.4519 - auc: 0.6120 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.6006 - val_accuracy: 0.7212 - val_precision: 0.6173 - val_recall: 0.0105 - val_mse: 0.2049 - val_mae: 0.4308 - val_auc: 0.7366 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 4/5
# 20/20 [==============================] - 1s 33ms/step - loss: 0.6459 - accuracy: 0.6640 - precision: 0.6173 - recall: 0.0104 - mse: 0.2264 - mae: 0.4488 - auc: 0.6175 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5996 - val_accuracy: 0.7212 - val_precision: 0.6173 - val_recall: 0.0103 - val_mse: 0.2044 - val_mae: 0.4292 - val_auc: 0.7407 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 5/5
# 20/20 [==============================] - 1s 47ms/step - loss: 0.6447 - accuracy: 0.6640 - precision: 0.6173 - recall: 0.0103 - mse: 0.2259 - mae: 0.4481 - auc: 0.6249 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5997 - val_accuracy: 0.7212 - val_precision: 0.6173 - val_recall: 0.0102 - val_mse: 0.2045 - val_mae: 0.4295 - val_auc: 0.7390 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
#
# 13/13 [==============================] - 0s 9ms/step - loss: 0.6486 - accuracy: 0.6462 - precision: 0.6173 - recall: 0.0101 - mse: 0.2281 - mae: 0.4533 - auc: 0.6628 - f1_score: 0.3925 - tp: 252.0000 - fp: 138.0000 - tn: 252.0000 - fn: 138.0000
# accuracy: 64.62%
#
# Epoch 1/5
# 20/20 [==============================] - 1s 34ms/step - loss: 0.6532 - accuracy: 0.6447 - precision: 0.6173 - recall: 0.0100 - mse: 0.2302 - mae: 0.4550 - auc: 0.6252 - f1_score: 0.3920 - tp: 804.0000 - fp: 443.0000 - tn: 804.0000 - fn: 443.0000 - val_loss: 0.6256 - val_accuracy: 0.6827 - val_precision: 0.6173 - val_recall: 0.0099 - val_mse: 0.2170 - val_mae: 0.4453 - val_auc: 0.7063 - val_f1_score: 0.4057 - val_tp: 213.0000 - val_fp: 99.0000 - val_tn: 213.0000 - val_fn: 99.0000
# Epoch 2/5
# 20/20 [==============================] - 1s 36ms/step - loss: 0.6536 - accuracy: 0.6447 - precision: 0.6173 - recall: 0.0099 - mse: 0.2303 - mae: 0.4579 - auc: 0.6220 - f1_score: 0.3920 - tp: 804.0000 - fp: 443.0000 - tn: 804.0000 - fn: 443.0000 - val_loss: 0.6260 - val_accuracy: 0.6827 - val_precision: 0.6173 - val_recall: 0.0098 - val_mse: 0.2172 - val_mae: 0.4466 - val_auc: 0.7072 - val_f1_score: 0.4057 - val_tp: 213.0000 - val_fp: 99.0000 - val_tn: 213.0000 - val_fn: 99.0000
# Epoch 3/5
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6541 - accuracy: 0.6447 - precision: 0.6173 - recall: 0.0097 - mse: 0.2306 - mae: 0.4583 - auc: 0.6195 - f1_score: 0.3920 - tp: 804.0000 - fp: 443.0000 - tn: 804.0000 - fn: 443.0000 - val_loss: 0.6256 - val_accuracy: 0.6827 - val_precision: 0.6173 - val_recall: 0.0096 - val_mse: 0.2170 - val_mae: 0.4461 - val_auc: 0.7062 - val_f1_score: 0.4057 - val_tp: 213.0000 - val_fp: 99.0000 - val_tn: 213.0000 - val_fn: 99.0000
# Epoch 4/5
# 20/20 [==============================] - 1s 36ms/step - loss: 0.6539 - accuracy: 0.6447 - precision: 0.6173 - recall: 0.0095 - mse: 0.2304 - mae: 0.4578 - auc: 0.6218 - f1_score: 0.3920 - tp: 804.0000 - fp: 443.0000 - tn: 804.0000 - fn: 443.0000 - val_loss: 0.6253 - val_accuracy: 0.6827 - val_precision: 0.6173 - val_recall: 0.0094 - val_mse: 0.2168 - val_mae: 0.4456 - val_auc: 0.7094 - val_f1_score: 0.4057 - val_tp: 213.0000 - val_fp: 99.0000 - val_tn: 213.0000 - val_fn: 99.0000
# Epoch 5/5
# 20/20 [==============================] - 1s 40ms/step - loss: 0.6535 - accuracy: 0.6447 - precision: 0.6173 - recall: 0.0094 - mse: 0.2303 - mae: 0.4575 - auc: 0.6226 - f1_score: 0.3920 - tp: 804.0000 - fp: 443.0000 - tn: 804.0000 - fn: 443.0000 - val_loss: 0.6251 - val_accuracy: 0.6827 - val_precision: 0.6173 - val_recall: 0.0093 - val_mse: 0.2167 - val_mae: 0.4454 - val_auc: 0.7099 - val_f1_score: 0.4057 - val_tp: 213.0000 - val_fp: 99.0000 - val_tn: 213.0000 - val_fn: 99.0000
#
# 13/13 [==============================] - 0s 9ms/step - loss: 0.5990 - accuracy: 0.7385 - precision: 0.6173 - recall: 0.0092 - mse: 0.2040 - mae: 0.4330 - auc: 0.7455 - f1_score: 0.4248 - tp: 288.0000 - fp: 102.0000 - tn: 288.0000 - fn: 102.0000
# accuracy: 73.85%
#
# Epoch 1/5
# 20/20 [==============================] - 1s 32ms/step - loss: 0.6477 - accuracy: 0.6640 - precision: 0.6173 - recall: 0.0092 - mse: 0.2272 - mae: 0.4522 - auc: 0.6237 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5928 - val_accuracy: 0.7276 - val_precision: 0.6173 - val_recall: 0.0091 - val_mse: 0.2013 - val_mae: 0.4255 - val_auc: 0.7562 - val_f1_score: 0.4212 - val_tp: 227.0000 - val_fp: 85.0000 - val_tn: 227.0000 - val_fn: 85.0000
# Epoch 2/5
# 20/20 [==============================] - 1s 33ms/step - loss: 0.6442 - accuracy: 0.6640 - precision: 0.6173 - recall: 0.0090 - mse: 0.2257 - mae: 0.4492 - auc: 0.6345 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5936 - val_accuracy: 0.7276 - val_precision: 0.6173 - val_recall: 0.0090 - val_mse: 0.2017 - val_mae: 0.4263 - val_auc: 0.7571 - val_f1_score: 0.4212 - val_tp: 227.0000 - val_fp: 85.0000 - val_tn: 227.0000 - val_fn: 85.0000
# Epoch 3/5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.6438 - accuracy: 0.6640 - precision: 0.6173 - recall: 0.0089 - mse: 0.2255 - mae: 0.4497 - auc: 0.6342 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5946 - val_accuracy: 0.7276 - val_precision: 0.6173 - val_recall: 0.0088 - val_mse: 0.2021 - val_mae: 0.4273 - val_auc: 0.7522 - val_f1_score: 0.4212 - val_tp: 227.0000 - val_fp: 85.0000 - val_tn: 227.0000 - val_fn: 85.0000
# Epoch 4/5
# 20/20 [==============================] - 1s 38ms/step - loss: 0.6438 - accuracy: 0.6640 - precision: 0.6173 - recall: 0.0088 - mse: 0.2255 - mae: 0.4500 - auc: 0.6360 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5950 - val_accuracy: 0.7276 - val_precision: 0.6173 - val_recall: 0.0087 - val_mse: 0.2023 - val_mae: 0.4275 - val_auc: 0.7507 - val_f1_score: 0.4212 - val_tp: 227.0000 - val_fp: 85.0000 - val_tn: 227.0000 - val_fn: 85.0000
# Epoch 5/5
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6437 - accuracy: 0.6640 - precision: 0.6173 - recall: 0.0086 - mse: 0.2255 - mae: 0.4498 - auc: 0.6355 - f1_score: 0.3990 - tp: 828.0000 - fp: 419.0000 - tn: 828.0000 - fn: 419.0000 - val_loss: 0.5952 - val_accuracy: 0.7276 - val_precision: 0.6173 - val_recall: 0.0086 - val_mse: 0.2024 - val_mae: 0.4275 - val_auc: 0.7491 - val_f1_score: 0.4212 - val_tp: 227.0000 - val_fp: 85.0000 - val_tn: 227.0000 - val_fn: 85.0000
#
# 13/13 [==============================] - 0s 11ms/step - loss: 0.6496 - accuracy: 0.6410 - precision: 0.6173 - recall: 0.0085 - mse: 0.2286 - mae: 0.4539 - auc: 0.6702 - f1_score: 0.3906 - tp: 250.0000 - fp: 140.0000 - tn: 250.0000 - fn: 140.0000
# accuracy: 64.10%
#
# Epoch 1/5
# 20/20 [==============================] - 1s 51ms/step - loss: 0.6458 - accuracy: 0.6560 - precision: 0.6173 - recall: 0.0085 - mse: 0.2266 - mae: 0.4522 - auc: 0.6455 - f1_score: 0.3961 - tp: 818.0000 - fp: 429.0000 - tn: 818.0000 - fn: 429.0000 - val_loss: 0.6024 - val_accuracy: 0.7212 - val_precision: 0.6173 - val_recall: 0.0084 - val_mse: 0.2057 - val_mae: 0.4331 - val_auc: 0.7393 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 2/5
# 20/20 [==============================] - 1s 53ms/step - loss: 0.6477 - accuracy: 0.6560 - precision: 0.6173 - recall: 0.0084 - mse: 0.2275 - mae: 0.4528 - auc: 0.6344 - f1_score: 0.3961 - tp: 818.0000 - fp: 429.0000 - tn: 818.0000 - fn: 429.0000 - val_loss: 0.6014 - val_accuracy: 0.7212 - val_precision: 0.6173 - val_recall: 0.0083 - val_mse: 0.2053 - val_mae: 0.4312 - val_auc: 0.7325 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 3/5
# 20/20 [==============================] - 1s 48ms/step - loss: 0.6472 - accuracy: 0.6560 - precision: 0.6173 - recall: 0.0082 - mse: 0.2272 - mae: 0.4513 - auc: 0.6374 - f1_score: 0.3961 - tp: 818.0000 - fp: 429.0000 - tn: 818.0000 - fn: 429.0000 - val_loss: 0.6012 - val_accuracy: 0.7212 - val_precision: 0.6173 - val_recall: 0.0082 - val_mse: 0.2052 - val_mae: 0.4303 - val_auc: 0.7268 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 4/5
# 20/20 [==============================] - 1s 47ms/step - loss: 0.6466 - accuracy: 0.6560 - precision: 0.6173 - recall: 0.0081 - mse: 0.2269 - mae: 0.4507 - auc: 0.6437 - f1_score: 0.3961 - tp: 818.0000 - fp: 429.0000 - tn: 818.0000 - fn: 429.0000 - val_loss: 0.6016 - val_accuracy: 0.7212 - val_precision: 0.6173 - val_recall: 0.0081 - val_mse: 0.2054 - val_mae: 0.4304 - val_auc: 0.7237 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
# Epoch 5/5
# 20/20 [==============================] - 1s 43ms/step - loss: 0.6464 - accuracy: 0.6560 - precision: 0.6173 - recall: 0.0080 - mse: 0.2268 - mae: 0.4505 - auc: 0.6487 - f1_score: 0.3961 - tp: 818.0000 - fp: 429.0000 - tn: 818.0000 - fn: 429.0000 - val_loss: 0.6021 - val_accuracy: 0.7212 - val_precision: 0.6173 - val_recall: 0.0079 - val_mse: 0.2056 - val_mae: 0.4305 - val_auc: 0.7242 - val_f1_score: 0.4190 - val_tp: 225.0000 - val_fp: 87.0000 - val_tn: 225.0000 - val_fn: 87.0000
#
#
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6462 - accuracy: 0.6504 - precision: 0.6173 - recall: 0.0074 - mse: 0.2268 - mae: 0.4480 - auc: 0.6623 - f1_score: 0.3941 - tp: 253.0000 - fp: 136.0000 - tn: 253.0000 - fn: 136.0000
# accuracy: 65.04%
#
# ___________________________________________________________________________________

# %%
output_df
# Out:
#        model  accuracy  precision    recall       mse       mae       auc  \
# 0  SimpleRNN  0.674704   0.480523  0.008509  0.217744  0.442004  0.700949
# 1       LSTM  0.669564   0.617284  0.014357  0.221337  0.449284  0.688168
# 2        GRU  0.669564   0.617284  0.008647  0.221549  0.446830  0.684813
#
#    f1_score  prediction time
# 0  0.431729         0.081775
# 1  0.400770         0.460007
# 2  0.400770         0.154772

# %% [markdown]
# <h3>Traditional Methodologies</h3>

# %%
stemmer = PorterStemmer()
analyzer = CountVectorizer().build_analyzer()
def stemmed_words(doc):
    stemmed_words = [stemmer.stem(w) for w in analyzer(doc)]
    non_stop_words = [word for word in stemmed_words]
    return non_stop_words

# %%
count_vectorizer = CountVectorizer(stop_words= stop_words, max_features= 1000)
feature_vector = count_vectorizer.fit(data_v1['Text'])
train_ds_features = count_vectorizer.transform(data_v1['Text'])
features = feature_vector.get_feature_names()
features_counts = np.sum(train_ds_features.toarray(), axis = 0)
features_counts = pd.DataFrame(dict(features =  features, counts = features_counts))
features_counts = features_counts.sort_values("counts", ascending= False)[0:15]
features_counts
# Out:
#      features  counts
# 333      euro    1461
# 329       eur    1374
# 675     pound    1217
# 420       gbp    1119
# 924       usd    1055
# 297    dollar     580
# 381     forex     410
# 379  forecast     384
# 187   british     374
# 684     price     364
# 711      rate     342
# 265  currency     256
# 308       ecb     242
# 337    eurusd     236
# 627   outlook     226

# %%
train_x, test_x, train_y, test_y =  train_test_split(train_ds_features, data_v1['Sentiment'], test_size = 0.3, random_state = 42)

# %%
x = train_ds_features
y = data_v1['Sentiment']

# %%
tsa_classifiers
# Out:
# [('SimpleRNN',
#   <keras.wrappers.scikit_learn.KerasClassifier at 0x7fe218eac9a0>),
#  ('LSTM', <keras.wrappers.scikit_learn.KerasClassifier at 0x7fe2428070a0>),
#  ('GRU', <keras.wrappers.scikit_learn.KerasClassifier at 0x7fe2021c3c10>)]

# %%
classifiers = {
    "BernoulliNB": BernoulliNB(),
    "ComplementNB": ComplementNB(),
    "MultinomialNB": MultinomialNB(),
    "LogisticRegression": LogisticRegression(),
    "KNeighborsClassifier": KNeighborsClassifier(),
    "DecisionTreeClassifier": DecisionTreeClassifier(),
    "RandomForestClassifier": RandomForestClassifier(),
    "MLPClassifier": MLPClassifier(max_iter=1000),
    "AdaBoostClassifier": AdaBoostClassifier()
}
estimators = []
for name, sklearn_classifier in classifiers.items():
    estimators.append((name,sklearn_classifier))

stacking_clf = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression(), cv=5)

voting_clf = VotingClassifier(
        estimators=estimators,
        voting="hard")
classifiers['VotingClassifier'] = voting_clf
classifiers['StackingClassifier'] = stacking_clf
classifiers
# Out:
# {'BernoulliNB': BernoulliNB(),
#  'ComplementNB': ComplementNB(),
#  'MultinomialNB': MultinomialNB(),
#  'LogisticRegression': LogisticRegression(),
#  'KNeighborsClassifier': KNeighborsClassifier(),
#  'DecisionTreeClassifier': DecisionTreeClassifier(),
#  'RandomForestClassifier': RandomForestClassifier(),
#  'MLPClassifier': MLPClassifier(max_iter=1000),
#  'AdaBoostClassifier': AdaBoostClassifier(),
#  'VotingClassifier': VotingClassifier(estimators=[('BernoulliNB', BernoulliNB()),
#                               ('ComplementNB', ComplementNB()),
#                               ('MultinomialNB', MultinomialNB()),
#                               ('LogisticRegression', LogisticRegression()),
#                               ('KNeighborsClassifier', KNeighborsClassifier()),
#                               ('DecisionTreeClassifier',
#                                DecisionTreeClassifier()),
#                               ('RandomForestClassifier',
#                                RandomForestClassifier()),
#                               ('MLPClassifier', MLPClassifier(max_iter=1000)),
#                               ('AdaBoostClassifier', AdaBoostClassifier())]),
#  'StackingClassifier': StackingClassifier(cv=5,
#                     estimators=[('BernoulliNB', BernoulliNB()),
#                                 ('ComplementNB', ComplementNB()),
#                                 ('MultinomialNB', MultinomialNB()),
#                                 ('LogisticRegression', LogisticRegression()),
#                                 ('KNeighborsClassifier', KNeighborsClassifier()),
#                                 ('DecisionTreeClassifier',
#                                  DecisionTreeClassifier()),
#                                 ('RandomForestClassifier',
#                                  RandomForestClassifier()),
#                                 ('MLPClassifier', MLPClassifier(max_iter=1000)),
#                                 ('AdaBoostClassifier', AdaBoostClassifier())],
#                     final_estimator=LogisticRegression())}

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import precision_score, \
    recall_score, confusion_matrix, classification_report, \
    accuracy_score, f1_score

for name, sklearn_classifier in classifiers.items():
    print("Classifier : ", name)
    accuracy = precision = recall = mse = mae = auc = f1_score_val = prediction_time = 0
    
    for train_index, test_index in kfold.split(x):
        train_x, test_x, train_y, test_y = x[train_index], x[test_index], y[train_index], y[test_index]       
    
        sklearn_classifier.fit(train_x.toarray(), train_y)
        start_time = time.time()
        test_ds_predicted = sklearn_classifier.predict(test_x.toarray())
        end_time = time.time() - start_time
        print(metrics.classification_report(test_y, test_ds_predicted))
        print("")
        print("Time taken to predict the model " + str(end_time))
        print("")
        tr_mae = mean_absolute_error(test_y, test_ds_predicted)
        tr_mse = mean_squared_error(test_y, test_ds_predicted)
        tr_accuracy = accuracy_score(test_y, test_ds_predicted)
        tr_f1_score = f1_score(test_y, test_ds_predicted, average='weighted')
        tr_recall = recall_score(test_y, test_ds_predicted, average='weighted')
        tr_precision = precision_score(test_y, test_ds_predicted, average='weighted')
        tr_auc = roc_auc_score(test_y, test_ds_predicted)

        accuracy += tr_accuracy
        precision += tr_precision
        recall += tr_recall
        mse += tr_mse
        mae += tr_mae
        auc += tr_auc
        f1_score_val += tr_f1_score
        prediction_time += end_time
    #print('MAE: %f' % mean_absolute_error(test_y, test_ds_predicted))
    #print('MSE: %f' % mean_squared_error(test_y, test_ds_predicted))
    #print('RMSE: %f' % sqrt(mean_squared_error(test_y, test_ds_predicted)))
    
    
    output_df = output_df.append([{'model': str(name), 'accuracy':accuracy/seed,'precision':precision/seed
                                       ,'recall':recall/seed,'mse':mse/seed,'mae':mae/seed
                                       ,'auc':auc/seed,'f1_score':f1_score_val/seed, 'prediction time': prediction_time/seed}], ignore_index=True)

    if name != 'VotingClassifier':
        yhat = sklearn_classifier.predict_proba(test_x.toarray())
        fpr_rf, tpr_rf, threshold2 = roc_curve(test_y.to_numpy(), yhat[:,1])
        plt.rcParams["figure.figsize"] = (10,7)
        plt.figure(1)
        plt.plot([0, 1], [0, 1], 'k--')
        plt.plot(fpr_rf, tpr_rf, label=str(name) + ' (area = {:.3f})'.format(tr_auc))
        plt.xlabel('False positive rate')
        plt.ylabel('True positive rate')
        plt.title('ROC curve')
        plt.legend(loc='best')
        plt.savefig('td_roc_curve.png')
    
    print("________________________________________________________")
    print("")
    print("")
plt.show()
# Out:
# Classifier :  BernoulliNB
#               precision    recall  f1-score   support
#
#            0       0.54      0.59      0.57       138
#            1       0.76      0.72      0.74       252
#
#     accuracy                           0.68       390
#    macro avg       0.65      0.66      0.65       390
# weighted avg       0.69      0.68      0.68       390
#
#
# Time taken to predict the model 0.002843141555786133
#
#               precision    recall  f1-score   support
#
#            0       0.46      0.49      0.48       102
#            1       0.82      0.80      0.81       288
#
#     accuracy                           0.72       390
#    macro avg       0.64      0.64      0.64       390
# weighted avg       0.72      0.72      0.72       390
#
#
# Time taken to predict the model 0.00803995132446289
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.61      0.61       140
#            1       0.78      0.78      0.78       250
#
#     accuracy                           0.72       390
#    macro avg       0.69      0.69      0.69       390
# weighted avg       0.72      0.72      0.72       390
#
#
# Time taken to predict the model 0.007385969161987305
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.60      0.57       128
#            1       0.80      0.76      0.78       262
#
#     accuracy                           0.71       390
#    macro avg       0.67      0.68      0.68       390
# weighted avg       0.72      0.71      0.71       390
#
#
# Time taken to predict the model 0.0065462589263916016
#
#               precision    recall  f1-score   support
#
#            0       0.51      0.50      0.51       136
#            1       0.73      0.74      0.74       253
#
#     accuracy                           0.66       389
#    macro avg       0.62      0.62      0.62       389
# weighted avg       0.66      0.66      0.66       389
#
#
# Time taken to predict the model 0.008111000061035156
#
# ________________________________________________________
#
#
# Classifier :  ComplementNB
#               precision    recall  f1-score   support
#
#            0       0.52      0.64      0.57       138
#            1       0.78      0.67      0.72       252
#
#     accuracy                           0.66       390
#    macro avg       0.65      0.66      0.65       390
# weighted avg       0.68      0.66      0.67       390
#
#
# Time taken to predict the model 0.000942230224609375
#
#               precision    recall  f1-score   support
#
#            0       0.46      0.61      0.52       102
#            1       0.84      0.75      0.79       288
#
#     accuracy                           0.71       390
#    macro avg       0.65      0.68      0.66       390
# weighted avg       0.74      0.71      0.72       390
#
#
# Time taken to predict the model 0.0036628246307373047
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.69      0.64       140
#            1       0.81      0.74      0.77       250
#
#     accuracy                           0.72       390
#    macro avg       0.71      0.72      0.71       390
# weighted avg       0.74      0.72      0.73       390
#
#
# Time taken to predict the model 0.0009508132934570312
#
#               precision    recall  f1-score   support
#
#            0       0.52      0.64      0.57       128
#            1       0.80      0.71      0.75       262
#
#     accuracy                           0.68       390
#    macro avg       0.66      0.67      0.66       390
# weighted avg       0.71      0.68      0.69       390
#
#
# Time taken to predict the model 0.0009398460388183594
#
#               precision    recall  f1-score   support
#
#            0       0.48      0.55      0.52       136
#            1       0.74      0.68      0.71       253
#
#     accuracy                           0.64       389
#    macro avg       0.61      0.62      0.61       389
# weighted avg       0.65      0.64      0.64       389
#
#
# Time taken to predict the model 0.003606081008911133
#
# ________________________________________________________
#
#
# Classifier :  MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.54      0.57      0.56       138
#            1       0.76      0.74      0.75       252
#
#     accuracy                           0.68       390
#    macro avg       0.65      0.66      0.65       390
# weighted avg       0.68      0.68      0.68       390
#
#
# Time taken to predict the model 0.003795146942138672
#
#               precision    recall  f1-score   support
#
#            0       0.47      0.49      0.48       102
#            1       0.82      0.81      0.81       288
#
#     accuracy                           0.72       390
#    macro avg       0.64      0.65      0.65       390
# weighted avg       0.73      0.72      0.72       390
#
#
# Time taken to predict the model 0.0011050701141357422
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.63      0.63       140
#            1       0.79      0.79      0.79       250
#
#     accuracy                           0.73       390
#    macro avg       0.71      0.71      0.71       390
# weighted avg       0.73      0.73      0.73       390
#
#
# Time taken to predict the model 0.004027128219604492
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.57      0.56       128
#            1       0.79      0.77      0.78       262
#
#     accuracy                           0.70       390
#    macro avg       0.66      0.67      0.67       390
# weighted avg       0.71      0.70      0.70       390
#
#
# Time taken to predict the model 0.003915071487426758
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.51      0.53       136
#            1       0.75      0.77      0.76       253
#
#     accuracy                           0.68       389
#    macro avg       0.65      0.64      0.64       389
# weighted avg       0.68      0.68      0.68       389
#
#
# Time taken to predict the model 0.0035698413848876953
#
# ________________________________________________________
#
#
# Classifier :  LogisticRegression
#               precision    recall  f1-score   support
#
#            0       0.61      0.49      0.54       138
#            1       0.75      0.83      0.78       252
#
#     accuracy                           0.71       390
#    macro avg       0.68      0.66      0.66       390
# weighted avg       0.70      0.71      0.70       390
#
#
# Time taken to predict the model 0.0022656917572021484
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.48      0.52       102
#            1       0.83      0.87      0.85       288
#
#     accuracy                           0.77       390
#    macro avg       0.70      0.68      0.68       390
# weighted avg       0.76      0.77      0.76       390
#
#
# Time taken to predict the model 0.0006170272827148438
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.51      0.57       140
#            1       0.75      0.85      0.80       250
#
#     accuracy                           0.73       390
#    macro avg       0.70      0.68      0.68       390
# weighted avg       0.72      0.73      0.72       390
#
#
# Time taken to predict the model 0.0030689239501953125
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.41      0.47       128
#            1       0.74      0.85      0.79       262
#
#     accuracy                           0.70       390
#    macro avg       0.66      0.63      0.63       390
# weighted avg       0.69      0.70      0.69       390
#
#
# Time taken to predict the model 0.0005891323089599609
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.43      0.49       136
#            1       0.73      0.83      0.78       253
#
#     accuracy                           0.69       389
#    macro avg       0.65      0.63      0.63       389
# weighted avg       0.68      0.69      0.68       389
#
#
# Time taken to predict the model 0.0038509368896484375
#
# ________________________________________________________
#
#
# Classifier :  KNeighborsClassifier
#               precision    recall  f1-score   support
#
#            0       0.55      0.53      0.54       138
#            1       0.75      0.77      0.76       252
#
#     accuracy                           0.68       390
#    macro avg       0.65      0.65      0.65       390
# weighted avg       0.68      0.68      0.68       390
#
#
# Time taken to predict the model 0.027379989624023438
#
#               precision    recall  f1-score   support
#
#            0       0.41      0.49      0.45       102
#            1       0.81      0.75      0.78       288
#
#     accuracy                           0.68       390
#    macro avg       0.61      0.62      0.61       390
# weighted avg       0.70      0.68      0.69       390
#
#
# Time taken to predict the model 0.02516031265258789
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.52      0.58       140
#            1       0.76      0.84      0.80       250
#
#     accuracy                           0.73       390
#    macro avg       0.70      0.68      0.69       390
# weighted avg       0.72      0.73      0.72       390
#
#
# Time taken to predict the model 0.027849912643432617
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.38      0.46       128
#            1       0.74      0.86      0.80       262
#
#     accuracy                           0.70       390
#    macro avg       0.65      0.62      0.63       390
# weighted avg       0.68      0.70      0.68       390
#
#
# Time taken to predict the model 0.02695918083190918
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.54      0.54       136
#            1       0.75      0.77      0.76       253
#
#     accuracy                           0.69       389
#    macro avg       0.65      0.65      0.65       389
# weighted avg       0.68      0.69      0.69       389
#
#
# Time taken to predict the model 0.028721094131469727
# ________________________________________________________
#
#
# Classifier :  DecisionTreeClassifier
#               precision    recall  f1-score   support
#
#            0       0.58      0.55      0.57       138
#            1       0.76      0.79      0.77       252
#
#     accuracy                           0.70       390
#    macro avg       0.67      0.67      0.67       390
# weighted avg       0.70      0.70      0.70       390
#
#
# Time taken to predict the model 0.0034058094024658203
#
#               precision    recall  f1-score   support
#
#            0       0.41      0.45      0.43       102
#            1       0.80      0.77      0.79       288
#
#     accuracy                           0.69       390
#    macro avg       0.61      0.61      0.61       390
# weighted avg       0.70      0.69      0.69       390
#
#
# Time taken to predict the model 0.001413106918334961
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.62      0.61       140
#            1       0.78      0.77      0.78       250
#
#     accuracy                           0.72       390
#    macro avg       0.69      0.70      0.70       390
# weighted avg       0.72      0.72      0.72       390
#
#
# Time taken to predict the model 0.003545045852661133
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.54      0.55       128
#            1       0.78      0.80      0.79       262
#
#     accuracy                           0.71       390
#    macro avg       0.67      0.67      0.67       390
# weighted avg       0.71      0.71      0.71       390
#
#
# Time taken to predict the model 0.0012710094451904297
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.51      0.55       136
#            1       0.75      0.81      0.78       253
#
#     accuracy                           0.70       389
#    macro avg       0.67      0.66      0.66       389
# weighted avg       0.70      0.70      0.70       389
#
#
# Time taken to predict the model 0.0038080215454101562
#
# ________________________________________________________
#
#
# Classifier :  RandomForestClassifier
#               precision    recall  f1-score   support
#
#            0       0.65      0.46      0.54       138
#            1       0.75      0.87      0.80       252
#
#     accuracy                           0.72       390
#    macro avg       0.70      0.66      0.67       390
# weighted avg       0.71      0.72      0.71       390
#
#
# Time taken to predict the model 0.015412092208862305
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.38      0.45       102
#            1       0.80      0.89      0.84       288
#
#     accuracy                           0.75       390
#    macro avg       0.67      0.63      0.64       390
# weighted avg       0.73      0.75      0.74       390
#
#
# Time taken to predict the model 0.016067028045654297
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.54      0.61       140
#            1       0.77      0.88      0.82       250
#
#     accuracy                           0.76       390
#    macro avg       0.74      0.71      0.72       390
# weighted avg       0.75      0.76      0.75       390
#
#
# Time taken to predict the model 0.016601085662841797
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.41      0.51       128
#            1       0.76      0.90      0.83       262
#
#     accuracy                           0.74       390
#    macro avg       0.72      0.66      0.67       390
# weighted avg       0.73      0.74      0.72       390
#
#
# Time taken to predict the model 0.015517950057983398
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.46      0.56       136
#            1       0.76      0.90      0.82       253
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.68      0.69       389
# weighted avg       0.74      0.75      0.73       389
#
#
# Time taken to predict the model 0.01679682731628418
#
# ________________________________________________________
#
#
# Classifier :  MLPClassifier
#               precision    recall  f1-score   support
#
#            0       0.57      0.50      0.53       138
#            1       0.74      0.79      0.77       252
#
#     accuracy                           0.69       390
#    macro avg       0.65      0.64      0.65       390
# weighted avg       0.68      0.69      0.68       390
#
#
# Time taken to predict the model 0.0016398429870605469
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.49      0.51       102
#            1       0.82      0.84      0.83       288
#
#     accuracy                           0.75       390
#    macro avg       0.68      0.67      0.67       390
# weighted avg       0.75      0.75      0.75       390
#
#
# Time taken to predict the model 0.0020668506622314453
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.57      0.58       140
#            1       0.76      0.78      0.77       250
#
#     accuracy                           0.71       390
#    macro avg       0.68      0.68      0.68       390
# weighted avg       0.70      0.71      0.70       390
#
#
# Time taken to predict the model 0.002798795700073242
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.55      0.56       128
#            1       0.79      0.80      0.79       262
#
#     accuracy                           0.72       390
#    macro avg       0.68      0.68      0.68       390
# weighted avg       0.72      0.72      0.72       390
#
#
# Time taken to predict the model 0.0041277408599853516
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.51      0.53       136
#            1       0.75      0.77      0.76       253
#
#     accuracy                           0.68       389
#    macro avg       0.65      0.64      0.64       389
# weighted avg       0.68      0.68      0.68       389
#
#
# Time taken to predict the model 0.0016782283782958984
#
# ________________________________________________________
#
#
# Classifier :  AdaBoostClassifier
#               precision    recall  f1-score   support
#
#            0       0.77      0.36      0.49       138
#            1       0.73      0.94      0.82       252
#
#     accuracy                           0.74       390
#    macro avg       0.75      0.65      0.66       390
# weighted avg       0.74      0.74      0.71       390
#
#
# Time taken to predict the model 0.03767800331115723
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.30      0.39       102
#            1       0.79      0.91      0.85       288
#
#     accuracy                           0.75       390
#    macro avg       0.67      0.61      0.62       390
# weighted avg       0.73      0.75      0.73       390
#
#
# Time taken to predict the model 0.029613733291625977
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.34      0.45       140
#            1       0.71      0.90      0.79       250
#
#     accuracy                           0.70       390
#    macro avg       0.68      0.62      0.62       390
# weighted avg       0.69      0.70      0.67       390
#
#
# Time taken to predict the model 0.02721405029296875
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.26      0.37       128
#            1       0.72      0.94      0.81       262
#
#     accuracy                           0.71       390
#    macro avg       0.69      0.60      0.59       390
# weighted avg       0.70      0.71      0.67       390
#
#
# Time taken to predict the model 0.02516913414001465
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.30      0.41       136
#            1       0.71      0.91      0.80       253
#
#     accuracy                           0.70       389
#    macro avg       0.68      0.61      0.60       389
# weighted avg       0.69      0.70      0.66       389
#
#
# Time taken to predict the model 0.02884197235107422
#
# ________________________________________________________
#
#
# Classifier :  VotingClassifier
#               precision    recall  f1-score   support
#
#            0       0.61      0.52      0.56       138
#            1       0.76      0.81      0.78       252
#
#     accuracy                           0.71       390
#    macro avg       0.68      0.67      0.67       390
# weighted avg       0.70      0.71      0.70       390
#
#
# Time taken to predict the model 0.08417391777038574
#               precision    recall  f1-score   support
#
#            0       0.55      0.41      0.47       102
#            1       0.81      0.88      0.84       288
#
#     accuracy                           0.76       390
#    macro avg       0.68      0.65      0.66       390
# weighted avg       0.74      0.76      0.74       390
#
#
# Time taken to predict the model 0.08391284942626953
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.63       140
#            1       0.78      0.86      0.82       250
#
#     accuracy                           0.76       390
#    macro avg       0.74      0.72      0.73       390
# weighted avg       0.75      0.76      0.75       390
#
#
# Time taken to predict the model 0.0885469913482666
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.50      0.55       128
#            1       0.78      0.85      0.81       262
#
#     accuracy                           0.74       390
#    macro avg       0.70      0.68      0.68       390
# weighted avg       0.73      0.74      0.73       390
#
#
# Time taken to predict the model 0.08807492256164551
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.46      0.53       136
#            1       0.74      0.84      0.79       253
#
#     accuracy                           0.71       389
#    macro avg       0.68      0.65      0.66       389
# weighted avg       0.70      0.71      0.70       389
#
#
# Time taken to predict the model 0.10882902145385742
#
# ________________________________________________________
#
#
# Classifier :  StackingClassifier
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       138
#            1       0.65      1.00      0.79       252
#
#     accuracy                           0.65       390
#    macro avg       0.32      0.50      0.39       390
# weighted avg       0.42      0.65      0.51       390
#
#
# Time taken to predict the model 0.0780799388885498
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.13      0.21       102
#            1       0.76      0.98      0.86       288
#
#     accuracy                           0.76       390
#    macro avg       0.72      0.55      0.54       390
# weighted avg       0.74      0.76      0.69       390
#
#
# Time taken to predict the model 0.06146097183227539
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       140
#            1       0.64      1.00      0.78       250
#
#     accuracy                           0.64       390
#    macro avg       0.32      0.50      0.39       390
# weighted avg       0.41      0.64      0.50       390
#
#
# Time taken to predict the model 0.07119107246398926
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.23      0.36       128
#            1       0.72      0.98      0.83       262
#
#     accuracy                           0.73       390
#    macro avg       0.77      0.60      0.59       390
# weighted avg       0.76      0.73      0.67       390
#
#
# Time taken to predict the model 0.0762178897857666
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.11      0.20       136
#            1       0.68      1.00      0.81       253
#
#     accuracy                           0.69       389
#    macro avg       0.81      0.55      0.50       389
# weighted avg       0.77      0.69      0.59       389
#
#
# Time taken to predict the model 0.07494401931762695
#
# ________________________________________________________

# %%
output_df
# Out:
#                      model  accuracy  precision    recall       mse       mae  \
# 0                SimpleRNN  0.674704   0.480523  0.008509  0.217744  0.442004
# 1                     LSTM  0.669564   0.617284  0.014357  0.221337  0.449284
# 2                      GRU  0.669564   0.617284  0.008647  0.221549  0.446830
# 3              BernoulliNB  0.695722   0.699594  0.695722  0.304278  0.304278
# 4             ComplementNB  0.683404   0.703822  0.683404  0.316596  0.316596
# 5            MultinomialNB  0.703426   0.704713  0.703426  0.296574  0.296574
# 6       LogisticRegression  0.718815   0.707197  0.718815  0.281185  0.281185
# 7     KNeighborsClassifier  0.695737   0.693563  0.695737  0.304263  0.304263
# 8   DecisionTreeClassifier  0.705489   0.704649  0.705489  0.294511  0.294511
# 9   RandomForestClassifier  0.744485   0.734295  0.744485  0.255515  0.255515
# 10           MLPClassifier  0.708554   0.704140  0.708554  0.291446  0.291446
# 11      AdaBoostClassifier  0.720359   0.709952  0.720359  0.279641  0.279641
# 12        VotingClassifier  0.734210   0.724048  0.734210  0.265790  0.265790
# 13      StackingClassifier  0.692147   0.618449  0.692147  0.307853  0.307853
#
#          auc  f1_score  prediction time
# 0   0.700949  0.431729         0.081775
# 1   0.688168  0.400770         0.460007
# 2   0.684813  0.400770         0.154772
# 3   0.659656  0.697312         0.006585
# 4   0.668479  0.690060         0.002020
# 5   0.664243  0.703886         0.003282
# 6   0.653870  0.708709         0.002078
# 7   0.644164  0.691724         0.027214
# 8   0.660956  0.704540         0.002689
# 9   0.669144  0.729773         0.016079
# 10  0.660951  0.705930         0.002462
# 11  0.617021  0.686860         0.029703
# 12  0.672032  0.725688         0.090708
# 13  0.541662  0.592632         0.072379

# %%
output_df.to_csv('classifiers_output_result.csv', sep='\t')
