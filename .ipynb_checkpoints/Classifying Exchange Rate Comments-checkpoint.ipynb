# %%
import re
from TextCleaner import TextCleaner
import pandas as pd
import numpy as np
import time
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sn
import keras_metrics as km
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
from sklearn.metrics import confusion_matrix
from numpy import sqrt 
# %matplotlib inline
import nltk
from langdetect import detect
import contractions
from nltk.corpus import stopwords
from textblob import Word
from sklearn.preprocessing import LabelEncoder
from collections import Counter
from wordcloud import WordCloud
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem.snowball import PorterStemmer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, GRU, SimpleRNN, SpatialDropout1D
from tensorflow.keras.layers import SpatialDropout1D
from tensorflow.keras.layers import Embedding
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.python.keras.metrics import Metric
import tensorflow as tf    
import tensorflow_addons as tfa
from tensorflow import keras 
from keras.metrics import Precision, Recall

# Classifiers
from sklearn.naive_bayes import BernoulliNB
from sklearn import metrics
from sklearn.naive_bayes import (
    BernoulliNB,
    ComplementNB,
    MultinomialNB,
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import StackingClassifier

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
pd.options.mode.chained_assignment = None  # default='warn'

# %%
df = pd.read_csv('sentiment.csv')
df = df.drop(df.columns[0], axis=1)
df
# Out:
#                Author                                               Text  \
# 0            yusobays  @elonmusk @elonmusk  please Come to TRY₺ #turk...
# 1       BtcTurkDestek  @DrBatal  Hello, if you have registered using ...
# 2      RisingValhalla  “I trade weekly bars. You?”\n\n200 day moving ...
# 3        Erda55203615  @elonmusk Try turkish lira its at the bottom m...
# 4        Erda55203615            @ImTooRealForU TRY FUCKING TURKISH LIRA
# ...               ...                                                ...
# 1944  flyingstocksman  For those of you who missed it last night with...
# 1945         alpeshbp  GBP/USD Weekly Price Forecast – The British Po...
# 1946     campsbay_com  20.0142 ZAR for 1 GBP @ December 31, 2020 at 0...
# 1947       MajorFXNow  GBP/EUR: Pound Lifted by UK Approval of AstraZ...
# 1948     trader_blitz  GBP/JPY | $GBPJPY | $GBP $JPY\n\nBRITISH POUND...
#
#                            Time  Like Count Currency ISO Code  \
# 0     2021-01-31 22:21:58+00:00           1               TRY
# 1     2021-01-30 18:07:15+00:00           0               TRY
# 2     2021-01-30 03:29:59+00:00           0               TRY
# 3     2021-01-29 20:20:49+00:00           0               TRY
# 4     2021-01-29 20:19:36+00:00           0               TRY
# ...                         ...         ...               ...
# 1944  2021-01-01 09:24:17+00:00           0               GBP
# 1945  2021-01-01 07:13:32+00:00           0               GBP
# 1946  2021-01-01 04:20:02+00:00           0               GBP
# 1947  2021-01-01 02:32:32+00:00           0               GBP
# 1948  2021-01-01 00:42:01+00:00           0               GBP
#
#                                                     Url  target
# 0     https://twitter.com/yusobays/status/1356004827...     0.0
# 1     https://twitter.com/BtcTurkDestek/status/13555...     0.0
# 2     https://twitter.com/RisingValhalla/status/1355...     0.0
# 3     https://twitter.com/Erda55203615/status/135524...    -1.0
# 4     https://twitter.com/Erda55203615/status/135524...    -1.0
# ...                                                 ...     ...
# 1944  https://twitter.com/flyingstocksman/status/134...     0.0
# 1945  https://twitter.com/alpeshbp/status/1344904575...     0.0
# 1946  https://twitter.com/campsbay_com/status/134486...     0.0
# 1947  https://twitter.com/MajorFXNow/status/13448338...     0.0
# 1948  https://twitter.com/trader_blitz/status/134480...     0.0
#
# [1949 rows x 7 columns]

# %%
def sentiments(df):
    if df['target'] >= 0:
        return 'Positive'
    elif df['target'] < 0:
        return 'Negative'

# %%
df['Sentiment'] = df.apply(sentiments, axis=1)

# %%
df
# Out:
#                Author                                               Text  \
# 0            yusobays  @elonmusk @elonmusk  please Come to TRY₺ #turk...
# 1       BtcTurkDestek  @DrBatal  Hello, if you have registered using ...
# 2      RisingValhalla  “I trade weekly bars. You?”\n\n200 day moving ...
# 3        Erda55203615  @elonmusk Try turkish lira its at the bottom m...
# 4        Erda55203615            @ImTooRealForU TRY FUCKING TURKISH LIRA
# ...               ...                                                ...
# 1944  flyingstocksman  For those of you who missed it last night with...
# 1945         alpeshbp  GBP/USD Weekly Price Forecast – The British Po...
# 1946     campsbay_com  20.0142 ZAR for 1 GBP @ December 31, 2020 at 0...
# 1947       MajorFXNow  GBP/EUR: Pound Lifted by UK Approval of AstraZ...
# 1948     trader_blitz  GBP/JPY | $GBPJPY | $GBP $JPY\n\nBRITISH POUND...
#
#                            Time  Like Count Currency ISO Code  \
# 0     2021-01-31 22:21:58+00:00           1               TRY
# 1     2021-01-30 18:07:15+00:00           0               TRY
# 2     2021-01-30 03:29:59+00:00           0               TRY
# 3     2021-01-29 20:20:49+00:00           0               TRY
# 4     2021-01-29 20:19:36+00:00           0               TRY
# ...                         ...         ...               ...
# 1944  2021-01-01 09:24:17+00:00           0               GBP
# 1945  2021-01-01 07:13:32+00:00           0               GBP
# 1946  2021-01-01 04:20:02+00:00           0               GBP
# 1947  2021-01-01 02:32:32+00:00           0               GBP
# 1948  2021-01-01 00:42:01+00:00           0               GBP
#
#                                                     Url  target Sentiment
# 0     https://twitter.com/yusobays/status/1356004827...     0.0  Positive
# 1     https://twitter.com/BtcTurkDestek/status/13555...     0.0  Positive
# 2     https://twitter.com/RisingValhalla/status/1355...     0.0  Positive
# 3     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# 4     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# ...                                                 ...     ...       ...
# 1944  https://twitter.com/flyingstocksman/status/134...     0.0  Positive
# 1945  https://twitter.com/alpeshbp/status/1344904575...     0.0  Positive
# 1946  https://twitter.com/campsbay_com/status/134486...     0.0  Positive
# 1947  https://twitter.com/MajorFXNow/status/13448338...     0.0  Positive
# 1948  https://twitter.com/trader_blitz/status/134480...     0.0  Positive
#
# [1949 rows x 8 columns]

# %%
data_v1 = df[['Text','Sentiment']]
data_v1.isnull().sum()
# Out:
# Text         0
# Sentiment    0
# dtype: int64

# %%
plt.figure(figsize=(7,8))
plt.title("Number of records of positive and negative sentiments")
plot = sn.countplot(x = 'Sentiment', data = data_v1)
for p in plot.patches:
    plot.annotate(p.get_height(),(p.get_x() + 0.2 ,p.get_height()+80))

# %%
clean = TextCleaner()
text = clean.convert_emoji_to_text("Hilarious 😂. The feeling of making a sale 😎, The feeling of actually fulfilling orders 😒")
print(text)

text4 = "Hello :-) :-)"
resp = clean.convert_emoticons(text4)
print(resp)
# Out:
# Hilarious face with tears of joy. The feeling of making a sale smiling face with sunglasses, The feeling of actually fulfilling orders unamused face
# Hello Happy face smiley Happy face smiley

# %%
df
# Out:
#                Author                                               Text  \
# 0            yusobays  @elonmusk @elonmusk  please Come to TRY₺ #turk...
# 1       BtcTurkDestek  @DrBatal  Hello, if you have registered using ...
# 2      RisingValhalla  “I trade weekly bars. You?”\n\n200 day moving ...
# 3        Erda55203615  @elonmusk Try turkish lira its at the bottom m...
# 4        Erda55203615            @ImTooRealForU TRY FUCKING TURKISH LIRA
# ...               ...                                                ...
# 1944  flyingstocksman  For those of you who missed it last night with...
# 1945         alpeshbp  GBP/USD Weekly Price Forecast – The British Po...
# 1946     campsbay_com  20.0142 ZAR for 1 GBP @ December 31, 2020 at 0...
# 1947       MajorFXNow  GBP/EUR: Pound Lifted by UK Approval of AstraZ...
# 1948     trader_blitz  GBP/JPY | $GBPJPY | $GBP $JPY\n\nBRITISH POUND...
#
#                            Time  Like Count Currency ISO Code  \
# 0     2021-01-31 22:21:58+00:00           1               TRY
# 1     2021-01-30 18:07:15+00:00           0               TRY
# 2     2021-01-30 03:29:59+00:00           0               TRY
# 3     2021-01-29 20:20:49+00:00           0               TRY
# 4     2021-01-29 20:19:36+00:00           0               TRY
# ...                         ...         ...               ...
# 1944  2021-01-01 09:24:17+00:00           0               GBP
# 1945  2021-01-01 07:13:32+00:00           0               GBP
# 1946  2021-01-01 04:20:02+00:00           0               GBP
# 1947  2021-01-01 02:32:32+00:00           0               GBP
# 1948  2021-01-01 00:42:01+00:00           0               GBP
#
#                                                     Url  target Sentiment
# 0     https://twitter.com/yusobays/status/1356004827...     0.0  Positive
# 1     https://twitter.com/BtcTurkDestek/status/13555...     0.0  Positive
# 2     https://twitter.com/RisingValhalla/status/1355...     0.0  Positive
# 3     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# 4     https://twitter.com/Erda55203615/status/135524...    -1.0  Negative
# ...                                                 ...     ...       ...
# 1944  https://twitter.com/flyingstocksman/status/134...     0.0  Positive
# 1945  https://twitter.com/alpeshbp/status/1344904575...     0.0  Positive
# 1946  https://twitter.com/campsbay_com/status/134486...     0.0  Positive
# 1947  https://twitter.com/MajorFXNow/status/13448338...     0.0  Positive
# 1948  https://twitter.com/trader_blitz/status/134480...     0.0  Positive
#
# [1949 rows x 8 columns]

# %%
def remove_url(text):
    result = re.sub(r'https?:\/\/\S*', '', text, flags=re.MULTILINE)
    return result

def replace_contractions(text):
    return contractions.fix(text)

abbs =  {"eur": "euro", "usd": "dollar", "gbp" : "pound", "u":"you", "tryeur":"turkish lira euro", "try":" turkish lira", "gt":"greater than","lt": "less than","btc":"bitcoin",
        "gbpusd": "pound dollar", "usdtry":"dollar turkish lira", "fx":"forex", "u":"you", "eurusd":"euro usd", "eurgbp":"euro pound", "jpy":"japanese yen","cny":"chinese yuan","uk":"united kingdom"}

def replace_currency(text):
    val = ''
    for i in text.split():
        if abbs.get(i.lower().strip()) is not None:
            #print(abbs.get(i.lower().strip()))
            val = val + str(abbs.get(i.lower().strip())) + ' '
        else:
            val = val + i + ' '
    return val

# %%
print(remove_url(df['Text'].iloc[1942]))
# Out:
# Visit  to check the latest #bitcoin price in #gbp #uk #pound. You can also use our free $GBP to $BTC price converter.

# %%
print(replace_currency("@elonmusk Try turkish lira its at the bottom"))
# Out:
# @elonmusk  turkish lira turkish lira its at the bottom

# %%
clean = TextCleaner()

def cleaning(df_cl, stop_words):
    
    # Removing URLs
    df_cl["Text"] = df_cl["Text"].apply(lambda x: remove_url(x))
    
     # Removing mentioned author names
    df_cl["Text"] = df_cl["Text"].apply(lambda x: re.sub("@[A-Za-z0-9]+","", x))
    
    # Lowercase
    df_cl['Text'] = df_cl['Text'].apply(lambda x: ' '.join(x.lower() for x in x.split()))
    
    df_cl["Text"] = df_cl["Text"].apply(lambda x: replace_contractions(x))
    
    df_cl["Text"] = df_cl["Text"].apply(lambda x: replace_currency(x))
    
     # Remove Non -letters
    df_cl['Text'] = df_cl['Text'].apply(lambda x: re.sub(r"[^a-zA-Z0-9]", ' ', x))
    
    # Removing Punctuation
    df_cl["Text"] = df_cl["Text"].apply(lambda x: re.sub(r'[^\w\s]','', x))
    
    # Removing stop words
    df_cl['Text'] = df_cl['Text'].apply(lambda x:' '.join(x for x in x.split() if x not in stop_words))
    
    # Lemmatization
    df_cl['Text'] = df_cl['Text'].apply(lambda x:' '.join([Word(x).lemmatize() for x in x.split()]))
    
    # Emoticons
    df_cl['Text'] = df_cl['Text'].apply(lambda x: clean.convert_emoji_to_text(x))
    
    # Emojis
    df_cl['Text'] = df_cl['Text'].apply(lambda x: clean.convert_emoji_to_text(x))    
    
    # Stemming
    #df_cl['Text'] = df_cl['Text'].apply(lambda x: port_stemmer(x))
    return df_cl

stop_words = stopwords.words('english')

# %%
data_v1 = cleaning(data_v1, stop_words)

# %%
data_v1
# Out:
#                                                    Text Sentiment
# 0                           please come try turkishlira  Positive
# 1     hello registered using turkish citizenship id ...  Positive
# 2     trade weekly bar 200 day moving average breach...  Positive
# 3       turkish lira turkish lira bottom maybe would go  Negative
# 4                     turkish lira fucking turkish lira  Negative
# ...                                                 ...       ...
# 1944  missed last night nye potentially important tw...  Positive
# 1945  gbp usd weekly price forecast british pound lo...  Positive
# 1946  20 0142 zar 1 pound december 31 2020 06 20am s...  Positive
# 1947  gbp eur pound lifted united kingdom approval a...  Positive
# 1948  gbp jpy gbpjpy gbp jpy british pound brexit br...  Positive
#
# [1949 rows x 2 columns]

# %%
common_words = ''
for i in data_v1.Text:
    i = str(i)
    tokens = i.split()
    common_words += " ".join(tokens)+" "
wordcloud = WordCloud(width=1600, height=800).generate(common_words)
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
lb = LabelEncoder()
data_v1['Sentiment'] = lb.fit_transform(data_v1['Sentiment'])

# %%
tokenizer = Tokenizer(num_words=1000, split=' ', lower=True) 
tokenizer.fit_on_texts(data_v1['Text'].values)
X = tokenizer.texts_to_sequences(df['Text'].values)
X = pad_sequences(X)

# %%
y = pd.get_dummies(data_v1['Sentiment'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

# %% [markdown]
# <h3>Time Series Methodologies</h3>
# <h4>Defining Models</h4>

# %%
models = [ 'SimpleRNN', 'LSTM', 'GRU']

# %%
METRICS = [ 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      km.binary_precision(), 
      km.binary_recall(),
      'mse', 
      'mae', 
      keras.metrics.AUC(name='auc'),
      tfa.metrics.F1Score(num_classes=2, threshold=0.5, average='macro')
      #keras.metrics.TruePositives(name='tp'),
      #keras.metrics.FalsePositives(name='fp'),
      #keras.metrics.TrueNegatives(name='tn'),
      #keras.metrics.FalseNegatives(name='fn'),
]
# Out:
# 2022-03-20 19:42:08.971308: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def build_model(nb_words, _model="SimpleRNN", embedding_matrix=None):
    model = Sequential()
    model.add(Embedding(input_dim=1000, output_dim=64, input_length = nb_words))
    if _model == "SimpleRNN":
        model.add(SimpleRNN(128, dropout=0.1, recurrent_dropout=0.1, activation='relu'))
    elif _model == "LSTM":
        model.add(LSTM(100, return_sequences=True))
        model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.1, activation='relu'))
    elif _model == "GRU":
        model.add(GRU(128))
    model.add(Dense(2, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=[METRICS])
    return model

# %%
print(X.shape)
print(y.shape)
# Out:
# (1949, 38)
# (1949, 2)

# %%
tsa_classifiers = []
output_df = pd.DataFrame(columns=['model', 'accuracy', 'precision', 'recall', 'mse', 'mae', 'auc', 'f1_score', 'prediction time'])

batch_size = 64
for idx, mdl in enumerate(models):
    print("Model : " + str(mdl))
    model_ = build_model(X.shape[1], mdl, None)
    
    keras_model = KerasClassifier(build_fn=model_)
    keras_model._estimator_type = "classifier"    
    tsa_classifiers.append(( str(mdl), keras_model  ))
    
    print("Model Summary")
    print(model_.summary())
    model_.fit(X_train, y_train, epochs=5, validation_split=0.2, batch_size=batch_size, verbose = 'auto', shuffle=False, validation_data=(X_test,y_test))
    
    start_time = time.time()
    y_pred = model_.predict(X_test)
    end_time = time.time() - start_time
    print("")
    
    scores = model_.evaluate(X_test, y_test)
    print("%s: %.2f%%" % (model_.metrics_names[1], scores[1]*100))    
    print("")

    output_df = output_df.append([{'model': str(mdl), 'accuracy':scores[1],'precision':scores[2]
                                   ,'recall':scores[3],'mse':scores[4],'mae':scores[5]
                                   ,'auc':scores[6],'f1_score':scores[7], 'prediction time': end_time}], ignore_index=True)
    
    yhat = model_.predict_on_batch(X_test)
    fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test.values.argmax(axis=1), yhat[:,1])
    
    print("")
    print("Time taken to predict the model " + str(end_time))
    
    plt.rcParams["figure.figsize"] = (10,7)
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr_rf, tpr_rf, label=str(mdl) + ' (area = {:.3f})'.format(scores[6]))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.savefig('tsa_roc_curve.png')
    
    #print(classification_report(y_test.values.argmax(axis=1), y_pred.argmax(axis=1)))
    print("___________________________________________________________________________________")
    
    print("")
    print("")
    print("")
    
plt.show()
# Out:
# Model : SimpleRNN
# Model Summary
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 38, 64)            64000
#
#  simple_rnn (SimpleRNN)      (None, 128)               24704
#
#  dense (Dense)               (None, 2)                 258
#
# =================================================================
# Total params: 88,962
# Trainable params: 88,962
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# /var/folders/33/v0__8kvs301dg744qmtfs33w0000gn/T/ipykernel_13926/1534225968.py:9: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_model = KerasClassifier(build_fn=model_)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /opt/anaconda3/lib/python3.9/site-packages/keras_metrics/metrics.py:26: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return object.__getattribute__(self, name)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 20/20 [==============================] - ETA: 0s - loss: 0.6582 - accuracy: 0.6367 - precision: 0.2989 - recall: 0.2238 - mse: 0.2295 - mae: 0.4566 - auc: 0.6863 - f1_score: 0.4473WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /opt/anaconda3/lib/python3.9/site-packages/keras_metrics/metrics.py:26: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return object.__getattribute__(self, name)
# 20/20 [==============================] - 2s 35ms/step - loss: 0.6582 - accuracy: 0.6367 - precision: 0.2989 - recall: 0.2238 - mse: 0.2295 - mae: 0.4566 - auc: 0.6863 - f1_score: 0.4473 - val_loss: 0.6486 - val_accuracy: 0.6603 - val_precision: 0.2991 - val_recall: 0.0679 - val_mse: 0.2280 - val_mae: 0.4712 - val_auc: 0.7007 - val_f1_score: 0.3977
# Epoch 2/5
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6205 - accuracy: 0.6712 - precision: 0.2991 - recall: 0.0443 - mse: 0.2146 - mae: 0.4530 - auc: 0.7807 - f1_score: 0.4016 - val_loss: 0.6251 - val_accuracy: 0.6603 - val_precision: 0.2991 - val_recall: 0.0324 - val_mse: 0.2172 - val_mae: 0.4427 - val_auc: 0.7206 - val_f1_score: 0.3977
# Epoch 3/5
# 20/20 [==============================] - 0s 13ms/step - loss: 0.5705 - accuracy: 0.6712 - precision: 0.2991 - recall: 0.0257 - mse: 0.1949 - mae: 0.3947 - auc: 0.8035 - f1_score: 0.4016 - val_loss: 0.6176 - val_accuracy: 0.6603 - val_precision: 0.2991 - val_recall: 0.0213 - val_mse: 0.2144 - val_mae: 0.4079 - val_auc: 0.7300 - val_f1_score: 0.3977
# Epoch 4/5
# 20/20 [==============================] - 0s 13ms/step - loss: 0.5188 - accuracy: 0.6792 - precision: 0.3232 - recall: 0.0202 - mse: 0.1752 - mae: 0.3573 - auc: 0.8234 - f1_score: 0.4274 - val_loss: 0.6182 - val_accuracy: 0.6571 - val_precision: 0.3603 - val_recall: 0.0212 - val_mse: 0.2131 - val_mae: 0.3981 - val_auc: 0.7298 - val_f1_score: 0.4053
# Epoch 5/5
# 20/20 [==============================] - 0s 14ms/step - loss: 0.4468 - accuracy: 0.7466 - precision: 0.4937 - recall: 0.0364 - mse: 0.1472 - mae: 0.3146 - auc: 0.8670 - f1_score: 0.6150 - val_loss: 0.7663 - val_accuracy: 0.6891 - val_precision: 0.6339 - val_recall: 0.0608 - val_mse: 0.2271 - val_mae: 0.3694 - val_auc: 0.7322 - val_f1_score: 0.5366
#
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5896 - accuracy: 0.7128 - precision: 0.6395 - recall: 0.0681 - mse: 0.1883 - mae: 0.3369 - auc: 0.7966 - f1_score: 0.5891
# accuracy: 71.28%
#
#
# Time taken to predict the model 0.1636948585510254
# ___________________________________________________________________________________
#
#
#
# Model : LSTM
# Model Summary
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 38, 64)            64000
#
#  lstm (LSTM)                 (None, 38, 100)           66000
#
#  lstm_1 (LSTM)               (None, 128)               117248
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 247,506
# Trainable params: 247,506
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# /var/folders/33/v0__8kvs301dg744qmtfs33w0000gn/T/ipykernel_13926/1534225968.py:9: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_model = KerasClassifier(build_fn=model_)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /opt/anaconda3/lib/python3.9/site-packages/keras_metrics/metrics.py:26: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return object.__getattribute__(self, name)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 20/20 [==============================] - ETA: 0s - loss: 0.6479 - accuracy: 0.6793 - precision: 0.6250 - recall: 0.0700 - mse: 0.2267 - mae: 0.4491 - auc: 0.7163 - f1_score: 0.4718WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /opt/anaconda3/lib/python3.9/site-packages/keras_metrics/metrics.py:26: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return object.__getattribute__(self, name)
# 20/20 [==============================] - 5s 114ms/step - loss: 0.6479 - accuracy: 0.6793 - precision: 0.6250 - recall: 0.0700 - mse: 0.2267 - mae: 0.4491 - auc: 0.7163 - f1_score: 0.4718 - val_loss: 0.6437 - val_accuracy: 0.6603 - val_precision: 0.6250 - val_recall: 0.0644 - val_mse: 0.2256 - val_mae: 0.4656 - val_auc: 0.7262 - val_f1_score: 0.3977
# Epoch 2/5
# 20/20 [==============================] - 2s 101ms/step - loss: 0.6224 - accuracy: 0.6712 - precision: 0.6250 - recall: 0.0595 - mse: 0.2159 - mae: 0.4432 - auc: 0.7300 - f1_score: 0.4016 - val_loss: 0.6328 - val_accuracy: 0.6603 - val_precision: 0.6250 - val_recall: 0.0554 - val_mse: 0.2213 - val_mae: 0.4069 - val_auc: 0.7423 - val_f1_score: 0.3977
# Epoch 3/5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.5667 - accuracy: 0.6913 - precision: 0.6310 - recall: 0.0534 - mse: 0.1926 - mae: 0.3897 - auc: 0.7841 - f1_score: 0.4753 - val_loss: 0.6482 - val_accuracy: 0.6955 - val_precision: 0.6462 - val_recall: 0.0590 - val_mse: 0.2170 - val_mae: 0.3763 - val_auc: 0.7371 - val_f1_score: 0.5557
# Epoch 4/5
# 20/20 [==============================] - 2s 115ms/step - loss: 0.4758 - accuracy: 0.7787 - precision: 0.6752 - recall: 0.0828 - mse: 0.1569 - mae: 0.3247 - auc: 0.8537 - f1_score: 0.7225 - val_loss: 0.6619 - val_accuracy: 0.6763 - val_precision: 0.6830 - val_recall: 0.1003 - val_mse: 0.2203 - val_mae: 0.3595 - val_auc: 0.7464 - val_f1_score: 0.5373
# Epoch 5/5
# 20/20 [==============================] - 2s 105ms/step - loss: 0.3809 - accuracy: 0.8348 - precision: 0.7072 - recall: 0.1239 - mse: 0.1190 - mae: 0.2475 - auc: 0.9135 - f1_score: 0.8021 - val_loss: 0.8060 - val_accuracy: 0.6795 - val_precision: 0.7120 - val_recall: 0.1478 - val_mse: 0.2290 - val_mae: 0.3604 - val_auc: 0.7350 - val_f1_score: 0.6216
#
# 13/13 [==============================] - 0s 20ms/step - loss: 0.6021 - accuracy: 0.7359 - precision: 0.7024 - recall: 0.1551 - mse: 0.1832 - mae: 0.3098 - auc: 0.8128 - f1_score: 0.6893
# accuracy: 73.59%
#
#
# Time taken to predict the model 0.5995581150054932
# ___________________________________________________________________________________
#
#
#
# Model : GRU
# Model Summary
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 38, 64)            64000
#
#  gru (GRU)                   (None, 128)               74496
#
#  dense_2 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 138,754
# Trainable params: 138,754
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# /var/folders/33/v0__8kvs301dg744qmtfs33w0000gn/T/ipykernel_13926/1534225968.py:9: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_model = KerasClassifier(build_fn=model_)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /opt/anaconda3/lib/python3.9/site-packages/keras_metrics/metrics.py:26: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return object.__getattribute__(self, name)
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 19/20 [===========================>..] - ETA: 0s - loss: 0.6507 - accuracy: 0.6750 - precision: 0.6871 - recall: 0.1552 - mse: 0.2290 - mae: 0.4582 - auc: 0.7170 - f1_score: 0.5141WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /opt/anaconda3/lib/python3.9/site-packages/keras_metrics/metrics.py:26: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return object.__getattribute__(self, name)
# 20/20 [==============================] - 3s 67ms/step - loss: 0.6478 - accuracy: 0.6768 - precision: 0.6871 - recall: 0.1550 - mse: 0.2277 - mae: 0.4561 - auc: 0.7192 - f1_score: 0.5138 - val_loss: 0.6352 - val_accuracy: 0.6603 - val_precision: 0.6871 - val_recall: 0.1484 - val_mse: 0.2221 - val_mae: 0.4255 - val_auc: 0.7253 - val_f1_score: 0.3977
# Epoch 2/5
# 20/20 [==============================] - 1s 47ms/step - loss: 0.5959 - accuracy: 0.6744 - precision: 0.6873 - recall: 0.1421 - mse: 0.2042 - mae: 0.4209 - auc: 0.7749 - f1_score: 0.4121 - val_loss: 0.6172 - val_accuracy: 0.6731 - val_precision: 0.6886 - val_recall: 0.1374 - val_mse: 0.2143 - val_mae: 0.4040 - val_auc: 0.7291 - val_f1_score: 0.4371
# Epoch 3/5
# 20/20 [==============================] - 1s 57ms/step - loss: 0.4985 - accuracy: 0.7410 - precision: 0.6924 - recall: 0.1421 - mse: 0.1654 - mae: 0.3436 - auc: 0.8386 - f1_score: 0.6468 - val_loss: 0.6407 - val_accuracy: 0.6731 - val_precision: 0.6904 - val_recall: 0.1492 - val_mse: 0.2184 - val_mae: 0.3725 - val_auc: 0.7375 - val_f1_score: 0.5396
# Epoch 4/5
# 20/20 [==============================] - 1s 60ms/step - loss: 0.3845 - accuracy: 0.8324 - precision: 0.7023 - recall: 0.1639 - mse: 0.1210 - mae: 0.2539 - auc: 0.9100 - f1_score: 0.7994 - val_loss: 0.6977 - val_accuracy: 0.6603 - val_precision: 0.7046 - val_recall: 0.1790 - val_mse: 0.2288 - val_mae: 0.3758 - val_auc: 0.7249 - val_f1_score: 0.5915
# Epoch 5/5
# 20/20 [==============================] - 1s 56ms/step - loss: 0.2943 - accuracy: 0.8805 - precision: 0.7167 - recall: 0.1966 - mse: 0.0900 - mae: 0.1987 - auc: 0.9496 - f1_score: 0.8609 - val_loss: 0.9796 - val_accuracy: 0.6763 - val_precision: 0.7207 - val_recall: 0.2129 - val_mse: 0.2424 - val_mae: 0.3535 - val_auc: 0.7272 - val_f1_score: 0.6331
#
# 13/13 [==============================] - 0s 9ms/step - loss: 0.7241 - accuracy: 0.7410 - precision: 0.7149 - recall: 0.2176 - mse: 0.2013 - mae: 0.2980 - auc: 0.8026 - f1_score: 0.7033
# accuracy: 74.10%
#
#
# Time taken to predict the model 0.3686866760253906
# ___________________________________________________________________________________

# %%
output_df
# Out:
#        model  accuracy  precision    recall       mse       mae       auc  \
# 0  SimpleRNN  0.712821   0.639534  0.068080  0.188266  0.336902  0.796631
# 1       LSTM  0.735897   0.702381  0.155090  0.183247  0.309761  0.812761
# 2        GRU  0.741026   0.714925  0.217619  0.201345  0.298019  0.802636
#
#    f1_score  prediction time
# 0  0.589103         0.163695
# 1  0.689325         0.599558
# 2  0.703342         0.368687

# %% [markdown]
# <h3>Traditional Methodologies</h3>

# %%
stemmer = PorterStemmer()
analyzer = CountVectorizer().build_analyzer()
def stemmed_words(doc):
    stemmed_words = [stemmer.stem(w) for w in analyzer(doc)]
    non_stop_words = [word for word in stemmed_words]
    return non_stop_words

# %%
count_vectorizer = CountVectorizer(stop_words= stop_words, max_features= 1000)
feature_vector = count_vectorizer.fit(data_v1['Text'])
train_ds_features = count_vectorizer.transform(data_v1['Text'])
features = feature_vector.get_feature_names()
features_counts = np.sum(train_ds_features.toarray(), axis = 0)
features_counts = pd.DataFrame(dict(features =  features, counts = features_counts))
features_counts = features_counts.sort_values("counts", ascending= False)[0:15]
features_counts
# Out:
#      features  counts
# 333      euro    1461
# 329       eur    1374
# 675     pound    1217
# 420       gbp    1119
# 924       usd    1055
# 297    dollar     580
# 381     forex     410
# 379  forecast     384
# 187   british     374
# 684     price     364
# 711      rate     342
# 265  currency     256
# 308       ecb     242
# 337    eurusd     236
# 627   outlook     226

# %%
train_x, test_x, train_y, test_y =  train_test_split(train_ds_features, data_v1['Sentiment'], test_size = 0.3, random_state = 42)

# %%
classifiers = {
    "BernoulliNB": BernoulliNB(),
    "ComplementNB": ComplementNB(),
    "MultinomialNB": MultinomialNB(),
    "LogisticRegression": LogisticRegression(),
    "KNeighborsClassifier": KNeighborsClassifier(),
    "DecisionTreeClassifier": DecisionTreeClassifier(),
    "RandomForestClassifier": RandomForestClassifier(),
    "MLPClassifier": MLPClassifier(max_iter=1000),
    "AdaBoostClassifier": AdaBoostClassifier()
}
estimators = []
for name, sklearn_classifier in classifiers.items():
    estimators.append((name,sklearn_classifier))

stacking_clf = StackingClassifier(estimators=estimators, final_estimator=RandomForestClassifier())

voting_clf = VotingClassifier(
        estimators=estimators,
        voting="hard")
classifiers['VotingClassifier'] = voting_clf
classifiers['StackingClassifier'] = stacking_clf
classifiers
# Out:
# {'BernoulliNB': BernoulliNB(),
#  'ComplementNB': ComplementNB(),
#  'MultinomialNB': MultinomialNB(),
#  'LogisticRegression': LogisticRegression(),
#  'KNeighborsClassifier': KNeighborsClassifier(),
#  'DecisionTreeClassifier': DecisionTreeClassifier(),
#  'RandomForestClassifier': RandomForestClassifier(),
#  'MLPClassifier': MLPClassifier(max_iter=1000),
#  'AdaBoostClassifier': AdaBoostClassifier(),
#  'VotingClassifier': VotingClassifier(estimators=[('BernoulliNB', BernoulliNB()),
#                               ('ComplementNB', ComplementNB()),
#                               ('MultinomialNB', MultinomialNB()),
#                               ('LogisticRegression', LogisticRegression()),
#                               ('KNeighborsClassifier', KNeighborsClassifier()),
#                               ('DecisionTreeClassifier',
#                                DecisionTreeClassifier()),
#                               ('RandomForestClassifier',
#                                RandomForestClassifier()),
#                               ('MLPClassifier', MLPClassifier(max_iter=1000)),
#                               ('AdaBoostClassifier', AdaBoostClassifier())]),
#  'StackingClassifier': StackingClassifier(estimators=[('BernoulliNB', BernoulliNB()),
#                                 ('ComplementNB', ComplementNB()),
#                                 ('MultinomialNB', MultinomialNB()),
#                                 ('LogisticRegression', LogisticRegression()),
#                                 ('KNeighborsClassifier', KNeighborsClassifier()),
#                                 ('DecisionTreeClassifier',
#                                  DecisionTreeClassifier()),
#                                 ('RandomForestClassifier',
#                                  RandomForestClassifier()),
#                                 ('MLPClassifier', MLPClassifier(max_iter=1000)),
#                                 ('AdaBoostClassifier', AdaBoostClassifier())],
#                     final_estimator=RandomForestClassifier())}

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import precision_score, \
    recall_score, confusion_matrix, classification_report, \
    accuracy_score, f1_score

for name, sklearn_classifier in classifiers.items():
    print("Classifier : ", name)
    sklearn_classifier.fit(train_x.toarray(), train_y)
    start_time = time.time()
    test_ds_predicted = sklearn_classifier.predict(test_x.toarray())
    end_time = time.time() - start_time
    print(metrics.classification_report(test_y,test_ds_predicted))
    print("")
    print("Time taken to predict the model " + str(end_time))
    print("")
    tr_mae = mean_absolute_error(test_y, test_ds_predicted)
    tr_mse = mean_squared_error(test_y, test_ds_predicted)
    tr_accuracy = accuracy_score(test_y, test_ds_predicted)
    tr_f1_score = f1_score(test_y, test_ds_predicted,average='weighted')
    tr_recall = recall_score(test_y, test_ds_predicted, average='weighted')
    tr_precision = precision_score(test_y, test_ds_predicted, average='weighted')
    tr_auc = roc_auc_score(test_y, test_ds_predicted)

    #print('MAE: %f' % mean_absolute_error(test_y, test_ds_predicted))
    #print('MSE: %f' % mean_squared_error(test_y, test_ds_predicted))
    #print('RMSE: %f' % sqrt(mean_squared_error(test_y, test_ds_predicted)))
    
    output_df = output_df.append([{'model': str(name), 'accuracy':tr_accuracy,'precision':tr_precision
                                   ,'recall':tr_recall,'mse':tr_mse,'mae':tr_mae
                                   ,'auc':tr_auc,'f1_score':tr_f1_score, 'prediction time': end_time}], ignore_index=True)
    
    
    if name != 'VotingClassifier':
        yhat = sklearn_classifier.predict_proba(test_x.toarray())
        fpr_rf, tpr_rf, threshold2 = roc_curve(test_y.to_numpy(), yhat[:,1])
        plt.rcParams["figure.figsize"] = (10,7)
        plt.figure(1)
        plt.plot([0, 1], [0, 1], 'k--')
        plt.plot(fpr_rf, tpr_rf, label=str(name) + ' (area = {:.3f})'.format(tr_auc))
        plt.xlabel('False positive rate')
        plt.ylabel('True positive rate')
        plt.title('ROC curve')
        plt.legend(loc='best')
        plt.savefig('td_roc_curve.png')
    
    print("________________________________________________________")
    print("")
    print("")
plt.show()
# Out:
# Classifier :  BernoulliNB
#               precision    recall  f1-score   support
#
#            0       0.54      0.57      0.55       191
#            1       0.79      0.76      0.77       394
#
#     accuracy                           0.70       585
#    macro avg       0.66      0.67      0.66       585
# weighted avg       0.71      0.70      0.70       585
#
#
# Time taken to predict the model 0.00590205192565918
#
# ________________________________________________________
#
#
# Classifier :  ComplementNB
#               precision    recall  f1-score   support
#
#            0       0.51      0.62      0.56       191
#            1       0.79      0.71      0.75       394
#
#     accuracy                           0.68       585
#    macro avg       0.65      0.67      0.66       585
# weighted avg       0.70      0.68      0.69       585
#
#
# Time taken to predict the model 0.0021209716796875
#
# ________________________________________________________
#
#
# Classifier :  MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.54      0.54      0.54       191
#            1       0.78      0.78      0.78       394
#
#     accuracy                           0.70       585
#    macro avg       0.66      0.66      0.66       585
# weighted avg       0.70      0.70      0.70       585
#
#
# Time taken to predict the model 0.003940105438232422
#
# ________________________________________________________
#
#
# Classifier :  LogisticRegression
#               precision    recall  f1-score   support
#
#            0       0.63      0.48      0.54       191
#            1       0.77      0.86      0.82       394
#
#     accuracy                           0.74       585
#    macro avg       0.70      0.67      0.68       585
# weighted avg       0.73      0.74      0.73       585
#
#
# Time taken to predict the model 0.003412961959838867
#
# ________________________________________________________
#
#
# Classifier :  KNeighborsClassifier
#               precision    recall  f1-score   support
#
#            0       0.57      0.55      0.56       191
#            1       0.79      0.80      0.79       394
#
#     accuracy                           0.72       585
#    macro avg       0.68      0.67      0.67       585
# weighted avg       0.71      0.72      0.72       585
#
#
# Time taken to predict the model 0.038294076919555664
#
# ________________________________________________________
#
#
# Classifier :  DecisionTreeClassifier
#               precision    recall  f1-score   support
#
#            0       0.61      0.57      0.59       191
#            1       0.80      0.83      0.81       394
#
#     accuracy                           0.74       585
#    macro avg       0.71      0.70      0.70       585
# weighted avg       0.74      0.74      0.74       585
#
#
# Time taken to predict the model 0.002630949020385742
#
# ________________________________________________________
#
#
# Classifier :  RandomForestClassifier
#               precision    recall  f1-score   support
#
#            0       0.66      0.50      0.57       191
#            1       0.78      0.88      0.83       394
#
#     accuracy                           0.75       585
#    macro avg       0.72      0.69      0.70       585
# weighted avg       0.74      0.75      0.74       585
#
#
# Time taken to predict the model 0.023058176040649414
#
# ________________________________________________________
#
#
# Classifier :  MLPClassifier
#               precision    recall  f1-score   support
#
#            0       0.61      0.57      0.59       191
#            1       0.80      0.82      0.81       394
#
#     accuracy                           0.74       585
#    macro avg       0.71      0.70      0.70       585
# weighted avg       0.74      0.74      0.74       585
#
#
# Time taken to predict the model 0.0035088062286376953
#
# ________________________________________________________
#
#
# Classifier :  AdaBoostClassifier
#               precision    recall  f1-score   support
#
#            0       0.71      0.30      0.42       191
#            1       0.74      0.94      0.82       394
#
#     accuracy                           0.73       585
#    macro avg       0.72      0.62      0.62       585
# weighted avg       0.73      0.73      0.69       585
#
#
# Time taken to predict the model 0.05330300331115723
#
# ________________________________________________________
#
#
# Classifier :  VotingClassifier
#               precision    recall  f1-score   support
#
#            0       0.61      0.51      0.56       191
#            1       0.78      0.84      0.81       394
#
#     accuracy                           0.74       585
#    macro avg       0.70      0.68      0.68       585
# weighted avg       0.73      0.74      0.73       585
#
#
# Time taken to predict the model 0.11650919914245605
#
# ________________________________________________________
#
#
# Classifier :  StackingClassifier
#               precision    recall  f1-score   support
#
#            0       0.62      0.46      0.52       191
#            1       0.77      0.86      0.81       394
#
#     accuracy                           0.73       585
#    macro avg       0.69      0.66      0.67       585
# weighted avg       0.72      0.73      0.72       585
#
#
# Time taken to predict the model 0.11147689819335938
#
# ________________________________________________________

# %%
output_df
# Out:
#                      model  accuracy  precision    recall       mse       mae  \
# 0                SimpleRNN  0.712821   0.639534  0.068080  0.188266  0.336902
# 1                     LSTM  0.735897   0.702381  0.155090  0.183247  0.309761
# 2                      GRU  0.741026   0.714925  0.217619  0.201345  0.298019
# 3              BernoulliNB  0.700855   0.705486  0.700855  0.299145  0.299145
# 4             ComplementNB  0.682051   0.701399  0.682051  0.317949  0.317949
# 5            MultinomialNB  0.702564   0.701768  0.702564  0.297436  0.297436
# 6       LogisticRegression  0.736752   0.725339  0.736752  0.263248  0.263248
# 7     KNeighborsClassifier  0.716239   0.714009  0.716239  0.283761  0.283761
# 8   DecisionTreeClassifier  0.741880   0.737177  0.741880  0.258120  0.258120
# 9   RandomForestClassifier  0.753846   0.744251  0.753846  0.246154  0.246154
# 10           MLPClassifier  0.741880   0.737743  0.741880  0.258120  0.258120
# 11      AdaBoostClassifier  0.731624   0.726357  0.731624  0.268376  0.268376
# 12        VotingClassifier  0.735043   0.726104  0.735043  0.264957  0.264957
# 13      StackingClassifier  0.729915   0.717201  0.729915  0.270085  0.270085
#
#          auc  f1_score  prediction time
# 0   0.796631  0.589103         0.163695
# 1   0.812761  0.689325         0.599558
# 2   0.802636  0.703342         0.368687
# 3   0.667320  0.702924         0.005902
# 4   0.665500  0.688619         0.002121
# 5   0.660496  0.702158         0.003940
# 6   0.669692  0.725992         0.003413
# 7   0.673346  0.715047         0.038294
# 8   0.696428  0.739016         0.002631
# 9   0.689126  0.743785         0.023058
# 10  0.697777  0.739428         0.003509
# 11  0.621376  0.694353         0.053303
# 12  0.677864  0.728357         0.116509
# 13  0.659221  0.717634         0.111477

# %%
output_df.to_csv('classifiers_output_result.csv', sep='\t')
