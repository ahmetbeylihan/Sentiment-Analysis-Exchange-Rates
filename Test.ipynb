# %%
import nltk
from nltk.corpus import shakespeare, machado, stopwords
w = nltk.corpus.gutenberg.words('shakespeare-caesar.txt')
w
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Julius', 'Caesar', ...]

# %%
words = [w for w in nltk.corpus.state_union.words() if w.isalpha()]
words
# Out:
# ['PRESIDENT',
#  'HARRY',
#  'S',
#  'TRUMAN',
#  'S',
#  'ADDRESS',
#  'BEFORE',
#  'A',
#  'JOINT',
#  'SESSION',
#  'OF',
#  'THE',
#  'CONGRESS',
#  'April',
#  'Mr',
#  'Speaker',
#  'Mr',
#  'President',
#  'Members',
#  'of',
#  'the',
#  'Congress',
#  'It',
#  'is',
#  'with',
#  'a',
#  'heavy',
#  'heart',
#  'that',
#  'I',
#  'stand',
#  'before',
#  'you',
#  'my',
#  'friends',
#  'and',
#  'colleagues',
#  'in',
#  'the',
#  'Congress',
#  'of',
#  'the',
#  'United',
#  'States',
#  'Only',
#  'yesterday',
#  'we',
#  'laid',
#  'to',
#  'rest',
#  'the',
#  'mortal',
#  'remains',
#  'of',
#  'our',
#  'beloved',
#  'President',
#  'Franklin',
#  'Delano',
#  'Roosevelt',
#  'At',
#  'a',
#  'time',
#  'like',
#  'this',
#  'words',
#  'are',
#  'inadequate',
#  'The',
#  'most',
#  'eloquent',
#  'tribute',
#  'would',
#  'be',
#  'a',
#  'reverent',
#  'silence',
#  'Yet',
#  'in',
#  'this',
#  'decisive',
#  'hour',
#  'when',
#  'world',
#  'events',
#  'are',
#  'moving',
#  'so',
#  'rapidly',
#  'our',
#  'silence',
#  'might',
#  'be',
#  'misunderstood',
#  'and',
#  'might',
#  'give',
#  'comfort',
#  'to',
#  'our',
#  'enemies',
#  'In',
#  'His',
#  'infinite',
#  'wisdom',
#  'Almighty',
#  'God',
#  'has',
#  'seen',
#  'fit',
#  'to',
#  'take',
#  'from',
#  'us',
#  'a',
#  'great',
#  'man',
#  'who',
#  'loved',
#  'and',
#  'was',
#  'beloved',
#  'by',
#  'all',
#  'humanity',
#  'No',
#  'man',
#  'could',
#  'possibly',
#  'fill',
#  'the',
#  'tremendous',
#  'void',
#  'left',
#  'by',
#  'the',
#  'passing',
#  'of',
#  'that',
#  'noble',
#  'soul',
#  'No',
#  'words',
#  'can',
#  'ease',
#  'the',
#  'aching',
#  'hearts',
#  'of',
#  'untold',
#  'millions',
#  'of',
#  'every',
#  'race',
#  'creed',
#  'and',
#  'color',
#  'The',
#  'world',
#  'knows',
#  'it',
#  'has',
#  'lost',
#  'a',
#  'heroic',
#  'champion',
#  'of',
#  'justice',
#  'and',
#  'freedom',
#  'Tragic',
#  'fate',
#  'has',
#  'thrust',
#  'upon',
#  'us',
#  'grave',
#  'responsibilities',
#  'We',
#  'must',
#  'carry',
#  'on',
#  'Our',
#  'departed',
#  'leader',
#  'never',
#  'looked',
#  'backward',
#  'He',
#  'looked',
#  'forward',
#  'and',
#  'moved',
#  'forward',
#  'That',
#  'is',
#  'what',
#  'he',
#  'would',
#  'want',
#  'us',
#  'to',
#  'do',
#  'That',
#  'is',
#  'what',
#  'America',
#  'will',
#  'do',
#  'So',
#  'much',
#  'blood',
#  'has',
#  'already',
#  'been',
#  'shed',
#  'for',
#  'the',
#  'ideals',
#  'which',
#  'we',
#  'cherish',
#  'and',
#  'for',
#  'which',
#  'Franklin',
#  'Delano',
#  'Roosevelt',
#  'lived',
#  'and',
#  'died',
#  'that',
#  'we',
#  'dare',
#  'not',
#  'permit',
#  'even',
#  'a',
#  'momentary',
#  'pause',
#  'in',
#  'the',
#  'hard',
#  'fight',
#  'for',
#  'victory',
#  'Today',
#  'the',
#  'entire',
#  'world',
#  'is',
#  'looking',
#  'to',
#  'America',
#  'for',
#  'enlightened',
#  'leadership',
#  'to',
#  'peace',
#  'and',
#  'progress',
#  'Such',
#  'a',
#  'leadership',
#  'requires',
#  'vision',
#  'courage',
#  'and',
#  'tolerance',
#  'It',
#  'can',
#  'be',
#  'provided',
#  'only',
#  'by',
#  'a',
#  'united',
#  'nation',
#  'deeply',
#  'devoted',
#  'to',
#  'the',
#  'highest',
#  'ideals',
#  'With',
#  'great',
#  'humility',
#  'I',
#  'call',
#  'upon',
#  'all',
#  'Americans',
#  'to',
#  'help',
#  'me',
#  'keep',
#  'our',
#  'nation',
#  'united',
#  'in',
#  'defense',
#  'of',
#  'those',
#  'ideals',
#  'which',
#  'have',
#  'been',
#  'so',
#  'eloquently',
#  'proclaimed',
#  'by',
#  'Franklin',
#  'Roosevelt',
#  'I',
#  'want',
#  'in',
#  'turn',
#  'to',
#  'assure',
#  'my',
#  'fellow',
#  'Americans',
#  'and',
#  'all',
#  'of',
#  'those',
#  'who',
#  'love',
#  'peace',
#  'and',
#  'liberty',
#  'throughout',
#  'the',
#  'world',
#  'that',
#  'I',
#  'will',
#  'support',
#  'and',
#  'defend',
#  'those',
#  'ideals',
#  'with',
#  'all',
#  'my',
#  'strength',
#  'and',
#  'all',
#  'my',
#  'heart',
#  'That',
#  'is',
#  'my',
#  'duty',
#  'and',
#  'I',
#  'shall',
#  'not',
#  'shirk',
#  'it',
#  'So',
#  'that',
#  'there',
#  'can',
#  'be',
#  'no',
#  'possible',
#  'misunderstanding',
#  'both',
#  'Germany',
#  'and',
#  'Japan',
#  'can',
#  'be',
#  'certain',
#  'beyond',
#  'any',
#  'shadow',
#  'of',
#  'a',
#  'doubt',
#  'that',
#  'America',
#  'will',
#  'continue',
#  'the',
#  'fight',
#  'for',
#  'freedom',
#  'until',
#  'no',
#  'vestige',
#  'of',
#  'resistance',
#  'remains',
#  'We',
#  'are',
#  'deeply',
#  'conscious',
#  'of',
#  'the',
#  'fact',
#  'that',
#  'much',
#  'hard',
#  'fighting',
#  'is',
#  'still',
#  'ahead',
#  'of',
#  'us',
#  'Having',
#  'to',
#  'pay',
#  'such',
#  'a',
#  'heavy',
#  'price',
#  'to',
#  'make',
#  'complete',
#  'victory',
#  'certain',
#  'America',
#  'will',
#  'never',
#  'become',
#  'a',
#  'party',
#  'to',
#  'any',
#  'plan',
#  'for',
#  'partial',
#  'victory',
#  'To',
#  'settle',
#  'for',
#  'merely',
#  'another',
#  'temporary',
#  'respite',
#  'would',
#  'surely',
#  'jeopardize',
#  'the',
#  'future',
#  'security',
#  'of',
#  'all',
#  'the',
#  'world',
#  'Our',
#  'demand',
#  'has',
#  'been',
#  'and',
#  'it',
#  'remains',
#  'Unconditional',
#  'Surrender',
#  'We',
#  'will',
#  'not',
#  'traffic',
#  'with',
#  'the',
#  'breakers',
#  'of',
#  'the',
#  'peace',
#  'on',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'peace',
#  'The',
#  'responsibility',
#  'for',
#  'making',
#  'of',
#  'the',
#  'peace',
#  'and',
#  'it',
#  'is',
#  'a',
#  'very',
#  'grave',
#  'responsibility',
#  'must',
#  'rest',
#  'with',
#  'the',
#  'defenders',
#  'of',
#  'the',
#  'peace',
#  'We',
#  'are',
#  'not',
#  'unconscious',
#  'of',
#  'the',
#  'dictates',
#  'of',
#  'humanity',
#  'We',
#  'do',
#  'not',
#  'wish',
#  'to',
#  'see',
#  'unnecessary',
#  'or',
#  'unjustified',
#  'suffering',
#  'But',
#  'the',
#  'laws',
#  'of',
#  'Go',
#  'd',
#  'and',
#  'of',
#  'man',
#  'have',
#  'been',
#  'violated',
#  'and',
#  'the',
#  'guilty',
#  'must',
#  'not',
#  'go',
#  'unpunished',
#  'Nothing',
#  'shall',
#  'shake',
#  'our',
#  'determination',
#  'to',
#  'punish',
#  'the',
#  'war',
#  'criminals',
#  'even',
#  'though',
#  'we',
#  'must',
#  'pursue',
#  'them',
#  'to',
#  'the',
#  'ends',
#  'of',
#  'the',
#  'earth',
#  'Lasting',
#  'peace',
#  'can',
#  'never',
#  'be',
#  'secured',
#  'if',
#  'we',
#  'permit',
#  'our',
#  'dangerous',
#  'opponents',
#  'to',
#  'plot',
#  'future',
#  'wars',
#  'with',
#  'impunity',
#  'at',
#  'any',
#  'mountain',
#  'retreat',
#  'however',
#  'distant',
#  'In',
#  'this',
#  'shrinking',
#  'world',
#  'it',
#  'is',
#  'futile',
#  'to',
#  'seek',
#  'safety',
#  'behind',
#  'geographical',
#  'barriers',
#  'Real',
#  'security',
#  'will',
#  'be',
#  'found',
#  'only',
#  'in',
#  'law',
#  'and',
#  'in',
#  'justice',
#  'Here',
#  'in',
#  'America',
#  'we',
#  'have',
#  'labored',
#  'long',
#  'and',
#  'hard',
#  'to',
#  'achieve',
#  'a',
#  'social',
#  'order',
#  'worthy',
#  'of',
#  'our',
#  'great',
#  'heritage',
#  'In',
#  'our',
#  'time',
#  'tremendous',
#  'progress',
#  'has',
#  'been',
#  'made',
#  'toward',
#  'a',
#  'really',
#  'democratic',
#  'way',
#  'of',
#  'life',
#  'Let',
#  'me',
#  'assure',
#  'the',
#  'forward',
#  'looking',
#  'people',
#  'of',
#  'America',
#  'that',
#  'there',
#  'w',
#  'ill',
#  'be',
#  'no',
#  'relaxation',
#  'in',
#  'our',
#  'efforts',
#  'to',
#  'improve',
#  'the',
#  'lot',
#  'of',
#  'the',
#  'common',
#  'people',
#  'In',
#  'the',
#  'difficult',
#  'days',
#  'ahead',
#  'unquestionably',
#  'we',
#  'shall',
#  'face',
#  'problems',
#  'of',
#  'staggering',
#  'proportions',
#  'However',
#  'with',
#  'the',
#  'faith',
#  'of',
#  'our',
#  'fathers',
#  'in',
#  'our',
#  'hearts',
#  'we',
#  'do',
#  'not',
#  'fear',
#  'the',
#  'future',
#  'On',
#  'the',
#  'battlefields',
#  'we',
#  'have',
#  'frequently',
#  'faced',
#  'overwhelming',
#  'odds',
#  'and',
#  'won',
#  'At',
#  'home',
#  'Americans',
#  'will',
#  'not',
#  'be',
#  'less',
#  'resolute',
#  'We',
#  'shall',
#  'never',
#  'cease',
#  'our',
#  'struggle',
#  'to',
#  'preserve',
#  'and',
#  'maintain',
#  'our',
#  'American',
#  'way',
#  'of',
#  'life',
#  'At',
#  'this',
#  'moment',
#  'America',
#  'along',
#  'with',
#  'her',
#  'brave',
#  'Allies',
#  'is',
#  'paying',
#  'again',
#  'a',
#  'heavy',
#  'price',
#  'for',
#  'the',
#  'defense',
#  'of',
#  'our',
#  'freedom',
#  'With',
#  'characteristic',
#  'energy',
#  'we',
#  'are',
#  'assisting',
#  'in',
#  'the',
#  'liberation',
#  'of',
#  'entire',
#  'nations',
#  'Gradually',
#  'the',
#  'shackles',
#  'of',
#  'slavery',
#  'are',
#  'being',
#  'broken',
#  'by',
#  't',
#  'he',
#  'forces',
#  'of',
#  'freedom',
#  'All',
#  'of',
#  'us',
#  'are',
#  'praying',
#  'for',
#  'a',
#  'speedy',
#  'victory',
#  'Every',
#  'day',
#  'peace',
#  'is',
#  'delayed',
#  'costs',
#  'a',
#  'terrible',
#  'toll',
#  'The',
#  'armies',
#  'of',
#  'liberation',
#  'today',
#  'are',
#  'bringing',
#  'to',
#  'an',
#  'end',
#  'Hitler',
#  's',
#  'ghastly',
#  'threat',
#  'to',
#  'dominate',
#  'the',
#  'world',
#  'Tokyo',
#  'rocks',
#  'under',
#  'the',
#  'weight',
#  'of',
#  'our',
#  'bombs',
#  'The',
#  'grand',
#  'strategy',
#  'of',
#  'the',
#  'United',
#  'Nations',
#  'war',
#  'has',
#  'been',
#  'determined',
#  'due',
#  'in',
#  'no',
#  'small',
#  'measure',
#  'to',
#  'the',
#  'vision',
#  'of',
#  'our',
#  'departed',
#  'Commander',
#  'in',
#  'Chief',
#  'We',
#  'are',
#  'now',
#  'carrying',
#  'out',
#  'our',
#  'part',
#  'of',
#  'that',
#  'strategy',
#  'under',
#  'the',
#  'able',
#  'direction',
#  'of',
#  'Admiral',
#  'Leahy',
#  'General',
#  'Marshall',
#  'A',
#  'dmiral',
#  'King',
#  'General',
#  'Arnold',
#  'General',
#  'Eisenhower',
#  'Admiral',
#  'Nimitz',
#  'and',
#  'General',
#  'MacArthur',
#  'I',
#  'want',
#  'the',
#  'entire',
#  'world',
#  'to',
#  'know',
#  'that',
#  'this',
#  'direction',
#  'must',
#  'and',
#  'will',
#  'remain',
#  'unchanged',
#  'and',
#  'unhampered',
#  'Our',
#  'debt',
#  'to',
#  'the',
#  'heroic',
#  'men',
#  'and',
#  'valiant',
#  'women',
#  'in',
#  'the',
#  'service',
#  'of',
#  'our',
#  'country',
#  'can',
#  'never',
#  'be',
#  'repaid',
#  'They',
#  'have',
#  'earned',
#  'our',
#  'undying',
#  'gratitude',
#  'America',
#  'will',
#  'never',
#  'forget',
#  'their',
#  'sacrifices',
#  'Because',
#  'of',
#  'these',
#  'sacrifices',
#  'the',
#  'dawn',
#  'of',
#  'justice',
#  'and',
#  'freedom',
#  'throughout',
#  'th',
#  'e',
#  'world',
#  'slowly',
#  'casts',
#  'its',
#  'gleam',
#  'across',
#  'the',
#  'horizon',
#  'Our',
#  'forefathers',
#  'came',
#  'to',
#  'our',
#  'rugged',
#  'shores',
#  'in',
#  'search',
#  'of',
#  'religious',
#  'tolerance',
#  'political',
#  'freedom',
#  'and',
#  'economic',
#  'opportunity',
#  'For',
#  'those',
#  'fundamental',
#  'rights',
#  'they',
#  'risked',
#  'their',
#  'lives',
#  'We',
#  'well',
#  'know',
#  'today',
#  'that',
#  'such',
#  'rights',
#  'can',
#  'be',
#  'preserved',
#  'only',
#  'by',
#  'constant',
#  'vigilance',
#  'the',
#  'eternal',
#  'price',
#  'of',
#  'liberty',
#  'Within',
#  'an',
#  'hour',
#  'after',
#  'I',
#  'took',
#  'the',
#  'oath',
#  'of',
#  ...]

# %%
stopwords = nltk.corpus.stopwords.words("english")
words = [w for w in words if w.lower() not in stopwords]

# %%
#words: list[str] = nltk.word_tokenize(text)
fd = nltk.FreqDist(words)
fd
# Out:
# FreqDist({'must': 1568, 'people': 1291, 'world': 1128, 'year': 1097, 'America': 1076, 'us': 1049, 'new': 1049, 'Congress': 1014, 'years': 827, 'American': 784, ...})

# %%
fd.most_common(3)
# Out:
# [('must', 1568), ('people', 1291), ('world', 1128)]

# %%
lower_fd = nltk.FreqDist([w.lower() for w in fd])

# %%
text = nltk.Text(nltk.corpus.state_union.words())
text.concordance("america", lines=5)
# Out:
# Displaying 5 of 1079 matches:
#  would want us to do . That is what America will do . So much blood has already
# ay , the entire world is looking to America for enlightened leadership to peace
# beyond any shadow of a doubt , that America will continue the fight for freedom
#  to make complete victory certain , America will never become a party to any pl
# nly in law and in justice . Here in America , we have labored long and hard to

# %%
concordance_list = text.concordance_list("america", lines=2)

# %%
for entry in concordance_list:
     print(entry.line)
# Out:
#  would want us to do . That is what America will do . So much blood has already
# ay , the entire world is looking to America for enlightened leadership to peace

# %%
words = [w for w in nltk.corpus.state_union.words() if w.isalpha()]
finder = nltk.collocations.TrigramCollocationFinder.from_words(words)

# %%
finder.ngram_fd.most_common(2)
# Out:
# [(('the', 'United', 'States'), 294), (('the', 'American', 'people'), 185)]

# %%
finder.ngram_fd.tabulate(2)
# Out:
#   ('the', 'United', 'States') ('the', 'American', 'people')
#                           294                           185

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
sia.polarity_scores("Wow, NLTK is really powerful!")
# Out:
# {'neg': 0.0, 'neu': 0.295, 'pos': 0.705, 'compound': 0.8012}

# %%
tweets = [t.replace("://", "//") for t in nltk.corpus.twitter_samples.strings()]

# %%
from random import shuffle
def is_positive(tweet: str) -> bool:
    """True if tweet has positive compound sentiment, False otherwise."""
    return sia.polarity_scores(tweet)["compound"] > 0

shuffle(tweets)
for tweet in tweets[:10]:
    print(">", is_positive(tweet), tweet)
# Out:
# > False RT @Natwaah: I wonder how much time Ed Miliband has wasted in these various Q&amp;As and debates by asking people their names and saying "let m…
# > True RT @jackfostr: @KennyFarq well, it's a bit selective, because SNP worked with all parties when in minority govt.
# > False if we vote in large snp group at wm its win/win no matter what else happens
# > True All Miliband had to say was we'll concentrate on winning as many seats as possible to win a majority.He can't even get that right #GE2015
# > True RT @AnitaBellows12: RT @Tommy_Colc
# FT come out in support of Tories claiming Miliband is "preoccupied w/ inequality".The man who wrote it h…
# > True @nejcsvete hi! On our shouting out list you are one of the best, what's your secret behind this?:)@AdeccoWaytoWork #SandroForCEO #CEO1Month
# > True @afneil ALLWAYS LIKED YOU ANDREW NOW PLAY MY BLOODY RECORD ON ELECTION NIGHT https//t.co/au9gnjoR3t CHEERS MATE !!!
# > True @dspdavey Gorgeous, Deborah! Good taste! :) You can use coupon code COLOURDEB for red, purple or blue here:  http//t.co/MXEKsnMvvX Thanks!!
# > True The moment I decide to log onto the account I haven't been on in years is the moment I saw the best thing ever :) http//t.co/pu6B5jodur
# > False RT @PeatWorrier: "A vote for the SNP is. Er. A vote for another referendum we insist Holyrood has no legal authority to legislate for" http…

# %%
positive_review_ids = nltk.corpus.movie_reviews.fileids(categories=["pos"])
negative_review_ids = nltk.corpus.movie_reviews.fileids(categories=["neg"])
all_review_ids = positive_review_ids + negative_review_ids

# %%
from statistics import mean

def is_positive(review_id: str) -> bool:
    """True if the average of all sentence compound scores is positive."""
    text = nltk.corpus.movie_reviews.raw(review_id)
    scores = [
        sia.polarity_scores(sentence)["compound"]
        for sentence in nltk.sent_tokenize(text)
    ]
    return mean(scores) > 0

# %%
unwanted = nltk.corpus.stopwords.words("english")
unwanted.extend([w.lower() for w in nltk.corpus.names.words()])

def skip_unwanted(pos_tuple):
    word, tag = pos_tuple
    if not word.isalpha() or word in unwanted:
        return False
    if tag.startswith("NN"):
        return False
    return True

positive_words = [word for word, tag in filter(
    skip_unwanted,
    nltk.pos_tag(nltk.corpus.movie_reviews.words(categories=["pos"]))
)]
negative_words = [word for word, tag in filter(
    skip_unwanted,
    nltk.pos_tag(nltk.corpus.movie_reviews.words(categories=["neg"]))
)]

# %%
def extract_features(text):
    features = dict()
    wordcount = 0
    compound_scores = list()
    positive_scores = list()

    for sentence in nltk.sent_tokenize(text):
        for word in nltk.word_tokenize(sentence):
            if word.lower() in top_100_positive:
                wordcount += 1
        compound_scores.append(sia.polarity_scores(sentence)["compound"])
        positive_scores.append(sia.polarity_scores(sentence)["pos"])

    # Adding 1 to the final compound score to always have positive numbers
    # since some classifiers you'll use later don't work with negative numbers.
    features["mean_compound"] = mean(compound_scores) + 1
    features["mean_positive"] = mean(positive_scores)
    features["wordcount"] = wordcount

    return features

# %%
positive_fd = nltk.FreqDist(positive_words)
negative_fd = nltk.FreqDist(negative_words)

common_set = set(positive_fd).intersection(negative_fd)

for word in common_set:
    del positive_fd[word]
    del negative_fd[word]

top_100_positive = {word for word, count in positive_fd.most_common(100)}
top_100_negative = {word for word, count in negative_fd.most_common(100)}

# %%
features = [
    (extract_features(nltk.corpus.movie_reviews.raw(review)), "pos")
    for review in nltk.corpus.movie_reviews.fileids(categories=["pos"])
]
features.extend([
    (extract_features(nltk.corpus.movie_reviews.raw(review)), "neg")
    for review in nltk.corpus.movie_reviews.fileids(categories=["neg"])
])

# %%
from sklearn.naive_bayes import (
    BernoulliNB,
    ComplementNB,
    MultinomialNB,
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
classifiers = {
    "BernoulliNB": BernoulliNB(),
    "ComplementNB": ComplementNB(),
    "MultinomialNB": MultinomialNB(),
    "KNeighborsClassifier": KNeighborsClassifier(),
    "DecisionTreeClassifier": DecisionTreeClassifier(),
    "RandomForestClassifier": RandomForestClassifier(),
    "LogisticRegression": LogisticRegression(),
    "MLPClassifier": MLPClassifier(max_iter=1000),
    "AdaBoostClassifier": AdaBoostClassifier(),
}

# %%
features = [
    (extract_features(nltk.corpus.movie_reviews.raw(review)), "pos")
    for review in nltk.corpus.movie_reviews.fileids(categories=["pos"])
]
features.extend([
    (extract_features(nltk.corpus.movie_reviews.raw(review)), "neg")
    for review in nltk.corpus.movie_reviews.fileids(categories=["neg"])
])

# %%
features
# Out:
# [({'mean_compound': 0.9735790697674419,
#    'mean_positive': 0.06688372093023255,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1019282608695653,
#    'mean_positive': 0.12247826086956522,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.303411111111111,
#    'mean_positive': 0.17627777777777778,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9218967741935484,
#    'mean_positive': 0.10312903225806452,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0812428571428572,
#    'mean_positive': 0.12728571428571428,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1828326923076924,
#    'mean_positive': 0.1455,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1628809523809525,
#    'mean_positive': 0.14966666666666667,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0671272727272727,
#    'mean_positive': 0.12469090909090909,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 0.9375013333333333,
#    'mean_positive': 0.0842,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.134544,
#    'mean_positive': 0.11618666666666666,
#    'wordcount': 3},
#   'pos'),
#  ({'mean_compound': 1.1545172413793103,
#    'mean_positive': 0.17010344827586207,
#    'wordcount': 4},
#   'pos'),
#  ({'mean_compound': 1.0059538461538462,
#    'mean_positive': 0.09615384615384616,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1402838709677419,
#    'mean_positive': 0.12203225806451613,
#    'wordcount': 3},
#   'pos'),
#  ({'mean_compound': 1.2246777777777778,
#    'mean_positive': 0.16292592592592592,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0004392857142856,
#    'mean_positive': 0.07096428571428572,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.4583366666666666,
#    'mean_positive': 0.2038,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.158078431372549,
#    'mean_positive': 0.13405882352941176,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.0409944444444443,
#    'mean_positive': 0.10675925925925926,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.2302466666666667, 'mean_positive': 0.17, 'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.2574156250000001,
#    'mean_positive': 0.129625,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.1320605263157895,
#    'mean_positive': 0.09671052631578947,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.2321961538461539,
#    'mean_positive': 0.13338461538461538,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9557886363636363,
#    'mean_positive': 0.11847727272727272,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.1947764705882353,
#    'mean_positive': 0.14313725490196078,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.0403892857142858,
#    'mean_positive': 0.10142857142857142,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0660619047619049,
#    'mean_positive': 0.09842857142857143,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0148181818181818,
#    'mean_positive': 0.07952272727272727,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.170412, 'mean_positive': 0.14396, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1040735294117647,
#    'mean_positive': 0.09142647058823529,
#    'wordcount': 4},
#   'pos'),
#  ({'mean_compound': 1.006935, 'mean_positive': 0.08405, 'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.2127296296296297,
#    'mean_positive': 0.12066666666666667,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.1848727272727273,
#    'mean_positive': 0.10663636363636364,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.2456842105263157,
#    'mean_positive': 0.0998421052631579,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.101904761904762,
#    'mean_positive': 0.11128571428571428,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0079733333333334,
#    'mean_positive': 0.1032,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.983246875, 'mean_positive': 0.079125, 'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.367611111111111,
#    'mean_positive': 0.16374074074074074,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 0.8373264705882353,
#    'mean_positive': 0.1176764705882353,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1126057142857142,
#    'mean_positive': 0.10964285714285714,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.1324791666666667,
#    'mean_positive': 0.11241666666666666,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9582864864864865,
#    'mean_positive': 0.09678378378378379,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.017665625, 'mean_positive': 0.10209375, 'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.97135,
#    'mean_positive': 0.11976470588235294,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.180825,
#    'mean_positive': 0.1636923076923077,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9367263157894736,
#    'mean_positive': 0.06602631578947368,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.1947227272727272,
#    'mean_positive': 0.11736363636363636,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.8699071428571429,
#    'mean_positive': 0.12296428571428572,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.06491,
#    'mean_positive': 0.09676666666666667,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 0.859936, 'mean_positive': 0.104, 'wordcount': 0}, 'neg'),
#  ({'mean_compound': 0.9723209302325582,
#    'mean_positive': 0.11576744186046511,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.8300617647058823,
#    'mean_positive': 0.07891176470588235,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9130414634146342,
#    'mean_positive': 0.07814634146341463,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0501142857142858,
#    'mean_positive': 0.14557142857142857,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 0.8424333333333334,
#    'mean_positive': 0.09025641025641025,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.0809883720930233,
#    'mean_positive': 0.09097674418604651,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.1116581395348837,
#    'mean_positive': 0.17200000000000001,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.17819, 'mean_positive': 0.10034, 'wordcount': 2}, 'pos'),
#  ({'mean_compound': 1.1234770833333334,
#    'mean_positive': 0.12139583333333333,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.1619342105263157,
#    'mean_positive': 0.16026315789473683,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.323325, 'mean_positive': 0.19835, 'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.9858012658227848,
#    'mean_positive': 0.07774683544303797,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 0.9339151515151515,
#    'mean_positive': 0.117,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0059189189189188,
#    'mean_positive': 0.061054054054054056,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.279890243902439,
#    'mean_positive': 0.14817073170731707,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0070305555555557,
#    'mean_positive': 0.07608333333333334,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0061909090909091,
#    'mean_positive': 0.08472727272727272,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9974142857142857,
#    'mean_positive': 0.08775,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9583419354838709,
#    'mean_positive': 0.07283870967741936,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0774208333333333,
#    'mean_positive': 0.06954166666666667,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.079163157894737,
#    'mean_positive': 0.13136842105263158,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.1021545454545454,
#    'mean_positive': 0.1393181818181818,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9649696428571428,
#    'mean_positive': 0.15125,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9352304347826087,
#    'mean_positive': 0.054,
#    'wordcount': 2},
#   'neg'),
#  ({'mean_compound': 1.139368, 'mean_positive': 0.13712, 'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 0.9132866666666667,
#    'mean_positive': 0.1055,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.2354370370370371,
#    'mean_positive': 0.15144444444444444,
#    'wordcount': 3},
#   'pos'),
#  ({'mean_compound': 0.9734340909090909,
#    'mean_positive': 0.09154545454545454,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9006366666666666,
#    'mean_positive': 0.08183333333333333,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.1431129032258065,
#    'mean_positive': 0.10735483870967742,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.0105045454545454,
#    'mean_positive': 0.09486363636363636,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0878263157894736,
#    'mean_positive': 0.1163421052631579,
#    'wordcount': 25},
#   'pos'),
#  ({'mean_compound': 0.9049442307692308,
#    'mean_positive': 0.0660576923076923,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.055704, 'mean_positive': 0.10244, 'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.1829042372881355,
#    'mean_positive': 0.13529661016949152,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 0.8500176470588235,
#    'mean_positive': 0.06970588235294117,
#    'wordcount': 2},
#   'neg'),
#  ({'mean_compound': 1.0053033898305084,
#    'mean_positive': 0.12481355932203389,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9669076923076924,
#    'mean_positive': 0.08515384615384615,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0679055555555557,
#    'mean_positive': 0.07794444444444444,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0214238805970148,
#    'mean_positive': 0.058940298507462685,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.2455571428571428,
#    'mean_positive': 0.21417857142857144,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1844583333333334,
#    'mean_positive': 0.1335,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0084272727272727,
#    'mean_positive': 0.08359090909090909,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0883851063829788,
#    'mean_positive': 0.11740425531914893,
#    'wordcount': 3},
#   'pos'),
#  ({'mean_compound': 1.2875761904761904,
#    'mean_positive': 0.14502380952380953,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.9550441860465116,
#    'mean_positive': 0.06188372093023256,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.0145514285714285,
#    'mean_positive': 0.07637142857142858,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9476369565217392,
#    'mean_positive': 0.12556521739130436,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.240809090909091,
#    'mean_positive': 0.12436363636363637,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1089701754385966,
#    'mean_positive': 0.12529824561403508,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.1240822222222222,
#    'mean_positive': 0.15117777777777777,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.276940909090909,
#    'mean_positive': 0.1348181818181818,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.1344885714285715,
#    'mean_positive': 0.12974285714285713,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.0280379310344827,
#    'mean_positive': 0.1086551724137931,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1724463414634148,
#    'mean_positive': 0.15302439024390244,
#    'wordcount': 6},
#   'pos'),
#  ({'mean_compound': 1.03599, 'mean_positive': 0.110725, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1488941176470588,
#    'mean_positive': 0.10123529411764706,
#    'wordcount': 18},
#   'pos'),
#  ({'mean_compound': 1.240548, 'mean_positive': 0.13192, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0850214285714286,
#    'mean_positive': 0.07294285714285714,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0663829787234043,
#    'mean_positive': 0.1001063829787234,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.9432153846153846,
#    'mean_positive': 0.08946153846153847,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.2535,
#    'mean_positive': 0.1900909090909091,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.85514, 'mean_positive': 0.0717, 'wordcount': 1}, 'neg'),
#  ({'mean_compound': 0.8922869565217392,
#    'mean_positive': 0.07565217391304348,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.8923375, 'mean_positive': 0.0634375, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0888975609756097,
#    'mean_positive': 0.10370731707317073,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.163085294117647,
#    'mean_positive': 0.15002941176470588,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.0274973684210527,
#    'mean_positive': 0.0861842105263158,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.2383529411764707,
#    'mean_positive': 0.1653529411764706,
#    'wordcount': 8},
#   'pos'),
#  ({'mean_compound': 1.165678787878788,
#    'mean_positive': 0.12654545454545454,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0317,
#    'mean_positive': 0.07435849056603773,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.2905333333333333,
#    'mean_positive': 0.1749090909090909,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.052485294117647,
#    'mean_positive': 0.1211764705882353,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.079457142857143,
#    'mean_positive': 0.17185714285714285,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9554916666666666,
#    'mean_positive': 0.06210416666666667,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9717857142857143,
#    'mean_positive': 0.05928571428571429,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9948400000000001,
#    'mean_positive': 0.08268571428571429,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.8915094339622641,
#    'mean_positive': 0.09066037735849057,
#    'wordcount': 4},
#   'pos'),
#  ({'mean_compound': 1.00462,
#    'mean_positive': 0.09154545454545454,
#    'wordcount': 16},
#   'pos'),
#  ({'mean_compound': 0.9584433333333333,
#    'mean_positive': 0.0677,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0187166666666667,
#    'mean_positive': 0.09972222222222223,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9928421052631579,
#    'mean_positive': 0.1275,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.2076888888888888,
#    'mean_positive': 0.11438888888888889,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1427814814814814,
#    'mean_positive': 0.12407407407407407,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.089315625, 'mean_positive': 0.12946875, 'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.1805380952380953,
#    'mean_positive': 0.17676190476190476,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.0879742268041237,
#    'mean_positive': 0.0862061855670103,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1033840909090908,
#    'mean_positive': 0.11113636363636363,
#    'wordcount': 6},
#   'pos'),
#  ({'mean_compound': 1.0824422222222223,
#    'mean_positive': 0.11324444444444444,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.980471875, 'mean_positive': 0.1296875, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.927776, 'mean_positive': 0.11272, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0515038461538462,
#    'mean_positive': 0.08857692307692308,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.161764705882353,
#    'mean_positive': 0.08611764705882353,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.8919924528301887,
#    'mean_positive': 0.09637735849056604,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0984227272727272,
#    'mean_positive': 0.08118181818181819,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.2310631578947369,
#    'mean_positive': 0.13142105263157894,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.8536304347826087,
#    'mean_positive': 0.08795652173913043,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.012215625, 'mean_positive': 0.10928125, 'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.317116, 'mean_positive': 0.18832, 'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0528204545454545,
#    'mean_positive': 0.09236363636363637,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.027995652173913,
#    'mean_positive': 0.10473913043478261,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0226595238095237,
#    'mean_positive': 0.10695238095238095,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0983568627450981,
#    'mean_positive': 0.10562745098039215,
#    'wordcount': 6},
#   'pos'),
#  ({'mean_compound': 1.079465789473684,
#    'mean_positive': 0.15007894736842106,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.8561,
#    'mean_positive': 0.061586206896551726,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0616311111111112,
#    'mean_positive': 0.11882222222222222,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1604351351351352,
#    'mean_positive': 0.17335135135135135,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9252653846153847,
#    'mean_positive': 0.10253846153846154,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9541526315789474,
#    'mean_positive': 0.06850877192982456,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 0.8797111111111111,
#    'mean_positive': 0.10968888888888889,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0756744680851065,
#    'mean_positive': 0.13097872340425532,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.4655473684210527,
#    'mean_positive': 0.19052631578947368,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.947275,
#    'mean_positive': 0.08607142857142858,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0773675675675676,
#    'mean_positive': 0.115,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.3888925925925926,
#    'mean_positive': 0.18433333333333332,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 0.6676052631578948,
#    'mean_positive': 0.04455263157894737,
#    'wordcount': 2},
#   'neg'),
#  ({'mean_compound': 1.123969090909091,
#    'mean_positive': 0.15205454545454544,
#    'wordcount': 3},
#   'pos'),
#  ({'mean_compound': 1.2671024390243901,
#    'mean_positive': 0.15278048780487805,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.026625, 'mean_positive': 0.090375, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.86825, 'mean_positive': 0.0775, 'wordcount': 0}, 'pos'),
#  ({'mean_compound': 0.7337285714285715,
#    'mean_positive': 0.061285714285714284,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9832620689655173,
#    'mean_positive': 0.08037931034482759,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 0.9430978260869565,
#    'mean_positive': 0.10080434782608695,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1505296296296297,
#    'mean_positive': 0.11359259259259259,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.0300488372093024,
#    'mean_positive': 0.12632558139534883,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.2297774193548388,
#    'mean_positive': 0.1586774193548387,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0373193548387096,
#    'mean_positive': 0.08293548387096775,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.1486695652173913,
#    'mean_positive': 0.14917391304347827,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.073578947368421,
#    'mean_positive': 0.06963157894736842,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.18828, 'mean_positive': 0.14845, 'wordcount': 2}, 'pos'),
#  ({'mean_compound': 0.9686705882352942,
#    'mean_positive': 0.08002941176470588,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.15414,
#    'mean_positive': 0.09278181818181819,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.0475407407407407,
#    'mean_positive': 0.06585185185185186,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9435034482758621,
#    'mean_positive': 0.0703448275862069,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.096777319587629,
#    'mean_positive': 0.1328041237113402,
#    'wordcount': 8},
#   'pos'),
#  ({'mean_compound': 0.9564033333333334,
#    'mean_positive': 0.1076,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9402130434782608,
#    'mean_positive': 0.058565217391304346,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9264525, 'mean_positive': 0.1245, 'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.2403242424242424,
#    'mean_positive': 0.12284848484848485,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.038078947368421,
#    'mean_positive': 0.10373684210526316,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.14775, 'mean_positive': 0.16225, 'wordcount': 0}, 'pos'),
#  ({'mean_compound': 0.8708259259259259,
#    'mean_positive': 0.07751851851851851,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.056602564102564,
#    'mean_positive': 0.13638461538461538,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9279450980392157,
#    'mean_positive': 0.08349019607843138,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1481190476190477,
#    'mean_positive': 0.15652380952380954,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.1771411764705881,
#    'mean_positive': 0.13220588235294117,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.0328294117647059,
#    'mean_positive': 0.09423529411764706,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9402214285714285,
#    'mean_positive': 0.11825,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.2647265306122448,
#    'mean_positive': 0.14706122448979592,
#    'wordcount': 3},
#   'pos'),
#  ({'mean_compound': 1.1937483870967742,
#    'mean_positive': 0.1095483870967742,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.3699789473684212,
#    'mean_positive': 0.17008771929824562,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.1152475, 'mean_positive': 0.122375, 'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1827926829268294,
#    'mean_positive': 0.13402439024390245,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.0829839285714287,
#    'mean_positive': 0.0855,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.004409677419355,
#    'mean_positive': 0.11303225806451613,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 0.9177,
#    'mean_positive': 0.09979245283018869,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0954625,
#    'mean_positive': 0.14641666666666667,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.8538489795918367,
#    'mean_positive': 0.06479591836734694,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 0.888516393442623,
#    'mean_positive': 0.06126229508196721,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0868428571428572,
#    'mean_positive': 0.12299047619047619,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.2083791666666666,
#    'mean_positive': 0.168375,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.0509976190476191,
#    'mean_positive': 0.1219047619047619,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0913354838709677,
#    'mean_positive': 0.14706451612903226,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1096727272727274,
#    'mean_positive': 0.10927272727272727,
#    'wordcount': 3},
#   'pos'),
#  ({'mean_compound': 1.1355212121212122,
#    'mean_positive': 0.13793939393939394,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 0.9435571428571429,
#    'mean_positive': 0.13917142857142858,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9715363636363636,
#    'mean_positive': 0.09304545454545454,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.070213157894737,
#    'mean_positive': 0.13173684210526315,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0115466666666666, 'mean_positive': 0.11, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1021809523809525,
#    'mean_positive': 0.09814285714285714,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.032108695652174,
#    'mean_positive': 0.10969565217391304,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.911765625, 'mean_positive': 0.06078125, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.009785294117647,
#    'mean_positive': 0.061735294117647055,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9501859375, 'mean_positive': 0.0694375, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.16168, 'mean_positive': 0.121825, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0069233333333334,
#    'mean_positive': 0.11003333333333333,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1821392857142858,
#    'mean_positive': 0.162,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.1116378378378378,
#    'mean_positive': 0.08291891891891892,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.134808510638298,
#    'mean_positive': 0.14780851063829786,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1536210526315789,
#    'mean_positive': 0.21847368421052632,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.05482,
#    'mean_positive': 0.10676666666666666,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.0089, 'mean_positive': 0.0857, 'wordcount': 0}, 'neg'),
#  ({'mean_compound': 0.968225,
#    'mean_positive': 0.06382142857142857,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1238411764705882,
#    'mean_positive': 0.12673529411764706,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0769,
#    'mean_positive': 0.10890697674418605,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.175565625, 'mean_positive': 0.13515625, 'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.2299632653061225,
#    'mean_positive': 0.14806122448979592,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.011925,
#    'mean_positive': 0.08808333333333333,
#    'wordcount': 4},
#   'neg'),
#  ({'mean_compound': 1.26267, 'mean_positive': 0.121225, 'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 0.9024925925925926,
#    'mean_positive': 0.09481481481481481,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9691774193548387,
#    'mean_positive': 0.07354838709677419,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.080316, 'mean_positive': 0.13344, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9898625, 'mean_positive': 0.08125, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0994973684210527,
#    'mean_positive': 0.16955263157894737,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9505695652173913,
#    'mean_positive': 0.07352173913043478,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.2013944444444444,
#    'mean_positive': 0.12069444444444444,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1088035714285713,
#    'mean_positive': 0.12575,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1033151515151516,
#    'mean_positive': 0.112,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.8952736842105263,
#    'mean_positive': 0.07036842105263158,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.03859375, 'mean_positive': 0.10703125, 'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.9434777777777777,
#    'mean_positive': 0.11337037037037037,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.8998314285714286,
#    'mean_positive': 0.07811428571428572,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.11449,
#    'mean_positive': 0.11665714285714286,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 0.9681896551724138,
#    'mean_positive': 0.09824137931034482,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0277181818181818,
#    'mean_positive': 0.10181818181818182,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.0769577777777777,
#    'mean_positive': 0.12382222222222222,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9800294871794872,
#    'mean_positive': 0.054128205128205126,
#    'wordcount': 8},
#   'pos'),
#  ({'mean_compound': 1.1916454545454545,
#    'mean_positive': 0.15693181818181817,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.1243555555555556,
#    'mean_positive': 0.12777777777777777,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1559142857142857,
#    'mean_positive': 0.1466,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.9474,
#    'mean_positive': 0.10445652173913043,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0813217391304348,
#    'mean_positive': 0.09778260869565218,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1446, 'mean_positive': 0.081, 'wordcount': 2}, 'pos'),
#  ({'mean_compound': 0.9296153846153846,
#    'mean_positive': 0.1432820512820513,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1545703703703705,
#    'mean_positive': 0.1034074074074074,
#    'wordcount': 10},
#   'pos'),
#  ({'mean_compound': 0.9082945945945946,
#    'mean_positive': 0.09437837837837838,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0748853658536586,
#    'mean_positive': 0.08285365853658537,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.2901067796610168,
#    'mean_positive': 0.16466101694915256,
#    'wordcount': 7},
#   'pos'),
#  ({'mean_compound': 1.052161111111111,
#    'mean_positive': 0.07177777777777777,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.7448739130434783,
#    'mean_positive': 0.07904347826086956,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.303284, 'mean_positive': 0.13596, 'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.0086722222222222,
#    'mean_positive': 0.08233333333333333,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.327016, 'mean_positive': 0.15976, 'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.031334090909091,
#    'mean_positive': 0.11111363636363636,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0916594594594595,
#    'mean_positive': 0.0944054054054054,
#    'wordcount': 12},
#   'pos'),
#  ({'mean_compound': 0.8414, 'mean_positive': 0.054, 'wordcount': 0}, 'neg'),
#  ({'mean_compound': 1.0621546875, 'mean_positive': 0.09971875, 'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 0.9830458333333333,
#    'mean_positive': 0.06466666666666666,
#    'wordcount': 3},
#   'pos'),
#  ({'mean_compound': 1.0102125,
#    'mean_positive': 0.11441666666666667,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9987903225806452,
#    'mean_positive': 0.08519354838709678,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0838608695652174,
#    'mean_positive': 0.16056521739130436,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9299275862068965,
#    'mean_positive': 0.10236206896551724,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.178725, 'mean_positive': 0.1428125, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0152642857142857,
#    'mean_positive': 0.11082142857142857,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0377483333333333,
#    'mean_positive': 0.15341666666666667,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.075791304347826,
#    'mean_positive': 0.0811304347826087,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.007225, 'mean_positive': 0.083, 'wordcount': 0}, 'neg'),
#  ({'mean_compound': 1.07764, 'mean_positive': 0.1953, 'wordcount': 0}, 'pos'),
#  ({'mean_compound': 1.1658641025641026,
#    'mean_positive': 0.12764102564102564,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.047966265060241,
#    'mean_positive': 0.1290120481927711,
#    'wordcount': 16},
#   'pos'),
#  ({'mean_compound': 1.1862657894736843,
#    'mean_positive': 0.14278947368421052,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.4685425531914893,
#    'mean_positive': 0.2094468085106383,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.746476923076923,
#    'mean_positive': 0.08092307692307693,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.2157875, 'mean_positive': 0.1481875, 'wordcount': 4},
#   'pos'),
#  ({'mean_compound': 1.0279,
#    'mean_positive': 0.062160714285714284,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.8534999999999999,
#    'mean_positive': 0.06323076923076923,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.2176791666666666,
#    'mean_positive': 0.15389583333333334,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1471913043478261,
#    'mean_positive': 0.08956521739130435,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.170173076923077,
#    'mean_positive': 0.1503076923076923,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.2064568181818183,
#    'mean_positive': 0.14572727272727273,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1157162162162162,
#    'mean_positive': 0.14635135135135136,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9853638888888889,
#    'mean_positive': 0.10533333333333333,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.8955302325581396,
#    'mean_positive': 0.08467441860465116,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9238857142857143,
#    'mean_positive': 0.07731428571428571,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.8513727272727273,
#    'mean_positive': 0.09986363636363636,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.3508379310344827,
#    'mean_positive': 0.20444827586206896,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.07463, 'mean_positive': 0.08425, 'wordcount': 0}, 'neg'),
#  ({'mean_compound': 1.025625,
#    'mean_positive': 0.11780769230769231,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.2215533333333333,
#    'mean_positive': 0.16373333333333334,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.1729315789473684,
#    'mean_positive': 0.10347368421052631,
#    'wordcount': 5},
#   'pos'),
#  ({'mean_compound': 1.3685695652173913,
#    'mean_positive': 0.183,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.8965333333333333,
#    'mean_positive': 0.14666666666666667,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0795762711864407,
#    'mean_positive': 0.12561016949152543,
#    'wordcount': 12},
#   'pos'),
#  ({'mean_compound': 1.1350212121212122,
#    'mean_positive': 0.17057575757575758,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.03767, 'mean_positive': 0.1437, 'wordcount': 0}, 'neg'),
#  ({'mean_compound': 0.95195,
#    'mean_positive': 0.12642307692307692,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0218324324324324,
#    'mean_positive': 0.07548648648648648,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.017221875, 'mean_positive': 0.09346875, 'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.1965860465116278,
#    'mean_positive': 0.09311627906976744,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.058132, 'mean_positive': 0.1028, 'wordcount': 1}, 'neg'),
#  ({'mean_compound': 1.0574307692307692,
#    'mean_positive': 0.09773076923076923,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.3971208333333334,
#    'mean_positive': 0.19366666666666668,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.1345795454545455,
#    'mean_positive': 0.12697727272727272,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.3450222222222221,
#    'mean_positive': 0.16244444444444445,
#    'wordcount': 6},
#   'pos'),
#  ({'mean_compound': 1.187323076923077,
#    'mean_positive': 0.13848717948717948,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9226514285714286,
#    'mean_positive': 0.07677142857142857,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9363139534883721,
#    'mean_positive': 0.09465116279069767,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9673935483870968,
#    'mean_positive': 0.107,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.32236, 'mean_positive': 0.1732, 'wordcount': 1}, 'pos'),
#  ({'mean_compound': 0.9685952380952381,
#    'mean_positive': 0.06152380952380952,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.006396, 'mean_positive': 0.12672, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9379513513513513,
#    'mean_positive': 0.11589189189189189,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 0.8503000000000001,
#    'mean_positive': 0.050225806451612905,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.893458064516129, 'mean_positive': 0.109, 'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1255034482758621,
#    'mean_positive': 0.10544827586206897,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9783459459459459,
#    'mean_positive': 0.1672972972972973,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0352137931034482,
#    'mean_positive': 0.09772413793103449,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 0.9189085106382979,
#    'mean_positive': 0.07391489361702128,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.8915666666666666,
#    'mean_positive': 0.057375,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.97998,
#    'mean_positive': 0.06922857142857143,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.170792,
#    'mean_positive': 0.12804000000000001,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0609555555555557,
#    'mean_positive': 0.11205555555555556,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.2683542857142858,
#    'mean_positive': 0.1556857142857143,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.0167473684210526,
#    'mean_positive': 0.11842105263157894,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.997255, 'mean_positive': 0.0917, 'wordcount': 0}, 'neg'),
#  ({'mean_compound': 1.0005,
#    'mean_positive': 0.10151923076923078,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.1905765957446808,
#    'mean_positive': 0.13751063829787233,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.7508285714285714,
#    'mean_positive': 0.069,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.908796551724138,
#    'mean_positive': 0.1323448275862069,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 0.9692134615384616,
#    'mean_positive': 0.1008076923076923,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 0.80614, 'mean_positive': 0.1254, 'wordcount': 0}, 'neg'),
#  ({'mean_compound': 1.00826, 'mean_positive': 0.1164, 'wordcount': 0}, 'neg'),
#  ({'mean_compound': 1.048045238095238,
#    'mean_positive': 0.09928571428571428,
#    'wordcount': 7},
#   'pos'),
#  ({'mean_compound': 1.086164705882353,
#    'mean_positive': 0.08476470588235294,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9369419999999999,
#    'mean_positive': 0.07548,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1742785714285715,
#    'mean_positive': 0.13942857142857143,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.3111825, 'mean_positive': 0.197275, 'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1374,
#    'mean_positive': 0.10394444444444444,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0025962962962962,
#    'mean_positive': 0.07875925925925926,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9202193548387096,
#    'mean_positive': 0.10093548387096775,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0464653846153846,
#    'mean_positive': 0.1448076923076923,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0990272727272727,
#    'mean_positive': 0.08418181818181818,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1870333333333334,
#    'mean_positive': 0.16149019607843138,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1079264150943395,
#    'mean_positive': 0.10069811320754717,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.0423694915254238,
#    'mean_positive': 0.13955932203389831,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.421658064516129,
#    'mean_positive': 0.24761290322580645,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9672756756756756,
#    'mean_positive': 0.0715945945945946,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.10201875, 'mean_positive': 0.1361875, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0921163265306122,
#    'mean_positive': 0.1370612244897959,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.053172,
#    'mean_positive': 0.08872000000000001,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1544390243902438,
#    'mean_positive': 0.10297560975609756,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.108869696969697,
#    'mean_positive': 0.10987878787878788,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.2072038461538461,
#    'mean_positive': 0.1266923076923077,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.6870714285714286,
#    'mean_positive': 0.05566666666666667,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0260291666666668,
#    'mean_positive': 0.10345833333333333,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9303066666666666,
#    'mean_positive': 0.07579999999999999,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1046115384615385,
#    'mean_positive': 0.11276923076923077,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9557318181818182,
#    'mean_positive': 0.08622727272727272,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.161521052631579,
#    'mean_positive': 0.12194736842105264,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 0.9728972602739726,
#    'mean_positive': 0.040547945205479455,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.5754894736842106,
#    'mean_positive': 0.03631578947368421,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.956839534883721,
#    'mean_positive': 0.07195348837209302,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.123575,
#    'mean_positive': 0.11055555555555556,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.8744102564102564,
#    'mean_positive': 0.12928205128205128,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.04569, 'mean_positive': 0.0861, 'wordcount': 1}, 'neg'),
#  ({'mean_compound': 1.0380796296296295,
#    'mean_positive': 0.12824074074074074,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.08986,
#    'mean_positive': 0.11535000000000001,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.8561181818181818,
#    'mean_positive': 0.061909090909090914,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.980721875, 'mean_positive': 0.11234375, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9841813333333334,
#    'mean_positive': 0.08309333333333334,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.2612,
#    'mean_positive': 0.15243589743589744,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.6456, 'mean_positive': 0.116, 'wordcount': 0}, 'neg'),
#  ({'mean_compound': 1.0785804347826087,
#    'mean_positive': 0.09447826086956522,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 0.8024909090909091,
#    'mean_positive': 0.06245454545454546,
#    'wordcount': 2},
#   'neg'),
#  ({'mean_compound': 1.2021096153846154,
#    'mean_positive': 0.15001923076923077,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.0378603448275863,
#    'mean_positive': 0.07687931034482759,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.256270588235294,
#    'mean_positive': 0.13488235294117648,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1399,
#    'mean_positive': 0.13721052631578948,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9824058823529411,
#    'mean_positive': 0.07074509803921569,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.796025,
#    'mean_positive': 0.06291666666666666,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9743308823529412,
#    'mean_positive': 0.08295588235294117,
#    'wordcount': 5},
#   'pos'),
#  ({'mean_compound': 1.1755384615384616,
#    'mean_positive': 0.09738461538461538,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.08148125, 'mean_positive': 0.100125, 'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0030358974358975,
#    'mean_positive': 0.06817948717948717,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.144638888888889,
#    'mean_positive': 0.13166666666666665,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1434961538461539,
#    'mean_positive': 0.14096153846153847,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.144892, 'mean_positive': 0.09168, 'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1928864864864865,
#    'mean_positive': 0.12316216216216216,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.9844238095238095,
#    'mean_positive': 0.08823809523809524,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 0.8175826086956521,
#    'mean_positive': 0.06434782608695652,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9454789473684211,
#    'mean_positive': 0.07363157894736842,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1330973684210526,
#    'mean_positive': 0.129,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.848625, 'mean_positive': 0.07465625, 'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.9302611111111111,
#    'mean_positive': 0.11155555555555556,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1338383333333333,
#    'mean_positive': 0.16606666666666667,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 0.9397964285714285,
#    'mean_positive': 0.08432142857142857,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0926,
#    'mean_positive': 0.10170212765957447,
#    'wordcount': 3},
#   'pos'),
#  ({'mean_compound': 0.9752208333333333,
#    'mean_positive': 0.090125,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.3402342857142857,
#    'mean_positive': 0.14274285714285714,
#    'wordcount': 4},
#   'pos'),
#  ({'mean_compound': 0.9591863636363637,
#    'mean_positive': 0.08418181818181818,
#    'wordcount': 5},
#   'pos'),
#  ({'mean_compound': 1.18892, 'mean_positive': 0.14805, 'wordcount': 1}, 'pos'),
#  ({'mean_compound': 1.2556714285714285,
#    'mean_positive': 0.162,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0727944444444444,
#    'mean_positive': 0.08997222222222222,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9106425, 'mean_positive': 0.081025, 'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.0516027027027026,
#    'mean_positive': 0.10378378378378378,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.128164705882353,
#    'mean_positive': 0.1235,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.3711214285714286,
#    'mean_positive': 0.1687142857142857,
#    'wordcount': 12},
#   'pos'),
#  ({'mean_compound': 1.0017090909090909,
#    'mean_positive': 0.09420454545454546,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.8263888888888888,
#    'mean_positive': 0.10937037037037037,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.7905333333333333,
#    'mean_positive': 0.0765925925925926,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.4383, 'mean_positive': 0.1845, 'wordcount': 2}, 'pos'),
#  ({'mean_compound': 1.2905666666666666,
#    'mean_positive': 0.09480000000000001,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.151776, 'mean_positive': 0.10106, 'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.8534942307692308,
#    'mean_positive': 0.06788461538461539,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1785116666666666,
#    'mean_positive': 0.15526666666666666,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.090659090909091,
#    'mean_positive': 0.09295454545454546,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.1055837209302326,
#    'mean_positive': 0.11248837209302326,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0834757575757576,
#    'mean_positive': 0.15981818181818183,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.9737727272727272,
#    'mean_positive': 0.05121212121212121,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1220533333333333,
#    'mean_positive': 0.1084,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.2599714285714285,
#    'mean_positive': 0.12614285714285714,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9729,
#    'mean_positive': 0.1345909090909091,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.7083823529411766,
#    'mean_positive': 0.2678235294117647,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0097571428571428,
#    'mean_positive': 0.08771428571428572,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9672065217391305,
#    'mean_positive': 0.06910869565217391,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1300815789473684,
#    'mean_positive': 0.13815789473684212,
#    'wordcount': 5},
#   'pos'),
#  ({'mean_compound': 1.2358625, 'mean_positive': 0.11975, 'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 0.9152052631578947,
#    'mean_positive': 0.06097368421052632,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.009937037037037,
#    'mean_positive': 0.09985185185185186,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.22108, 'mean_positive': 0.0934, 'wordcount': 0}, 'pos'),
#  ({'mean_compound': 1.2200897435897435,
#    'mean_positive': 0.16528205128205128,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.0097944444444444,
#    'mean_positive': 0.09397222222222222,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.9114292682926829,
#    'mean_positive': 0.07380487804878048,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.013928488372093,
#    'mean_positive': 0.038209302325581396,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.4221742857142856,
#    'mean_positive': 0.1915714285714286,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.7556636363636364,
#    'mean_positive': 0.11466666666666667,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.143878, 'mean_positive': 0.13608, 'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9088173913043478,
#    'mean_positive': 0.09556521739130436,
#    'wordcount': 0},
#   'neg'),
# ...
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0204,
#    'mean_positive': 0.11588888888888889,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1496833333333334,
#    'mean_positive': 0.12278333333333333,
#    'wordcount': 3},
#   'pos'),
#  ({'mean_compound': 0.9769965517241379,
#    'mean_positive': 0.07310344827586207,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1437714285714287,
#    'mean_positive': 0.09895238095238096,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1700136363636364,
#    'mean_positive': 0.12118181818181818,
#    'wordcount': 11},
#   'pos'),
#  ({'mean_compound': 1.0336387096774193,
#    'mean_positive': 0.08829032258064516,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0370032258064517,
#    'mean_positive': 0.12287096774193548,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.94415, 'mean_positive': 0.10225, 'wordcount': 1}, 'neg'),
#  ({'mean_compound': 1.1114553571428571,
#    'mean_positive': 0.12133928571428572,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9337777777777778,
#    'mean_positive': 0.0635,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.1528666666666667,
#    'mean_positive': 0.0955,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1176041666666667,
#    'mean_positive': 0.11812500000000001,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.9633833333333334,
#    'mean_positive': 0.1215,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.101325,
#    'mean_positive': 0.10782142857142857,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.267596875, 'mean_positive': 0.1391875, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9976825, 'mean_positive': 0.056125, 'wordcount': 5},
#   'pos'),
#  ({'mean_compound': 1.2884941176470588,
#    'mean_positive': 0.14358823529411766,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.4045176470588236,
#    'mean_positive': 0.20841176470588235,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.040265, 'mean_positive': 0.09475, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.2033767441860466,
#    'mean_positive': 0.10988372093023256,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.095942105263158,
#    'mean_positive': 0.054052631578947366,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.2576073170731707,
#    'mean_positive': 0.15502439024390244,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.15015, 'mean_positive': 0.1442, 'wordcount': 5}, 'pos'),
#  ({'mean_compound': 1.2102837209302326,
#    'mean_positive': 0.10879069767441861,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1151291666666667,
#    'mean_positive': 0.09247916666666667,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9870471264367816,
#    'mean_positive': 0.05441379310344828,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.0259387096774193,
#    'mean_positive': 0.15038709677419354,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0014518518518518,
#    'mean_positive': 0.06357407407407407,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.0435978260869565,
#    'mean_positive': 0.09073913043478261,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.922265625, 'mean_positive': 0.07271875, 'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.2273390243902438,
#    'mean_positive': 0.10958536585365854,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.3219904761904762,
#    'mean_positive': 0.12557142857142858,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.062470588235294,
#    'mean_positive': 0.05944117647058823,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 0.87885,
#    'mean_positive': 0.09291666666666666,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0048866666666667,
#    'mean_positive': 0.07673333333333333,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1935923076923076,
#    'mean_positive': 0.12967307692307692,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.1518596774193548,
#    'mean_positive': 0.1376451612903226,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 0.7784230769230769,
#    'mean_positive': 0.049115384615384616,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.05989, 'mean_positive': 0.10276, 'wordcount': 0}, 'neg'),
#  ({'mean_compound': 1.1134741935483872,
#    'mean_positive': 0.1334516129032258,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 0.9910865384615385,
#    'mean_positive': 0.0724423076923077,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.017808695652174,
#    'mean_positive': 0.09721739130434782,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.121129411764706,
#    'mean_positive': 0.12094117647058823,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9374733333333334,
#    'mean_positive': 0.10016666666666667,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0799384615384615,
#    'mean_positive': 0.12121153846153845,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.12663125, 'mean_positive': 0.13478125, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1101234042553192,
#    'mean_positive': 0.1274468085106383,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.354247619047619,
#    'mean_positive': 0.17514285714285713,
#    'wordcount': 8},
#   'pos'),
#  ({'mean_compound': 1.1028764705882352,
#    'mean_positive': 0.10476470588235294,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0083551724137931,
#    'mean_positive': 0.1442758620689655,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.966365, 'mean_positive': 0.09855, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.4060181818181818,
#    'mean_positive': 0.25972727272727275,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.2838148148148147,
#    'mean_positive': 0.20666666666666667,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9516857142857142,
#    'mean_positive': 0.10285714285714286,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1242666666666667,
#    'mean_positive': 0.11007407407407407,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.970262962962963,
#    'mean_positive': 0.08462962962962962,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.7769961538461538,
#    'mean_positive': 0.05896153846153846,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9970488888888889,
#    'mean_positive': 0.12273333333333333,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.1892575757575758,
#    'mean_positive': 0.15627272727272729,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.2331195652173914,
#    'mean_positive': 0.1292608695652174,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.173346511627907,
#    'mean_positive': 0.18609302325581395,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.1330071428571429,
#    'mean_positive': 0.12989285714285714,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1689, 'mean_positive': 0.145625, 'wordcount': 0}, 'pos'),
#  ({'mean_compound': 1.1737974025974025,
#    'mean_positive': 0.12258441558441559,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1412032258064517,
#    'mean_positive': 0.11306451612903226,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9106714285714286,
#    'mean_positive': 0.10028571428571428,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9738368421052631,
#    'mean_positive': 0.06387719298245614,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0449318181818181,
#    'mean_positive': 0.11531818181818182,
#    'wordcount': 3},
#   'pos'),
#  ({'mean_compound': 1.0703421052631579,
#    'mean_positive': 0.09905263157894736,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1189526315789473,
#    'mean_positive': 0.12305263157894737,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9934111111111111,
#    'mean_positive': 0.06473333333333334,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.103508695652174,
#    'mean_positive': 0.13134782608695653,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.7535964285714286,
#    'mean_positive': 0.054107142857142854,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 0.9679411764705882,
#    'mean_positive': 0.05811764705882353,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.0868790322580646,
#    'mean_positive': 0.10338709677419355,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.2971222222222223,
#    'mean_positive': 0.15877777777777777,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.1469245614035088,
#    'mean_positive': 0.10808771929824561,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.2245854838709678,
#    'mean_positive': 0.11595161290322581,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.1372200000000001,
#    'mean_positive': 0.11993333333333334,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.0424333333333333,
#    'mean_positive': 0.08614285714285715,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.126295, 'mean_positive': 0.1042, 'wordcount': 0}, 'pos'),
#  ({'mean_compound': 0.9164230769230769,
#    'mean_positive': 0.08776923076923077,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.112268888888889,
#    'mean_positive': 0.09504444444444445,
#    'wordcount': 3},
#   'pos'),
#  ({'mean_compound': 0.8876921568627452,
#    'mean_positive': 0.09915686274509804,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0062461538461538,
#    'mean_positive': 0.07661538461538461,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9663775, 'mean_positive': 0.1012, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.180195918367347,
#    'mean_positive': 0.11461224489795918,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9452022727272728,
#    'mean_positive': 0.08329545454545455,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1064769230769231,
#    'mean_positive': 0.0963076923076923,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.4409096774193548,
#    'mean_positive': 0.20887096774193548,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.3776899999999999,
#    'mean_positive': 0.1309,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9668966666666666,
#    'mean_positive': 0.09783333333333333,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.7512529411764706,
#    'mean_positive': 0.06364705882352942,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9836868421052631,
#    'mean_positive': 0.09273684210526316,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.0626703703703704,
#    'mean_positive': 0.09337037037037037,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.0830382352941177,
#    'mean_positive': 0.08455882352941177,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1503612903225806,
#    'mean_positive': 0.11580645161290322,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.2291525, 'mean_positive': 0.103475, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.289203448275862,
#    'mean_positive': 0.12120689655172413,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.9987628571428572,
#    'mean_positive': 0.10337142857142857,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.1665928571428572,
#    'mean_positive': 0.10535714285714286,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0109642857142858,
#    'mean_positive': 0.08025,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.9165028571428572,
#    'mean_positive': 0.06817142857142858,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9760333333333333,
#    'mean_positive': 0.07762222222222222,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9031895833333333,
#    'mean_positive': 0.0600625,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9426527777777778,
#    'mean_positive': 0.05247222222222222,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.1871510204081632,
#    'mean_positive': 0.14287755102040817,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.212,
#    'mean_positive': 0.12866153846153847,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.040410344827586,
#    'mean_positive': 0.10213793103448277,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.0576714285714286,
#    'mean_positive': 0.14085714285714285,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.9114291666666666,
#    'mean_positive': 0.092875,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1684333333333332,
#    'mean_positive': 0.15555555555555556,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.05266, 'mean_positive': 0.102375, 'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9780064516129032,
#    'mean_positive': 0.07790322580645162,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.44038, 'mean_positive': 0.1362, 'wordcount': 0}, 'pos'),
#  ({'mean_compound': 1.1345869565217392,
#    'mean_positive': 0.11873913043478261,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.8936093023255813,
#    'mean_positive': 0.0768139534883721,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.003525,
#    'mean_positive': 0.07138636363636364,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 1.0122222222222221,
#    'mean_positive': 0.08803703703703704,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.163181818181818,
#    'mean_positive': 0.13218181818181818,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.085571875, 'mean_positive': 0.11690625, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.8355033898305084,
#    'mean_positive': 0.08788135593220339,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 1.3075541666666668,
#    'mean_positive': 0.170375,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9822,
#    'mean_positive': 0.09140298507462687,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 0.659528, 'mean_positive': 0.02824, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.84860625, 'mean_positive': 0.06415625, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0094633333333334,
#    'mean_positive': 0.0936,
#    'wordcount': 5},
#   'pos'),
#  ({'mean_compound': 1.0739641025641025,
#    'mean_positive': 0.09769230769230769,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.2849477272727272,
#    'mean_positive': 0.17363636363636364,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.9085730769230769,
#    'mean_positive': 0.0695,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.8136142857142857,
#    'mean_positive': 0.06360714285714285,
#    'wordcount': 9},
#   'pos'),
#  ({'mean_compound': 1.0104533333333334,
#    'mean_positive': 0.051533333333333334,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0285886075949366,
#    'mean_positive': 0.08881012658227848,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 0.9703617021276596,
#    'mean_positive': 0.08627659574468086,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.334862962962963,
#    'mean_positive': 0.13392592592592592,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0426882352941176,
#    'mean_positive': 0.0991764705882353,
#    'wordcount': 4},
#   'pos'),
#  ({'mean_compound': 1.0594105263157896,
#    'mean_positive': 0.11533333333333333,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.0517461538461539,
#    'mean_positive': 0.13182051282051283,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 0.862764, 'mean_positive': 0.11568, 'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 0.9359791666666667,
#    'mean_positive': 0.064875,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 1.167004, 'mean_positive': 0.1304, 'wordcount': 1}, 'pos'),
#  ({'mean_compound': 1.1747357142857142,
#    'mean_positive': 0.1735,
#    'wordcount': 1},
#   'pos'),
#  ({'mean_compound': 0.7377285714285715,
#    'mean_positive': 0.044071428571428574,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0120368421052632,
#    'mean_positive': 0.11357894736842106,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1418166666666667,
#    'mean_positive': 0.092,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.1521260869565217,
#    'mean_positive': 0.12434782608695652,
#    'wordcount': 2},
#   'pos'),
#  ({'mean_compound': 0.8807883720930233,
#    'mean_positive': 0.0722093023255814,
#    'wordcount': 1},
#   'neg'),
#  ({'mean_compound': 0.96913125, 'mean_positive': 0.10290625, 'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.3079941176470589,
#    'mean_positive': 0.20055882352941176,
#    'wordcount': 0},
#   'pos'),
#  ({'mean_compound': 1.0475964285714285,
#    'mean_positive': 0.10378571428571429,
#    'wordcount': 0},
#   'neg'),
#  ({'mean_compound': 1.2074135135135136,
#    'mean_positive': 0.1668108108108108,
#    'wordcount': 0},
#   'neg'),
#  ...]

# %%
train_count = len(features) // 4
shuffle(features)
for name, sklearn_classifier in classifiers.items():
    classifier = nltk.classify.SklearnClassifier(sklearn_classifier)
    classifier.train(features[:train_count])
    accuracy = nltk.classify.accuracy(classifier, features[train_count:])
    print(F"{accuracy:.2%} - {name}")
# Out:
# 66.67% - BernoulliNB
# 66.67% - ComplementNB
# 66.67% - MultinomialNB
# 70.13% - KNeighborsClassifier
# 62.60% - DecisionTreeClassifier
# 69.40% - RandomForestClassifier
# 71.73% - LogisticRegression
# 73.33% - MLPClassifier
# 70.80% - AdaBoostClassifier
